# %%
import pandas as pd

# %%
google_news = pd.read_csv('csvs/google_news_updated.csv', sep='\t')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
google_news[google_news.isnull().any(axis=1)]
# Out:
#    News
# 4   NaN
# 61  NaN

# %%
google_news.dropna(inplace=True)

# %%
dtm = tfidf.fit_transform(google_news['News'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=10,random_state=101)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=101)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV

search_params = {
  'n_components': [5, 10, 15, 20, 25],
  'learning_decay': [.5, .7]
}

model = LatentDirichletAllocation()

# Try all of the options
gridsearch = GridSearchCV(model, param_grid=search_params, n_jobs=-1, verbose=1)
gridsearch.fit(dtm)

# What did we find?
print("Best Model's Params: ", gridsearch.best_params_)
print("Best Log Likelihood Score: ", gridsearch.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -3454.3441540666377

# %%
topic_lst = []
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
    
    topic_lst.append([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['effect', 'electropages', 'ids', 'robin', 'heaven', 'prime', 'minerals', 'unique', 'ft', 'rare', 'amazon', 'point47', 'chakrabarti', 'sanctions', 'infineon']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['bid', 'discount', 'regulators', 'rtx', 'stockpiling', 'lake', 'alder', 'vw', 'hours', 'graphics', 'gaming', 'audi', 'segars', 'arm', 'duesmann']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['joint', 'javascript', 'detected', 'unusual', 'inquiries', 'activity', 'sure', 'availability', 'gaming', 'marvell', 'review', 'healthcare', 'contact', 'murphy', 'ministry']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['car', 'supply', 'tesla', 'semiconductor', 'global', 'news', 'production', '2021', 'new', 'chips', 'gm', 'year', 'said', 'shortage', 'chip']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['wang', 'mubadala', 'noah', 'bel', 'trevor', 'msrp', 'picks', 'hoarding', 'established', 'quarterly', 'smith', 'bolling', 'mansion', 'reuss', 'globalfoundries']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['126', 'gallons', 'settlement', 'kinsus', 'black', 'powerful', 'widow', 'unimicron', 'substrates', 'cells', 'ya', 'nan', 'abf', 'substrate', 'rivian']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['brazil', 'ihs', '2026', 'mexico', 'costs', 'transportation', 'exclusive', 'content', 'professionals', 'desktop', 'forecast', 'tax', 'thomson', 'barra', 'reuters']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['technology', 'end', 'intel', 'demand', 'industry', 'shortages', 'customers', 'information', 'market', 'pandemic', 'manufacturing', 'automotive', 'chain', 'tsmc', 'supply']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['satya', 'app', 'delta', 'cbs', 'benefit', 'cnn', 'indices', 'msu', 'performer', 'veerapaneni', 'window', 'liu', 'theme', 'gmt', 'michigan']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['savings', 'exactly', 'lottery', 'retirement', 'idc', 'whatsapp', 'moody', 'instruments', 'texas', 'glut', 'advisor', 'wheaton', 'fool', 'motley', 'marketplace']

# %%
import json

# %%
with open('csvs/google_topics.json','w+', encoding='utf-8') as f:
    f.writelines(json.dumps(topic_lst))

# %%
topic_results = LDA.transform(dtm)

# %%
topic_results.shape
# Out:
# (83, 10)

# %%
google_news['Topic'] = topic_results.argmax(axis=1)

# %%
google_news
# Out:
#                                                  News  Topic
# 0   Last Updated 7 days ago U.S., EU agree to work...      7
# 1   Live Now: President Biden Hosts a Meeting with...      7
# 2   Skip to main content The Struggle to Define Lo...      6
# 3   Search quotes, news & videos AMD CEO Lisa Su s...      7
# 5   Search quotes, news & videos Abu Dhabi-control...      3
# ..                                                ...    ...
# 80  WORKING FROM HOME CLOUD INNOVATION CXO MORE Hu...      4
# 81  If you're a crypto novice, you might be wonder...      3
# 82  Last Updated 40 minutes ago Auto output dives ...      7
# 83  Thursday, Oct 7th 2021 12AM 26°C 'It's easier ...      7
# 84  News Noticias Fund Managers & Funds Events Mag...      6
#
# [83 rows x 2 columns]

# %%
google_news.to_csv('csvs/google_news_with_topic.csv',sep='\t', index=False)

# %%
# ===================== COMPANY INFO Google News============================

# %%
all_news = list(google_news['News'])

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
import en_core_web_sm

# %%
nlp = en_core_web_sm.load()

# %%
doc = nlp(all_news[10])
[(X.text, X.label_) for X in doc.ents]
# Out:
# [('Elon Musk', 'PERSON'),
#  ('FRI', 'ORG'),
#  ('20217:41 AM', 'TIME'),
#  ('25 20212:50 AM EDT Share Article', 'TIME'),
#  ('Facebook Share Article', 'WORK_OF_ART'),
#  ('Twitter Share Article', 'PRODUCT'),
#  ('LinkedIn Share Article', 'ORG'),
#  ('next year', 'DATE'),
#  ('Italian', 'NORP'),
#  ('Friday', 'DATE'),
#  ('Intel', 'ORG'),
#  ('TSMC', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('several years', 'DATE'),
#  ('Tesla Motors', 'ORG'),
#  ('Elon Musk', 'PERSON'),
#  ('Model S.', 'PRODUCT'),
#  ('Elon Musk', 'ORG'),
#  ('Friday', 'DATE'),
#  ('next year', 'DATE'),
#  ('next year', 'DATE'),
#  ('Italian', 'NORP'),
#  ('Friday', 'DATE'),
#  ('Intel', 'ORG'),
#  ('TSMC', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('several years', 'DATE'),
#  ('Glenn O’Donnell', 'PERSON'),
#  ('Forrester', 'PERSON'),
#  ('2023', 'DATE'),
#  ('2022', 'DATE'),
#  ('2023', 'DATE'),
#  ('April', 'DATE'),
#  ('Ford', 'ORG'),
#  ('Volkswagen', 'ORG'),
#  ('Daimler', 'ORG'),
#  ('first-quarter', 'DATE'),
#  ('Musk', 'ORG'),
#  ('Tesla', 'ORDINAL'),
#  ('This quarter', 'DATE'),
#  ('Tesla', 'ORDINAL'),
#  ('AlixPartners', 'ORG'),
#  ('this week', 'DATE'),
#  ('$210 billion', 'MONEY'),
#  ('this year', 'DATE'),
#  ('Malaysia', 'GPE'),
#  ('Mark Wakefield', 'PERSON'),
#  ('AlixPartners', 'ORG'),
#  ('2019', 'DATE'),
#  ('Tesla', 'ORDINAL'),
#  ('Musk', 'ORG'),
#  ('July', 'DATE'),
#  ('Tesla', 'ORDINAL'),
#  ('5:00 PM', 'TIME'),
#  ('5:00 PM', 'TIME'),
#  ('CNBC', 'ORG'),
#  ('CNBC', 'ORG'),
#  ('CNBC', 'ORG'),
#  ('CNBC LLC', 'ORG'),
#  ('All Rights Reserved', 'WORK_OF_ART'),
#  ('Division of NBCUniversal Data', 'ORG'),
#  ('at least 15 minutes', 'TIME'),
#  ('Global Business and Financial News, Stock Quotes', 'ORG'),
#  ('Market Data', 'ORG'),
#  ('Analysis', 'LOC')]

# %%
organization = []
for news in all_news:
    doc = nlp(news)
    organization.append([i.text for i in doc.ents if (i.label_ == 'ORG' and i.text != "LLC")])

# %%
flat_org = [item for sublist in organization for item in sublist]

# %%
flat_org_unq = list(set(flat_org))

# %%
keywords = [
    "house",
    "university",
    "report",
    "information",
    "communication",
    "time",
    "visa",
    "master",
    "social",
    "sale",
    "invest",
    "street",
    "network",
    "terminal",
    "linked",
    "facebook",
    "yahoo",
    'youtube',
    "daily",
    "week",
    "business",
    "trust",
    "foundation",
    ".com",
    "stud",
    "history",
    "school",
    "stock",
    "world",
    "cnn",
    "science",
    "england &",
    "fund",
    "wordpress",
    "trump",
    "electric",
    "twitter",
    "musk",
    "elon",
    "berkley",
    "usb",
    "l.",
    "modi",
    "postal"
    "app",
    "semiconductor",
    "Li",
    "ST",
    "on",
    "Lattice",
    "micro",
    "state",
    "ip",
    "ev",
    "ml",
    "next",
    "live",
    "led",
    "silicon",
    "covid",
    "news",
    "journal",
    "council",
    'Global',
    'car',
    'app',
    'Government',
    'VAT',
    'Air',
    'OPEN',
    'Group',
    'WSJ',
    'Shop',
    'cnbc',
    'bank',
    "air",
    "fact",
    "mobil"
]

# %%
filtered_flat_org_unq = []

for org in flat_org_unq:
    flag = True
    for k in keywords:
        if k.strip().lower() in org.strip().lower():
            flag = False
            break
    if flag:
        filtered_flat_org_unq.append(org)

# %%
temp_all_news = " ".join(all_news)

# %%
freq_dict = dict()
for org in filtered_flat_org_unq:
    if len(org) > 2:
        count = temp_all_news.lower().count(org.lower())
        freq_dict[org] = count

# %%
freq_dict
# Out:
# {'Rewards': 4,
#  'Barcroft Media/Getty': 1,
#  "Pandora Papers '": 2,
#  'EPM': 1,
#  'Nissan Motor': 3,
#  'Jeep': 2,
#  'Marvell': 11,
#  'USPS View': 1,
#  'FAA': 1,
#  'Churchill': 5,
#  'Tesla General Motors Co': 5,
#  'Mellanox Technologies': 1,
#  'SUMCO': 1,
#  'Commerce Department': 7,
#  "The Democratic Party's": 1,
#  'JetBlue': 2,
#  'Lunchclub': 1,
#  'Part VII Surveillance': 1,
#  'Bain &': 2,
#  'Fiat Chrysler': 3,
#  'FOUP': 1,
#  'Nissan Motor Co.,': 2,
#  'IHS Markit': 8,
#  'Sainsbury': 1,
#  'Guardian': 2,
#  'Dodge': 2,
#  'Wang': 10,
#  'Ultra Cruise VW': 2,
#  'CSCRP': 12,
#  'SPD': 1,
#  'TSMC data': 1,
#  'Mojix': 2,
#  'Saks Fifth Avenue': 4,
#  'Pfizer': 4,
#  'Oak Furnitureland': 1,
#  'The Commerce Department': 4,
#  'US Treasury': 3,
#  'Ford Motor Co.’s': 1,
#  'Disney': 4,
#  'Hanbury': 4,
#  'Ajinomoto Co.': 1,
#  'CMA': 1,
#  'Fiat': 4,
#  'REE': 270,
#  'Market Data': 15,
#  'Terran Orbital': 1,
#  'HNA': 8,
#  'Volkswagen': 10,
#  'GamesRadar': 3,
#  'A16': 1,
#  'Verdict': 4,
#  'Intel INTC': 1,
#  'the US Department of Interior': 1,
#  'Null Pointer': 2,
#  'Hynix': 2,
#  'Meeker': 2,
#  'Howdy': 1,
#  'Toyota Motors': 2,
#  'HGV': 4,
#  'IHS Markit INFO': 1,
#  'NIO': 73,
#  'PFE': 1,
#  'Wells Fargo': 2,
#  'eBay': 1,
#  'Attisani/FT Share': 1,
#  'ITV': 1,
#  'NSO': 111,
#  "Democracy New York's": 1,
#  'Gavekal Research': 1,
#  'AMD RX': 2,
#  'Chicago Mercantile Exchange Inc.': 1,
#  'Associated Press': 3,
#  'BloombergLeft-Wing Rage': 3,
#  'RFI': 10,
#  'Fortune': 3,
#  'Buncefield Oil Depot': 1,
#  'Home Depot': 3,
#  'JPMorgan Chase & Co.': 1,
#  'Reuss says Looking': 1,
#  'Alejandro de la Garza/New York': 1,
#  'Societe Generale': 1,
#  'DoD': 3,
#  'GETTY': 18,
#  'Verge': 2,
#  'IHS Markit Prospecting': 1,
#  'TSMC': 147,
#  'MacRumors': 3,
#  'Toyota': 27,
#  'Arianespace': 1,
#  'TTC': 3,
#  'Fed': 28,
#  'Getty Images': 15,
#  'Mercedes-Benz': 1,
#  'AMIA': 2,
#  'CMS': 1,
#  'Spring Rock Green': 1,
#  'Wolfspeed Inc.': 1,
#  'UAE': 3,
#  'SaaS': 4,
#  'Nike': 1,
#  'the European Court': 2,
#  'Toyota Motor Corp.': 2,
#  'Ultraviolet Audio Video': 1,
#  'Reuters': 80,
#  'LBC': 3,
#  "Moody's": 4,
#  'Huawei': 4,
#  'BMG': 1,
#  'JJE North America': 1,
#  'Mace': 7,
#  'UAW': 5,
#  'Normative': 1,
#  'Supreme Court': 3,
#  'The Department for Transport': 1,
#  'Moody’s': 1,
#  'Mazda': 1,
#  'IHS MARKIT Automotive Research and Analysis Analysis': 1,
#  'FAQ': 1,
#  'VCU': 4,
#  'CIVAC': 2,
#  'JD Sports': 1,
#  'Channel 4': 2,
#  'Asbo': 2,
#  'Supply Chain Dive': 3,
#  'Miami |': 2,
#  'Goldman Sachs': 11,
#  'BoE': 3,
#  'Ford Motor Co.': 2,
#  'a UK Company': 1,
#  'Gavekal': 10,
#  'Royal Dutch Shell': 2,
#  'Volvo': 6,
#  'the Federal eRulemaking Portal': 1,
#  'Media Ltd.': 1,
#  'Cree Inc.': 1,
#  'GrabFood': 1,
#  'the Subscriber Agreement & Terms of Use': 1,
#  'Brent': 8,
#  'AMD': 43,
#  'Nissan': 23,
#  'LXRX': 2,
#  'DLC': 1,
#  'Duesmann': 12,
#  'Bain & Co.': 2,
#  'Michigan Senate': 1,
#  'Siemens': 1,
#  'NYSEMKT': 2,
#  'Intel Foundry Services': 1,
#  'Eloy': 4,
#  '14 Cores & Alder Lake-M': 1,
#  'The Associated Press': 2,
#  'UK Insurance': 1,
#  'Murphy': 13,
#  'Milkshakes': 2,
#  'BIS': 19,
#  'INEGI': 1,
#  'The New Yorker': 4,
#  'Marketplace': 10,
#  'the U.S. Department of Commerce': 1,
#  'Tesla Inc.': 1,
#  'Democratic Progressive Party': 1,
#  'INTC': 3,
#  'Porsche': 1,
#  'Fiat Chrysler Automobiles NV': 1,
#  '7:15AM IDC': 1,
#  'RED VENTURES': 1,
#  'The EU Digital Services': 1,
#  'the Digital Markets Act': 2,
#  "BBC Radio 4's": 1,
#  'the Wolfspeed Assurance of Supply Program': 1,
#  'BBC Radio 4’s': 1,
#  'Teslarati': 2,
#  'Ford Motor F -1.1%': 1,
#  'TIMOTHY A. CLARY/AFP': 1,
#  'The Motley Fool': 5,
#  'Kenyatta': 2,
#  'Oki Engineering': 1,
#  'Gavekal Asia': 1,
#  'GT Advanced Technologies': 1,
#  'Alexa': 1,
#  'AT&T Bell Laboratories': 1,
#  'Xcode': 2,
#  'LMC Automotive': 2,
#  'OEM': 2,
#  'AEB': 2,
#  'S&P': 11,
#  'LETI/CEA': 1,
#  'Woodford': 1,
#  'The US Commerce Department': 1,
#  'PCB': 2,
#  'Brexit': 11,
#  'Universal Credit': 8,
#  'Download Trefis Data': 1,
#  'Equiti Capital': 1,
#  'Boeing': 2,
#  'Target': 22,
#  'Samsung': 19,
#  'Bloomberg / Getty Images': 1,
#  'Nintendo Switch': 2,
#  'LMS Automotive': 1,
#  'Gavekal Gavekal': 1,
#  'AB Volvo': 5,
#  'Broadcom': 6,
#  'Nvidia': 30,
#  'Smash Bros.’': 1,
#  'ICE Data Services': 1,
#  'UBS': 111,
#  'pan-EU': 2,
#  'IKEA': 2,
#  'Intel': 86,
#  'Essex': 1,
#  'Sakurai': 1,
#  'DISMISSES': 3,
#  'Lloyds': 1,
#  'the US EPA': 1,
#  'Ford Motor Company': 1,
#  'Nissan Motor Co.': 2,
#  'AFP': 4,
#  'JSR': 1,
#  'Print  ': 1,
#  'Camber Energy Inc.': 1,
#  'Lexus': 2,
#  'Kellogg': 2,
#  'USICA': 3,
#  'POPULAR': 13,
#  'the General Assembly': 1,
#  'OPEC': 14,
#  'Email GM': 1,
#  'American Express Good': 2,
#  'Intraday Data': 2,
#  'Toyota Motor': 6,
#  'Macs May': 2,
#  'Coca-Cola': 2,
#  'Ultrasound Companies Seek Priority': 1,
#  'Academia Sinica': 5,
#  'Btu': 2,
#  'General Motors Co.': 2,
#  'VGC': 2,
#  'JPMorgan': 4,
#  'Harrell': 5,
#  'Biden-Pelosi Overreach': 2,
#  'Alphabet': 1,
#  'President Capital Management Corp.': 1,
#  'Acura': 1,
#  'Intel Corp.': 3,
#  'Ocotillo Fab': 1,
#  'Point47:26Oct 6, 2021': 1,
#  'SMIC': 2,
#  'EXCEPT': 5,
#  'CMX Denim': 2,
#  'Shell': 4,
#  'Qualcomm': 10,
#  'Miller': 3,
#  'Vaccine Tracker &': 1,
#  'Commerce': 29,
#  'BOSS Magazine': 1,
#  'HMRC': 1,
#  'USPS Press': 1,
#  'BVTV': 6,
#  'USPS': 5,
#  'Optus': 1,
#  '台積電': 1,
#  'Gartner': 4,
#  'Future brands': 2,
#  'Twitch': 13,
#  'CBS Interactive Inc.': 2,
#  'Vlad Novakovski': 2,
#  'Nedap Nedap': 2,
#  'General Motors': 47,
#  'Ajinomoto': 2,
#  'ADIZ': 2,
#  'LLP Brexit': 1,
#  'IHS MARKIT - OCTOBER 2021': 1,
#  'NHS': 1,
#  'Tesco': 6,
#  'BMW': 11,
#  'Medical Center Hospital': 1,
#  'FSD Beta': 1,
#  'Save & file': 2,
#  'Nasdaq': 8,
#  'Subaru': 2,
#  'Canberra': 1,
#  'Warner Media Company': 1,
#  'Mitsubishi Motors North America': 1,
#  'Howell': 1,
#  'Google': 3,
#  'Runway': 8,
#  'Culture Committee': 1,
#  'Mehrotra': 9,
#  'YOSHIFUMI UESAKA': 1,
#  'NAACP': 1,
#  'The US treasury': 1,
#  'Getty Images CHENG TING-FANG': 1,
#  'RHA': 18,
#  "General Motors Co's": 1,
#  'ABF': 14,
#  'Nvidia Corp.': 2,
#  'NBN': 1,
#  'Get Supply Chain Dive': 1,
#  'America Act': 5,
#  'General Motors GM': 1,
#  'Kung': 3,
#  'Ease Europe’s': 2,
#  'Sexy': 1,
#  'SaaS 2021': 2,
#  'The New YorkerBuy Covers': 1,
#  'N Glebe Road Suite 210': 1,
#  'Wolfspeed': 10,
#  'SCC': 2,
#  'Daring Buyer': 1,
#  'ResMed': 1,
#  'Slack': 1,
#  'MIT': 120,
#  'Powerball': 1,
#  'Cadillac': 8,
#  'MSU': 22,
#  'Diess': 3,
#  'Zach Daniel': 1,
#  'Mitsubishi': 2,
#  'DJI Opco': 1,
#  'Motorola': 1,
#  'IMF': 9,
#  'U.S. Supreme Court': 2,
#  'Cabinet': 5,
#  'The Prime Effect': 15,
#  'Macy': 9,
#  'Nvidia NVDA': 1,
#  'TPM': 1,
#  'the Commerce Department': 4,
#  'Future US Inc': 2,
#  'Insulate': 8,
#  'PRA': 25,
#  'Elkem ASA': 1,
#  'Critical Minerals': 7,
#  'RAM': 75,
#  'Satya Veerapaneni': 2,
#  'Barra': 23,
#  'GOP': 1,
#  'DigitalEurope': 1,
#  'UWB': 1,
#  'Segars': 17,
#  'LG Chem': 1,
#  'Hacker leaks Twitch': 1,
#  'Marvell Technology': 5,
#  'BIG DATA/IOT/': 1,
#  'Treasury': 5,
#  'Super Cruise': 7,
#  'Harvard': 3,
#  'Denso Corp.': 1,
#  'Hanbury of Bain': 1,
#  'The Home Office': 1,
#  'FRI': 35,
#  'Intel Corp': 6,
#  'BMW AG': 1,
#  'NYSE': 3,
#  'Digital': 27,
#  'Chinese Academy': 3,
#  'treasury': 5,
#  'Getty Images/Image Source': 1,
#  'Apollo': 1,
#  'EIA': 1,
#  'GMC Sierra': 1,
#  'EUV': 4,
#  'Hyundai': 5,
#  'Merkel Dismisses Russian Role': 2,
#  'Native': 16,
#  'the Success of Brands High Quits Rates,': 1,
#  'Ford': 31,
#  'USPS Slowdown': 1,
#  'US treasury': 3,
#  'Big Tech': 4,
#  'BBC': 6,
#  'IHS': 12,
#  'Electropages Media Ltd': 1,
#  'Campbell Soup': 1,
#  'The Penny Hoarder Issues “Urgent': 1,
#  'Punit PARANJPE': 1,
#  'Audi': 18,
#  'Camber Energy': 2,
#  'Buick': 3,
#  'ZDNet': 2,
#  'the Park Slope Food Co-op': 1,
#  'Toshiba': 1,
#  'Fox': 2,
#  'Merck': 2,
#  'the High Court': 1,
#  'GMC': 5,
#  'FCC': 2,
#  'EyeSight': 1,
#  'LatAm': 2,
#  'BeeHero': 2,
#  '@WillyShih_atHBS': 1,
#  'MarketWatch': 11,
#  'Church': 7,
#  'Boris brands': 1,
#  'SSD': 2,
#  'AJ Bell': 1,
#  'AMC Entertainment Holdings Inc.': 1,
#  '802.11az Empower': 1,
#  'FTSE': 7,
#  'Snap': 8,
#  'Futurum Research': 1,
#  'Energy Fuels': 4,
#  'FOREX': 1,
#  'PCGamesN': 2,
#  'Citywire': 4,
#  'Veerapaneni': 4,
#  'New Yorker': 5,
#  'NXPI': 1,
#  'Asda': 9,
#  'ET Intel Corp.': 1,
#  'NFT': 2,
#  'Women’s Hospital': 2,
#  'LAM Research': 1,
#  'GKN': 1,
#  'Insulate Britain': 7,
#  'REUTERS/': 7,
#  'Greggs': 2,
#  'Tesla Inc': 6,
#  'Ibiden Co.': 1,
#  'Senate': 8,
#  'The Sierra Club': 1,
#  'the US Federal Reserve': 1,
#  'Broadcom Corp.': 1,
#  'FRANKFURT': 2,
#  'Italy GM': 2,
#  'COBOL': 1,
#  'Nikkei Asia': 6,
#  'Kia': 6,
#  'SOURCING': 12,
#  'A15': 4,
#  'Tesla Motors': 2,
#  'CDC': 2,
#  'the Department of Commerce': 5,
#  'TurboTax': 1,
#  'FTC': 1,
#  'OCIO': 2,
#  'Nan Ya Printed Circuit Board Corp.': 1,
#  'RIN 0694-XC084': 1,
#  'Great Supply Chain Partners': 2,
#  'AWS': 14,
#  'Electropages': 6,
#  'Alberto Alerigi Junior': 1,
#  'Telegraph': 1,
#  'Qualcomm Inc.': 1,
#  'Park': 16,
#  'IDC': 9,
#  'Copyright 2018': 1,
#  'Wearable Sensors': 1}

# %%
sorted_freq_dict = {k: v for k, v in sorted(freq_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_freq_dict
# Out:
# {'REE': 270,
#  'TSMC': 147,
#  'MIT': 120,
#  'NSO': 111,
#  'UBS': 111,
#  'Intel': 86,
#  'Reuters': 80,
#  'RAM': 75,
#  'NIO': 73,
#  'General Motors': 47,
#  'AMD': 43,
#  'FRI': 35,
#  'Ford': 31,
#  'Nvidia': 30,
#  'Commerce': 29,
#  'Fed': 28,
#  'Toyota': 27,
#  'Digital': 27,
#  'PRA': 25,
#  'Nissan': 23,
#  'Barra': 23,
#  'Target': 22,
#  'MSU': 22,
#  'BIS': 19,
#  'Samsung': 19,
#  'GETTY': 18,
#  'RHA': 18,
#  'Audi': 18,
#  'Segars': 17,
#  'Native': 16,
#  'Park': 16,
#  'Market Data': 15,
#  'Getty Images': 15,
#  'The Prime Effect': 15,
#  'OPEC': 14,
#  'ABF': 14,
#  'AWS': 14,
#  'Murphy': 13,
#  'POPULAR': 13,
#  'Twitch': 13,
#  'CSCRP': 12,
#  'Duesmann': 12,
#  'IHS': 12,
#  'SOURCING': 12,
#  'Marvell': 11,
#  'Goldman Sachs': 11,
#  'S&P': 11,
#  'Brexit': 11,
#  'BMW': 11,
#  'MarketWatch': 11,
#  'Wang': 10,
#  'Volkswagen': 10,
#  'RFI': 10,
#  'Gavekal': 10,
#  'Marketplace': 10,
#  'Qualcomm': 10,
#  'Wolfspeed': 10,
#  'Mehrotra': 9,
#  'IMF': 9,
#  'Macy': 9,
#  'Asda': 9,
#  'IDC': 9,
#  'IHS Markit': 8,
#  'HNA': 8,
#  'Brent': 8,
#  'Universal Credit': 8,
#  'Nasdaq': 8,
#  'Runway': 8,
#  'Cadillac': 8,
#  'Insulate': 8,
#  'Snap': 8,
#  'Senate': 8,
#  'Commerce Department': 7,
#  'Mace': 7,
#  'Critical Minerals': 7,
#  'Super Cruise': 7,
#  'Church': 7,
#  'FTSE': 7,
#  'Insulate Britain': 7,
#  'REUTERS/': 7,
#  'Volvo': 6,
#  'Broadcom': 6,
#  'Toyota Motor': 6,
#  'BVTV': 6,
#  'Tesco': 6,
#  'Intel Corp': 6,
#  'BBC': 6,
#  'Tesla Inc': 6,
#  'Nikkei Asia': 6,
#  'Kia': 6,
#  'Electropages': 6,
#  'Churchill': 5,
#  'Tesla General Motors Co': 5,
#  'UAW': 5,
#  'The Motley Fool': 5,
#  'AB Volvo': 5,
#  'Academia Sinica': 5,
#  'Harrell': 5,
#  'EXCEPT': 5,
#  'USPS': 5,
#  'America Act': 5,
#  'Cabinet': 5,
#  'Marvell Technology': 5,
#  'Treasury': 5,
#  'treasury': 5,
#  'Hyundai': 5,
#  'GMC': 5,
#  'New Yorker': 5,
#  'the Department of Commerce': 5,
#  'Rewards': 4,
#  'Saks Fifth Avenue': 4,
#  'Pfizer': 4,
#  'The Commerce Department': 4,
#  'Disney': 4,
#  'Hanbury': 4,
#  'Fiat': 4,
#  'Verdict': 4,
#  'HGV': 4,
#  'SaaS': 4,
#  "Moody's": 4,
#  'Huawei': 4,
#  'VCU': 4,
#  'Eloy': 4,
#  'The New Yorker': 4,
#  'AFP': 4,
#  'JPMorgan': 4,
#  'Shell': 4,
#  'Gartner': 4,
#  'the Commerce Department': 4,
#  'EUV': 4,
#  'Big Tech': 4,
#  'Energy Fuels': 4,
#  'Citywire': 4,
#  'Veerapaneni': 4,
#  'A15': 4,
#  'Nissan Motor': 3,
#  'Fiat Chrysler': 3,
#  'US Treasury': 3,
#  'GamesRadar': 3,
#  'Associated Press': 3,
#  'BloombergLeft-Wing Rage': 3,
#  'Fortune': 3,
#  'Home Depot': 3,
#  'DoD': 3,
#  'MacRumors': 3,
#  'TTC': 3,
#  'UAE': 3,
#  'LBC': 3,
#  'Supreme Court': 3,
#  'Supply Chain Dive': 3,
#  'BoE': 3,
#  'INTC': 3,
#  'DISMISSES': 3,
#  'USICA': 3,
#  'Intel Corp.': 3,
#  'Miller': 3,
#  'Google': 3,
#  'Kung': 3,
#  'Diess': 3,
#  'Harvard': 3,
#  'NYSE': 3,
#  'Chinese Academy': 3,
#  'US treasury': 3,
#  'Buick': 3,
#  "Pandora Papers '": 2,
#  'Jeep': 2,
#  'JetBlue': 2,
#  'Bain &': 2,
#  'Nissan Motor Co.,': 2,
#  'Guardian': 2,
#  'Dodge': 2,
#  'Ultra Cruise VW': 2,
#  'Mojix': 2,
#  'Null Pointer': 2,
#  'Hynix': 2,
#  'Meeker': 2,
#  'Toyota Motors': 2,
#  'Wells Fargo': 2,
#  'AMD RX': 2,
#  'Verge': 2,
#  'AMIA': 2,
#  'the European Court': 2,
#  'Toyota Motor Corp.': 2,
#  'CIVAC': 2,
#  'Channel 4': 2,
#  'Asbo': 2,
#  'Miami |': 2,
#  'Ford Motor Co.': 2,
#  'Royal Dutch Shell': 2,
#  'LXRX': 2,
#  'Bain & Co.': 2,
#  'NYSEMKT': 2,
#  'The Associated Press': 2,
#  'Milkshakes': 2,
#  'the Digital Markets Act': 2,
#  'Teslarati': 2,
#  'Kenyatta': 2,
#  'Xcode': 2,
#  'LMC Automotive': 2,
#  'OEM': 2,
#  'AEB': 2,
#  'PCB': 2,
#  'Boeing': 2,
#  'Nintendo Switch': 2,
#  'pan-EU': 2,
#  'IKEA': 2,
#  'Nissan Motor Co.': 2,
#  'Lexus': 2,
#  'Kellogg': 2,
#  'American Express Good': 2,
#  'Intraday Data': 2,
#  'Macs May': 2,
#  'Coca-Cola': 2,
#  'Btu': 2,
#  'General Motors Co.': 2,
#  'VGC': 2,
#  'Biden-Pelosi Overreach': 2,
#  'SMIC': 2,
#  'CMX Denim': 2,
#  'Future brands': 2,
#  'CBS Interactive Inc.': 2,
#  'Vlad Novakovski': 2,
#  'Nedap Nedap': 2,
#  'Ajinomoto': 2,
#  'ADIZ': 2,
#  'Save & file': 2,
#  'Subaru': 2,
#  'Nvidia Corp.': 2,
#  'Ease Europe’s': 2,
#  'SaaS 2021': 2,
#  'SCC': 2,
#  'Mitsubishi': 2,
#  'U.S. Supreme Court': 2,
#  'Future US Inc': 2,
#  'Satya Veerapaneni': 2,
#  'Merkel Dismisses Russian Role': 2,
#  'Camber Energy': 2,
#  'ZDNet': 2,
#  'Fox': 2,
#  'Merck': 2,
#  'FCC': 2,
#  'LatAm': 2,
#  'BeeHero': 2,
#  'SSD': 2,
#  'PCGamesN': 2,
#  'NFT': 2,
#  'Women’s Hospital': 2,
#  'Greggs': 2,
#  'FRANKFURT': 2,
#  'Italy GM': 2,
#  'Tesla Motors': 2,
#  'CDC': 2,
#  'OCIO': 2,
#  'Great Supply Chain Partners': 2,
#  'Barcroft Media/Getty': 1,
#  'EPM': 1,
#  'USPS View': 1,
#  'FAA': 1,
#  'Mellanox Technologies': 1,
#  'SUMCO': 1,
#  "The Democratic Party's": 1,
#  'Lunchclub': 1,
#  'Part VII Surveillance': 1,
#  'FOUP': 1,
#  'Sainsbury': 1,
#  'SPD': 1,
#  'TSMC data': 1,
#  'Oak Furnitureland': 1,
#  'Ford Motor Co.’s': 1,
#  'Ajinomoto Co.': 1,
#  'CMA': 1,
#  'Terran Orbital': 1,
#  'A16': 1,
#  'Intel INTC': 1,
#  'the US Department of Interior': 1,
#  'Howdy': 1,
#  'IHS Markit INFO': 1,
#  'PFE': 1,
#  'eBay': 1,
#  'Attisani/FT Share': 1,
#  'ITV': 1,
#  "Democracy New York's": 1,
#  'Gavekal Research': 1,
#  'Chicago Mercantile Exchange Inc.': 1,
#  'Buncefield Oil Depot': 1,
#  'JPMorgan Chase & Co.': 1,
#  'Reuss says Looking': 1,
#  'Alejandro de la Garza/New York': 1,
#  'Societe Generale': 1,
#  'IHS Markit Prospecting': 1,
#  'Arianespace': 1,
#  'Mercedes-Benz': 1,
#  'CMS': 1,
#  'Spring Rock Green': 1,
#  'Wolfspeed Inc.': 1,
#  'Nike': 1,
#  'Ultraviolet Audio Video': 1,
#  'BMG': 1,
#  'JJE North America': 1,
#  'Normative': 1,
#  'The Department for Transport': 1,
#  'Moody’s': 1,
#  'Mazda': 1,
#  'IHS MARKIT Automotive Research and Analysis Analysis': 1,
#  'FAQ': 1,
#  'JD Sports': 1,
#  'a UK Company': 1,
#  'the Federal eRulemaking Portal': 1,
#  'Media Ltd.': 1,
#  'Cree Inc.': 1,
#  'GrabFood': 1,
#  'the Subscriber Agreement & Terms of Use': 1,
#  'DLC': 1,
#  'Michigan Senate': 1,
#  'Siemens': 1,
#  'Intel Foundry Services': 1,
#  '14 Cores & Alder Lake-M': 1,
#  'UK Insurance': 1,
#  'INEGI': 1,
#  'the U.S. Department of Commerce': 1,
#  'Tesla Inc.': 1,
#  'Democratic Progressive Party': 1,
#  'Porsche': 1,
#  'Fiat Chrysler Automobiles NV': 1,
#  '7:15AM IDC': 1,
#  'RED VENTURES': 1,
#  'The EU Digital Services': 1,
#  "BBC Radio 4's": 1,
#  'the Wolfspeed Assurance of Supply Program': 1,
#  'BBC Radio 4’s': 1,
#  'Ford Motor F -1.1%': 1,
#  'TIMOTHY A. CLARY/AFP': 1,
#  'Oki Engineering': 1,
#  'Gavekal Asia': 1,
#  'GT Advanced Technologies': 1,
#  'Alexa': 1,
#  'AT&T Bell Laboratories': 1,
#  'LETI/CEA': 1,
#  'Woodford': 1,
#  'The US Commerce Department': 1,
#  'Download Trefis Data': 1,
#  'Equiti Capital': 1,
#  'Bloomberg / Getty Images': 1,
#  'LMS Automotive': 1,
#  'Gavekal Gavekal': 1,
#  'Smash Bros.’': 1,
#  'ICE Data Services': 1,
#  'Essex': 1,
#  'Sakurai': 1,
#  'Lloyds': 1,
#  'the US EPA': 1,
#  'Ford Motor Company': 1,
#  'JSR': 1,
#  'Print  ': 1,
#  'Camber Energy Inc.': 1,
#  'the General Assembly': 1,
#  'Email GM': 1,
#  'Ultrasound Companies Seek Priority': 1,
#  'Alphabet': 1,
#  'President Capital Management Corp.': 1,
#  'Acura': 1,
#  'Ocotillo Fab': 1,
#  'Point47:26Oct 6, 2021': 1,
#  'Vaccine Tracker &': 1,
#  'BOSS Magazine': 1,
#  'HMRC': 1,
#  'USPS Press': 1,
#  'Optus': 1,
#  '台積電': 1,
#  'LLP Brexit': 1,
#  'IHS MARKIT - OCTOBER 2021': 1,
#  'NHS': 1,
#  'Medical Center Hospital': 1,
#  'FSD Beta': 1,
#  'Canberra': 1,
#  'Warner Media Company': 1,
#  'Mitsubishi Motors North America': 1,
#  'Howell': 1,
#  'Culture Committee': 1,
#  'YOSHIFUMI UESAKA': 1,
#  'NAACP': 1,
#  'The US treasury': 1,
#  'Getty Images CHENG TING-FANG': 1,
#  "General Motors Co's": 1,
#  'NBN': 1,
#  'Get Supply Chain Dive': 1,
#  'General Motors GM': 1,
#  'Sexy': 1,
#  'The New YorkerBuy Covers': 1,
#  'N Glebe Road Suite 210': 1,
#  'Daring Buyer': 1,
#  'ResMed': 1,
#  'Slack': 1,
#  'Powerball': 1,
#  'Zach Daniel': 1,
#  'DJI Opco': 1,
#  'Motorola': 1,
#  'Nvidia NVDA': 1,
#  'TPM': 1,
#  'Elkem ASA': 1,
#  'GOP': 1,
#  'DigitalEurope': 1,
#  'UWB': 1,
#  'LG Chem': 1,
#  'Hacker leaks Twitch': 1,
#  'BIG DATA/IOT/': 1,
#  'Denso Corp.': 1,
#  'Hanbury of Bain': 1,
#  'The Home Office': 1,
#  'BMW AG': 1,
#  'Getty Images/Image Source': 1,
#  'Apollo': 1,
#  'EIA': 1,
#  'GMC Sierra': 1,
#  'the Success of Brands High Quits Rates,': 1,
#  'USPS Slowdown': 1,
#  'Electropages Media Ltd': 1,
#  'Campbell Soup': 1,
#  'The Penny Hoarder Issues “Urgent': 1,
#  'Punit PARANJPE': 1,
#  'the Park Slope Food Co-op': 1,
#  'Toshiba': 1,
#  'the High Court': 1,
#  'EyeSight': 1,
#  '@WillyShih_atHBS': 1,
#  'Boris brands': 1,
#  'AJ Bell': 1,
#  'AMC Entertainment Holdings Inc.': 1,
#  '802.11az Empower': 1,
#  'Futurum Research': 1,
#  'FOREX': 1,
#  'NXPI': 1,
#  'ET Intel Corp.': 1,
#  'LAM Research': 1,
#  'GKN': 1,
#  'Ibiden Co.': 1,
#  'The Sierra Club': 1,
#  'the US Federal Reserve': 1,
#  'Broadcom Corp.': 1,
#  'COBOL': 1,
#  'TurboTax': 1,
#  'FTC': 1,
#  'Nan Ya Printed Circuit Board Corp.': 1,
#  'RIN 0694-XC084': 1,
#  'Alberto Alerigi Junior': 1,
#  'Telegraph': 1,
#  'Qualcomm Inc.': 1,
#  'Copyright 2018': 1,
#  'Wearable Sensors': 1}

# %%
import json

# %%
with open('csvs/updated_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(sorted_freq_dict))

# %%
import itertools

thirty_sorted_freq_dict = dict(itertools.islice(sorted_freq_dict.items(), 30))

# %%
with open('csvs/updated_thirty_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(thirty_sorted_freq_dict))

# %%
keys = list(sorted_freq_dict.keys())

# %%
lower_sorted_freq_dict = {k.lower():sorted_freq_dict[k] for k in keys}

# %%
with open('csvs/updated_sorted_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(lower_sorted_freq_dict))

# %%
import itertools

lower_thirty_sorted_freq_dict = dict(itertools.islice(lower_sorted_freq_dict.items(), 30))

# %%
with open('csvs/lower_updated_thirty_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(lower_thirty_sorted_freq_dict))

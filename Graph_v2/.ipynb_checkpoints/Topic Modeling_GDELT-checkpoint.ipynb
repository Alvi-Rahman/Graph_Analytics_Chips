# %%
import pandas as pd
import json
gdelt_news = pd.read_csv('csvs/gdelt_news_updated.csv', sep='\t')

# %%
gdelt_news.fillna('', inplace=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
dtm = tfidf.fit_transform(gdelt_news['News'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=10,random_state=101)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=101)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV

search_params = {
  'n_components': [5, 10, 15, 20, 25],
  'learning_decay': [.5, .7]
}

model = LatentDirichletAllocation()

# Try all of the options
gridsearch = GridSearchCV(model, param_grid=search_params, n_jobs=-1, verbose=1)
gridsearch.fit(dtm)

# What did we find?
print("Best Model's Params: ", gridsearch.best_params_)
print("Best Log Likelihood Score: ", gridsearch.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -2896.018811810439

# %%
topic_lst = []
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
    topic_lst.append([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['disadvantage', '1996', 'unsubscribe', 'stabilize', 'emails', 'cells', 'markit', 'vw', 'sanctions', 'audi', 'monthly', 'ihs', 'duesmann', 'rivian', 'reuss']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['mile', 'selecting', '219', 'lowering', 'simple', 'sacrificing', 'cheapest', 'exports', 'petrol', 'dependence', 'ways', 'vulnerable', 'freight', 'recession', 'hurting']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['detected', 'javascript', 'unusual', 'message', 'hoarding', 'window', 'ya', 'nan', 'circular', 'report', 'refurbished', 'abf', 'gmt', 'carbide', 'substrate']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['news', 'gm', 'production', 'chain', '2021', 'new', 'tsmc', 'industry', 'chips', 'semiconductor', 'year', 'shortage', 'said', 'supply', 'chip']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['uids', 'heating', 'biontech', 'easy', 'robin', 'cent', 'electropages', 'ids', 'unique', 'ticker', 'original', 'ft', 'barra', 'infineon', 'india']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['photoresists', 'quad', '31st', 'yoshifumi', 'insiders', 'redlen', 'champion', 'tokyo', '96', 'insights', 'nikkei', 'log', 'knock', 'icon', 'sketch']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['2030', 'content', 'mexico', 'division', 'quotes', 'inbox', 'eu', 'exclusive', 'professionals', 'desktop', 'inflation', 'delivered', 'thomson', 'cnbc', 'reuters']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['resilient', 'resiliency', 'federal', 'questions', 'private', 'healthcare', 'cscrp', 'automakers', 'yeast', 'request', 'features', 'vulnerabilities', 'congress', 'shocks', 'ministry']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['detroit', 'benefit', 'sic', 'performer', 'wang', 'memory', 'nedap', 'msrp', 'michigan', 'press', 'barra', 'supplier', 'carbide', 'theme', 'wolfspeed']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['report', 'alder', 'lake', 'advisors', 'mini', 'veerapaneni', 'gavekal', 'fool', '3nm', 'advisor', 'motley', 'musk', 'friday', '13', 'iphone']

# %%
with open('csvs/gdelt_topics.json','w+', encoding='utf-8') as f:
    f.writelines(json.dumps(topic_lst))

# %%
topic_results = LDA.transform(dtm)

# %%
gdelt_news['Topic'] = topic_results.argmax(axis=1)

# %%
gdelt_news.to_csv('csvs/gdelt_news_with_topic.csv', index=False)

# %%
all_news = list(gdelt_news['News'])

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(all_news[10])
[(X.text, X.label_) for X in doc.ents]
# Out:
# [('Kay Georgi', 'PERSON'),
#  ('John Gurtunca', 'PERSON'),
#  ('David Hanke', 'PERSON'),
#  ('Marwa Hassoun', 'PERSON'),
#  ('late September', 'DATE'),
#  ('the Biden Administration', 'ORG'),
#  ('White House', 'ORG'),
#  ('Congress', 'ORG'),
#  ('Commerce Department', 'ORG'),
#  ('White House', 'ORG'),
#  ('Congress', 'ORG'),
#  ('America Act', 'ORG'),
#  ('Commerce Continues Engagement', 'ORG'),
#  ('September 23, 2021', 'DATE'),
#  ('Commerce', 'ORG'),
#  ('Gina Raimondo', 'PERSON'),
#  ('National Economic Council', 'ORG'),
#  ('Brian Deese', 'PERSON'),
#  ('White House', 'FAC'),
#  ('third', 'ORDINAL'),
#  ('the Biden Administration', 'ORG'),
#  ('the U.S. Department of Commerce', 'ORG'),
#  ('September 24, 2021', 'DATE'),
#  ('the Commerce Department', 'ORG'),
#  ('Bureau of Industry and Security', 'ORG'),
#  ('BIS', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('non-U.S.', 'GPE'),
#  ('BIS', 'ORG'),
#  ('RFI', 'ORG'),
#  ('RFI', 'ORG'),
#  ('two', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('years 2019 and', 'DATE'),
#  ('2020', 'DATE'),
#  ('2021', 'DATE'),
#  ('three', 'CARDINAL'),
#  ('second', 'ORDINAL'),
#  ('BIS', 'ORG'),
#  ('2019', 'DATE'),
#  ('2020', 'DATE'),
#  ('monthly', 'DATE'),
#  ('2021', 'DATE'),
#  ('the next six months', 'DATE'),
#  ('BIS', 'ORG'),
#  ('the next six months', 'DATE'),
#  ('November 8, 2021', 'DATE'),
#  ('the Federal eRulemaking Portal', 'ORG'),
#  ('BIS', 'ORG'),
#  ('RIN 0694-XC084', 'ORG'),
#  ('Raimondo', 'PERSON'),
#  ('Commerce', 'ORG'),
#  ('RFI', 'ORG'),
#  ('September 23, 2021', 'DATE'),
#  ('Bloomberg', 'PERSON'),
#  ('the Biden Administration', 'ORG'),
#  ('the Defense Production Act', 'LAW'),
#  ('White House', 'ORG'),
#  ('Congress', 'ORG'),
#  ('Bolster Supply Chains Sameera Fazili', 'ORG'),
#  ('the National Economic Council', 'ORG'),
#  ('Peter Harrell', 'PERSON'),
#  ('International Economics and Competitiveness', 'ORG'),
#  ('the National Security Council', 'ORG'),
#  ('White House', 'ORG'),
#  ('September 23, 2021', 'DATE'),
#  ('RFI', 'ORG'),
#  ('the Biden Administration', 'ORG'),
#  ('Congress', 'ORG'),
#  ('Harrell', 'ORG'),
#  ('Administration', 'ORG'),
#  ('Southeast Asia', 'LOC'),
#  ('COVID', 'ORG'),
#  ('Congress', 'ORG'),
#  ('Fazili', 'ORG'),
#  ('Harrell', 'ORG'),
#  ('two', 'CARDINAL'),
#  ('First', 'ORDINAL'),
#  ('Congress', 'ORG'),
#  ('Second', 'ORDINAL'),
#  ('Congress', 'ORG'),
#  ('Critical Supply Chain Resiliency Program', 'ORG'),
#  ('the Department of Commerce', 'ORG'),
#  ('Biden', 'PERSON'),
#  ('CSCRP', 'ORG'),
#  ('Congress', 'ORG'),
#  ('June 8, 2021', 'DATE'),
#  ('Senate', 'ORG'),
#  ('the United States Innovation and Competition Act', 'ORG'),
#  ('USICA', 'ORG'),
#  ('Supply Chain Resilience Program', 'WORK_OF_ART'),
#  ('Senate', 'ORG'),
#  ('the CHIPS for America Act’s', 'ORG'),
#  ('USICA', 'ORG'),
#  ('House', 'ORG'),
#  ('later this year', 'DATE'),
#  ('early next year', 'DATE'),
#  ('House', 'ORG'),
#  ('Biden', 'PERSON'),
#  ('Build Back Better', 'WORK_OF_ART'),
#  ('the House Committee on Energy and Commerce', 'ORG'),
#  ('$10 billion', 'MONEY'),
#  ('five years', 'DATE'),
#  ('the Commerce Department', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('Biden Orders', 'PERSON'),
#  ('Review of America', 'ORG'),
#  ('Critical Minerals', 'ORG'),
#  ('Zombie', 'PERSON'),
#  ('FCC', 'ORG'),
#  ('Fox', 'ORG'),
#  ('John Gurtunca', 'PERSON'),
#  ('David Hanke', 'PERSON'),
#  ('Marwa Hassoun', 'PERSON'),
#  ('Follow Defense Production Act + Follow Request For Information + Follow Supply Chain + Follow Supply Shortages + Follow U.S. Commerce Department + Follow Administrative Agency + Follow',
#   'LAW'),
#  ('JD Supra', 'PERSON')]

# %%
organization = []
for news in all_news:
    doc = nlp(news)
    organization.append([i.text for i in doc.ents if (i.label_ == 'ORG' and i.text != "LLC")])

# %%
flat_org = [item for sublist in organization for item in sublist]

# %%
flat_org_unq = list(set(flat_org))

# %%
keywords = [
    "house",
    "university",
    "report",
    "information",
    "communication",
    "time",
    "visa",
    "master",
    "social",
    "sale",
    "invest",
    "street",
    "network",
    "terminal",
    "linked",
    "facebook",
    "yahoo",
    'youtube',
    "daily",
    "week",
    "business",
    "trust",
    "foundation",
    ".com",
    "stud",
    "history",
    "school",
    "stock",
    "world",
    "cnn",
    "science",
    "england &",
    "fund",
    "wordpress",
    "trump",
    "electric",
    "twitter",
    "musk",
    "elon",
    "berkley",
    "usb",
    "l.",
    "modi",
    "postal"
    "app",
    "semiconductor",
    "Li",
    "ST",
    "on",
    "Lattice",
    "micro",
    "state",
    "ip",
    "ev",
    "ml",
    "next",
    "live",
    "led",
    "silicon",
    "covid",
    "news",
    "journal",
    "council",
    "SaaS",
    'Global',
    'car',
    'app',
    'Government',
    'VAT',
    'Air',
    'OPEN',
    'Group',
    'WSJ',
    'Shop',
    'cnbc',
    'Bank'
]

# %%
filtered_flat_org_unq = []

for org in flat_org_unq:
    flag = True
    for k in keywords:
        if k.strip().lower() in org.strip().lower():
            flag = False
            break
    if flag:
        filtered_flat_org_unq.append(org)

# %%
filtered_flat_org_unq
# Out:
# ['Mellanox Technologies',
#  'US Treasury',
#  'BoE',
#  'General Motors Co.',
#  'Native',
#  'Mehrotra',
#  'Marvell',
#  'MacRumors',
#  'ET Intel Corp.',
#  'IHS MARKIT - OCTOBER 2021',
#  'Toyota Motors',
#  'Nikkei Asia',
#  'the General Assembly',
#  'Ultrasound Companies Seek Priority',
#  'PSA Group',
#  'Qualcomm',
#  'Toshiba',
#  'GKN',
#  'PE',
#  'Nintendo Switch',
#  'RAM',
#  'Apple Arcade',
#  'Shop',
#  'GT Advanced Technologies',
#  'GOP',
#  'AMD',
#  'VW',
#  'Nan Ya Printed Circuit Board Corp.',
#  'Campbell Soup',
#  'CMX Denim',
#  'Xcode',
#  'PFE',
#  'Alexa',
#  'The Home Office',
#  'LMC Automotive',
#  'ResMed',
#  'EUV',
#  'Ford',
#  'DigitalEurope',
#  'Wolfspeed',
#  'the U.S. Government',
#  'Harrell',
#  'Punit PARANJPE',
#  'MSU',
#  'IHS MARKIT Automotive Research and Analysis Analysis',
#  'S&P',
#  'pan-EU',
#  'Getty Images CHENG TING-FANG',
#  'Null Pointer',
#  'the Park Slope Food Co-op',
#  'RIN 0694-XC084',
#  'Insulate Britain',
#  'USPS Press',
#  'IHS',
#  'Mazda',
#  'Culture Committee',
#  'General Motors',
#  'Oki Engineering',
#  'Hanbury of Bain',
#  'Snap',
#  'Future brands',
#  'SSD',
#  'IHS Markit Prospecting',
#  'JetBlue',
#  'LLP Brexit',
#  'UK Manufacturing',
#  'Chinese Academy',
#  'Buncefield Oil Depot',
#  'Fiat',
#  'Disney',
#  'Nissan Motor Co.',
#  'Danske Bank',
#  'Gavekal',
#  'Daring Buyer',
#  'Premium Carmakers',
#  'IDC',
#  'the U.S. Department of Commerce',
#  'Tesla Motors',
#  'Apple Inc. Companies',
#  'AT&T Bell Laboratories',
#  'TurboTax',
#  'TSMC data',
#  '802.11az Empower',
#  'CBS Interactive Inc.',
#  'Global Purchasing and Supply Chain',
#  'Electropages',
#  'Teslarati',
#  'FCC',
#  'Wolfspeed Inc.',
#  'UAE',
#  'Fed',
#  'FSD Beta',
#  'JPMorgan Chase & Co.',
#  'Equiti Capital',
#  'Big Tech',
#  'USPS Slowdown',
#  'Democratic Progressive Party',
#  'EyeSight',
#  'Ajinomoto Co.',
#  'Print  ',
#  'Milkshakes',
#  'EU',
#  'FAQ',
#  'Citigroup Inc.',
#  'HMRC',
#  'AEB',
#  'Runway',
#  'Miami |',
#  'Alberto Alerigi Junior',
#  'SPD',
#  'REUTERS/',
#  'the Commerce Department',
#  'Churchill',
#  'Marvell Technology',
#  'Nedap Nedap',
#  'Broadcom Corp.',
#  'Coca-Cola',
#  'Zach Daniel',
#  'NBN',
#  'HP',
#  'Acura',
#  'Download Trefis Data',
#  'NI',
#  'AJ Bell',
#  'IHS Markit',
#  'Howell',
#  'BBC',
#  'Part VII Surveillance',
#  'GLOBAL',
#  'Intel Corp.',
#  'Porsche',
#  'USPS View',
#  'Marketplace',
#  'British Airways',
#  'Intel Corp',
#  'Tesla Inc',
#  'Spring Rock Green',
#  'Nvidia NVDA',
#  'The Department for Transport',
#  'SUMCO',
#  'Getty Images',
#  'INEGI',
#  'Market Data',
#  'SMIC',
#  'CMS',
#  'Nissan Motor',
#  'Attisani/FT Share',
#  'Nissan',
#  'GamesRadar',
#  'PCGamesN',
#  'CNBC LLC',
#  'ITV',
#  'COBOL',
#  'Rewards',
#  'GMC',
#  'VAT',
#  'CSCRP',
#  'Broadcom',
#  'Great Supply Chain Partners',
#  'Ease Europe’s',
#  'Bloomberg / Getty Images',
#  'Hyundai',
#  'Nvidia',
#  'Verge',
#  'Arianespace',
#  'NV',
#  'Jeep',
#  'Brexit',
#  'the Digital Markets Act',
#  'UK Insurance',
#  'BOSS Magazine',
#  'NFT',
#  'The Penny Hoarder Issues “Urgent',
#  'JJE North America',
#  'Volkswagen Group',
#  'Church',
#  'Ibiden Co.',
#  '14 Cores & Alder Lake-M',
#  'IKEA',
#  'Barra',
#  'Motorola',
#  'Group',
#  "Volkswagen Group's",
#  'Rabobank',
#  'the US EPA',
#  'SOURCING',
#  'Hacker leaks Twitch',
#  'Vlad Novakovski',
#  'Intraday Data',
#  'Volvo',
#  'Save & file',
#  'Elkem ASA',
#  '台積電',
#  'AWS',
#  'Ultra Cruise VW',
#  'A15',
#  'Nissan Motor Co.,',
#  'Oak Furnitureland',
#  'DoD',
#  'A16',
#  'Medical Center Hospital',
#  'Verdict',
#  'Supreme Court',
#  "The Democratic Party's",
#  'Sexy',
#  'UM',
#  'Point47:26Oct 6, 2021',
#  'Audi',
#  'Ford Motor F -1.1%',
#  'WSJ',
#  'CMA',
#  'OEM',
#  'Pfizer',
#  'a UK Company',
#  'LXRX',
#  "the Bank of England's",
#  'Volkswagen',
#  'treasury',
#  'WhatsApp',
#  'Critical Minerals',
#  'TTC',
#  'Toyota Motor Corp.',
#  'Associated Press',
#  'Smash Bros.’',
#  'ADIZ',
#  'FRANKFURT',
#  'The Commerce Department',
#  'Ocotillo Fab',
#  'Nvidia Corp.',
#  'Lexus',
#  'US treasury',
#  'Meeker',
#  'Ultraviolet Audio Video',
#  'Energy Fuels',
#  'FOUP',
#  'Guardian',
#  'Terran Orbital',
#  'LBC',
#  'BeeHero',
#  'Murphy',
#  'VW Group',
#  'FTSE',
#  'AB Volvo',
#  'VGC',
#  'Chair of the Supply Chain Management Analytics Department',
#  'Kenyatta',
#  'the US Department of Interior',
#  'NYSE',
#  'BP',
#  'Reuters',
#  "Democracy New York's",
#  'FOREX',
#  'Healthcare',
#  'FACTSET',
#  'Academia Sinica',
#  'Warner Media Company',
#  'Ryanair',
#  'Reuss says Looking',
#  'Fox',
#  'the European Central Bank',
#  'Denso Corp.',
#  'GM',
#  'NXPI',
#  'Electropages Media Ltd',
#  'U.S. Supreme Court',
#  'the Wolfspeed Assurance of Supply Program',
#  'EXCEPT',
#  'Gavekal Research',
#  'Park',
#  'Tesco',
#  'Sainsbury',
#  'Essex',
#  'DISMISSES',
#  'CNBC',
#  'Insulate',
#  'Qualcomm Inc.',
#  'The EU Digital Services',
#  'LETI/CEA',
#  '@WillyShih_atHBS',
#  'JSR',
#  'TSMC',
#  'Lloyds',
#  'Getty Images/Image Source',
#  'Futurum Research',
#  'Global',
#  'American Express Good',
#  'SoftBank',
#  'OS',
#  'Royal Dutch Shell',
#  'The New YorkerBuy Covers',
#  'PRA',
#  'Ford Motor Company',
#  'DJI Opco',
#  'Mitsubishi',
#  'Normative',
#  'BMW AG',
#  'TPM',
#  'INTC',
#  'Nasdaq',
#  'the Subscriber Agreement & Terms of Use',
#  'Gavekal Global Macro Research',
#  'Merkel Dismisses Russian Role',
#  'Wells Fargo',
#  'Macs May',
#  'Universal Credit',
#  'BBC Radio 4’s',
#  'Camber Energy Inc.',
#  'Alphabet',
#  'ICE Data Services',
#  'Copyright 2018',
#  'the High Court',
#  'Segars',
#  'CAR',
#  'Societe Generale',
#  'USICA',
#  'IMF',
#  'Gavekal Gavekal',
#  'Twitch',
#  'Channel 4',
#  'Slack',
#  'Mace',
#  'Avis Budget Group Inc.',
#  'GlobalFoundries',
#  'Wang',
#  'BMW',
#  'SCC',
#  'Boris brands',
#  'Barcroft Media/Getty',
#  'N Glebe Road Suite 210',
#  'VCU',
#  'UBS',
#  'Powerball',
#  'The US Commerce Department',
#  'Brent',
#  'Camber Energy',
#  'AMC Entertainment Holdings Inc.',
#  'Gartner',
#  'HGV',
#  'Ford Motor Co.’s',
#  'Sami Fathi Apple',
#  'Vaccine Tracker &',
#  'Italy GM',
#  'BloombergLeft-Wing Rage',
#  'Commerce',
#  'Woodford',
#  'The Associated Press',
#  'Toyota',
#  'Toyota Motor',
#  'RED VENTURES',
#  'the Federal eRulemaking Portal',
#  'Eloy',
#  'Canberra',
#  'OPEN',
#  'GETTY',
#  'Telegraph',
#  'CDC',
#  'LatAm',
#  'Intel',
#  'GMC Sierra',
#  'Michigan Senate',
#  'AMD RX',
#  'Tesla General Motors Co',
#  "Pandora Papers '",
#  'Digital',
#  'eBay',
#  'Diess',
#  'Moody’s',
#  'Sakurai',
#  'ABF',
#  'Hynix',
#  'Cadillac',
#  'Super Cruise',
#  'Optus',
#  'FTC',
#  'TIMOTHY A. CLARY/AFP',
#  'the Bank of England',
#  'Apple MacBook',
#  'Siemens',
#  'IHS Markit INFO',
#  'Alejandro de la Garza/New York',
#  'Hanbury',
#  'Buick',
#  'Home Depot',
#  'Email GM',
#  'Mercedes-Benz',
#  'BMG',
#  'the European Court',
#  'Intel Foundry Services',
#  'Ford Motor Co.',
#  'Gavekal Asia',
#  'NYSEMKT',
#  'Nike',
#  'EIA',
#  'NAACP',
#  'Merck',
#  'the Success of Brands High Quits Rates,',
#  'The US treasury',
#  'Ajinomoto',
#  'DLC',
#  'Kia',
#  'FAA',
#  'NSO',
#  'CIVAC',
#  'New Yorker',
#  'America Act',
#  'British Apples and Pears',
#  'Air',
#  'Get Supply Chain Dive',
#  'USPS',
#  'Tesla Inc.',
#  'Goldman Sachs',
#  'The New Yorker',
#  'Intel INTC',
#  'Kung',
#  'BIS',
#  'Samsung',
#  'Shell',
#  'OCIO',
#  'NHS',
#  'General Motors GM',
#  'The Motley Fool',
#  'Media Ltd.',
#  'Greggs',
#  "General Motors Co's",
#  'GrabFood',
#  'app',
#  'UWB',
#  'Tsinghua Unigroup',
#  'REE',
#  'Classified Ad Recruitment & Career',
#  'Commerce Department',
#  'Cree Inc.',
#  'EPM',
#  'Veerapaneni',
#  'the Volkswagen Group',
#  'Mojix',
#  'LMS Automotive',
#  'RHA',
#  'Saks Fifth Avenue',
#  'LAM Research',
#  'Bank',
#  'NIO',
#  'OPEC',
#  'Kellogg',
#  'HNA',
#  'Apollo',
#  'Target',
#  "Moody's",
#  'Cabinet',
#  'Subaru',
#  'Asda',
#  "BBC Radio 4's",
#  'Fortune',
#  'Btu',
#  'JD Sports',
#  'Fiat Chrysler',
#  'Miller',
#  'Senate',
#  'RFI',
#  'Google',
#  'Bain &',
#  'Women’s Hospital',
#  'FRI',
#  'The Prime Effect',
#  'YOSHIFUMI UESAKA',
#  'Asbo',
#  'Biden-Pelosi Overreach',
#  'Dodge',
#  'LG Chem',
#  'Citywire',
#  'Treasury',
#  'JPMorgan',
#  'Alberto Alerigi Cars',
#  'Chicago Mercantile Exchange Inc.',
#  'FACT',
#  'Fiat Chrysler Automobiles NV',
#  '7:15AM IDC',
#  'Macy',
#  'the US Federal Reserve',
#  'BVTV',
#  'Supply Chain Dive',
#  'AFP',
#  'Wearable Sensors',
#  'Duesmann',
#  'AMIA',
#  'Government',
#  'The Sierra Club',
#  'MIT',
#  'the Department of Commerce',
#  'Harvard',
#  'GlobalData',
#  'Apple',
#  'Lunchclub',
#  'Satya Veerapaneni',
#  'UAW',
#  'Howdy',
#  'Bain & Co.',
#  'President Capital Management Corp.',
#  'Boeing',
#  'PCB',
#  'Mitsubishi Motors North America',
#  'BIG DATA/IOT/',
#  'MarketWatch',
#  'Future US Inc',
#  'Huawei',
#  'POPULAR',
#  'ZDNet']

# %%
temp_all_news = " ".join(all_news)

# %%
freq_dict = dict()
for org in filtered_flat_org_unq:
    if len(org) > 2:
        count = temp_all_news.lower().count(org.lower())
        freq_dict[org] = count

# %%
sorted_freq_dict = {k: v for k, v in sorted(freq_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_freq_dict
# Out:
# {'REE': 270,
#  'TSMC': 147,
#  'MIT': 120,
#  'UBS': 111,
#  'NSO': 111,
#  'Intel': 86,
#  'Apple': 82,
#  'Reuters': 80,
#  'RAM': 75,
#  'NIO': 73,
#  'General Motors': 47,
#  'AMD': 43,
#  'FRI': 35,
#  'Ford': 31,
#  'Nvidia': 30,
#  'Commerce': 29,
#  'Fed': 28,
#  'Toyota': 27,
#  'Digital': 27,
#  'PRA': 25,
#  'GlobalFoundries': 24,
#  'Nissan': 23,
#  'Barra': 23,
#  'MSU': 22,
#  'Target': 22,
#  'BIS': 19,
#  'Samsung': 19,
#  'Audi': 18,
#  'GETTY': 18,
#  'RHA': 18,
#  'Segars': 17,
#  'Native': 16,
#  'Park': 16,
#  'Getty Images': 15,
#  'Market Data': 15,
#  'The Prime Effect': 15,
#  'AWS': 14,
#  'ABF': 14,
#  'OPEC': 14,
#  'Murphy': 13,
#  'Twitch': 13,
#  'POPULAR': 13,
#  'IHS': 12,
#  'CSCRP': 12,
#  'SOURCING': 12,
#  'Duesmann': 12,
#  'Marvell': 11,
#  'S&P': 11,
#  'Brexit': 11,
#  'BMW': 11,
#  'Goldman Sachs': 11,
#  'MarketWatch': 11,
#  'Qualcomm': 10,
#  'Wolfspeed': 10,
#  'Gavekal': 10,
#  'Marketplace': 10,
#  'Volkswagen': 10,
#  'Wang': 10,
#  'RFI': 10,
#  'Mehrotra': 9,
#  'the U.S. Government': 9,
#  'IDC': 9,
#  'IMF': 9,
#  'Asda': 9,
#  'Macy': 9,
#  'Snap': 8,
#  'Runway': 8,
#  'IHS Markit': 8,
#  'Insulate': 8,
#  'Nasdaq': 8,
#  'Universal Credit': 8,
#  'Brent': 8,
#  'Cadillac': 8,
#  'HNA': 8,
#  'Senate': 8,
#  'Insulate Britain': 7,
#  'REUTERS/': 7,
#  'Church': 7,
#  'Critical Minerals': 7,
#  'FTSE': 7,
#  'Healthcare': 7,
#  'Mace': 7,
#  'Super Cruise': 7,
#  'Commerce Department': 7,
#  'Nikkei Asia': 6,
#  'Electropages': 6,
#  'BBC': 6,
#  'Intel Corp': 6,
#  'Tesla Inc': 6,
#  'CNBC LLC': 6,
#  'Broadcom': 6,
#  'Volvo': 6,
#  'Tesco': 6,
#  'Toyota Motor': 6,
#  'the Bank of England': 6,
#  'Kia': 6,
#  'Classified Ad Recruitment & Career': 6,
#  'BVTV': 6,
#  'Harrell': 5,
#  'Churchill': 5,
#  'Marvell Technology': 5,
#  'GMC': 5,
#  'Hyundai': 5,
#  'treasury': 5,
#  'AB Volvo': 5,
#  'FACTSET': 5,
#  'Academia Sinica': 5,
#  'EXCEPT': 5,
#  'Tesla General Motors Co': 5,
#  'New Yorker': 5,
#  'America Act': 5,
#  'USPS': 5,
#  'The Motley Fool': 5,
#  'Cabinet': 5,
#  'Treasury': 5,
#  'the Department of Commerce': 5,
#  'UAW': 5,
#  'EUV': 4,
#  'Fiat': 4,
#  'Disney': 4,
#  'Big Tech': 4,
#  'the Commerce Department': 4,
#  'Rewards': 4,
#  'Volkswagen Group': 4,
#  'A15': 4,
#  'Verdict': 4,
#  'Pfizer': 4,
#  'The Commerce Department': 4,
#  'Energy Fuels': 4,
#  'VCU': 4,
#  'Gartner': 4,
#  'HGV': 4,
#  'Eloy': 4,
#  'Hanbury': 4,
#  'The New Yorker': 4,
#  'Shell': 4,
#  'Veerapaneni': 4,
#  'Saks Fifth Avenue': 4,
#  "Moody's": 4,
#  'Citywire': 4,
#  'JPMorgan': 4,
#  'AFP': 4,
#  'Huawei': 4,
#  'US Treasury': 3,
#  'BoE': 3,
#  'MacRumors': 3,
#  'Chinese Academy': 3,
#  'UAE': 3,
#  'Intel Corp.': 3,
#  'Nissan Motor': 3,
#  'GamesRadar': 3,
#  'DoD': 3,
#  'Supreme Court': 3,
#  'TTC': 3,
#  'Associated Press': 3,
#  'US treasury': 3,
#  'LBC': 3,
#  'NYSE': 3,
#  'DISMISSES': 3,
#  'INTC': 3,
#  'USICA': 3,
#  'BloombergLeft-Wing Rage': 3,
#  'Diess': 3,
#  'Buick': 3,
#  'Home Depot': 3,
#  'Kung': 3,
#  'Fortune': 3,
#  'Fiat Chrysler': 3,
#  'Miller': 3,
#  'Google': 3,
#  'Supply Chain Dive': 3,
#  'Harvard': 3,
#  'General Motors Co.': 2,
#  'Toyota Motors': 2,
#  'PSA Group': 2,
#  'Nintendo Switch': 2,
#  'CMX Denim': 2,
#  'Xcode': 2,
#  'LMC Automotive': 2,
#  'pan-EU': 2,
#  'Null Pointer': 2,
#  'Future brands': 2,
#  'SSD': 2,
#  'JetBlue': 2,
#  'Nissan Motor Co.': 2,
#  'Tesla Motors': 2,
#  'CBS Interactive Inc.': 2,
#  'Teslarati': 2,
#  'FCC': 2,
#  'Milkshakes': 2,
#  'AEB': 2,
#  'Miami |': 2,
#  'Nedap Nedap': 2,
#  'Coca-Cola': 2,
#  'SMIC': 2,
#  'PCGamesN': 2,
#  'Great Supply Chain Partners': 2,
#  'Ease Europe’s': 2,
#  'Verge': 2,
#  'Jeep': 2,
#  'the Digital Markets Act': 2,
#  'NFT': 2,
#  'IKEA': 2,
#  'Vlad Novakovski': 2,
#  'Intraday Data': 2,
#  'Save & file': 2,
#  'Ultra Cruise VW': 2,
#  'Nissan Motor Co.,': 2,
#  'OEM': 2,
#  'LXRX': 2,
#  "the Bank of England's": 2,
#  'WhatsApp': 2,
#  'Toyota Motor Corp.': 2,
#  'ADIZ': 2,
#  'FRANKFURT': 2,
#  'Nvidia Corp.': 2,
#  'Lexus': 2,
#  'Meeker': 2,
#  'Guardian': 2,
#  'BeeHero': 2,
#  'VGC': 2,
#  'Kenyatta': 2,
#  'Fox': 2,
#  'U.S. Supreme Court': 2,
#  'American Express Good': 2,
#  'SoftBank': 2,
#  'Royal Dutch Shell': 2,
#  'Mitsubishi': 2,
#  'Merkel Dismisses Russian Role': 2,
#  'Wells Fargo': 2,
#  'Macs May': 2,
#  'Channel 4': 2,
#  'SCC': 2,
#  'Camber Energy': 2,
#  'Italy GM': 2,
#  'The Associated Press': 2,
#  'CDC': 2,
#  'LatAm': 2,
#  'AMD RX': 2,
#  "Pandora Papers '": 2,
#  'Hynix': 2,
#  'the European Court': 2,
#  'Ford Motor Co.': 2,
#  'NYSEMKT': 2,
#  'Merck': 2,
#  'Ajinomoto': 2,
#  'CIVAC': 2,
#  'OCIO': 2,
#  'Greggs': 2,
#  'the Volkswagen Group': 2,
#  'Mojix': 2,
#  'Kellogg': 2,
#  'Subaru': 2,
#  'Btu': 2,
#  'Bain &': 2,
#  'Women’s Hospital': 2,
#  'Asbo': 2,
#  'Biden-Pelosi Overreach': 2,
#  'Dodge': 2,
#  'AMIA': 2,
#  'Satya Veerapaneni': 2,
#  'Bain & Co.': 2,
#  'Boeing': 2,
#  'PCB': 2,
#  'Future US Inc': 2,
#  'ZDNet': 2,
#  'Mellanox Technologies': 1,
#  'ET Intel Corp.': 1,
#  'IHS MARKIT - OCTOBER 2021': 1,
#  'the General Assembly': 1,
#  'Ultrasound Companies Seek Priority': 1,
#  'Toshiba': 1,
#  'GKN': 1,
#  'Apple Arcade': 1,
#  'GT Advanced Technologies': 1,
#  'GOP': 1,
#  'Nan Ya Printed Circuit Board Corp.': 1,
#  'Campbell Soup': 1,
#  'PFE': 1,
#  'Alexa': 1,
#  'The Home Office': 1,
#  'ResMed': 1,
#  'DigitalEurope': 1,
#  'Punit PARANJPE': 1,
#  'IHS MARKIT Automotive Research and Analysis Analysis': 1,
#  'Getty Images CHENG TING-FANG': 1,
#  'the Park Slope Food Co-op': 1,
#  'RIN 0694-XC084': 1,
#  'USPS Press': 1,
#  'Mazda': 1,
#  'Culture Committee': 1,
#  'Oki Engineering': 1,
#  'Hanbury of Bain': 1,
#  'IHS Markit Prospecting': 1,
#  'LLP Brexit': 1,
#  'UK Manufacturing': 1,
#  'Buncefield Oil Depot': 1,
#  'Danske Bank': 1,
#  'Daring Buyer': 1,
#  'Premium Carmakers': 1,
#  'the U.S. Department of Commerce': 1,
#  'Apple Inc. Companies': 1,
#  'AT&T Bell Laboratories': 1,
#  'TurboTax': 1,
#  'TSMC data': 1,
#  '802.11az Empower': 1,
#  'Global Purchasing and Supply Chain': 1,
#  'Wolfspeed Inc.': 1,
#  'FSD Beta': 1,
#  'JPMorgan Chase & Co.': 1,
#  'Equiti Capital': 1,
#  'USPS Slowdown': 1,
#  'Democratic Progressive Party': 1,
#  'EyeSight': 1,
#  'Ajinomoto Co.': 1,
#  'Print  ': 1,
#  'FAQ': 1,
#  'Citigroup Inc.': 1,
#  'HMRC': 1,
#  'Alberto Alerigi Junior': 1,
#  'SPD': 1,
#  'Broadcom Corp.': 1,
#  'Zach Daniel': 1,
#  'NBN': 1,
#  'Acura': 1,
#  'Download Trefis Data': 1,
#  'AJ Bell': 1,
#  'Howell': 1,
#  'Part VII Surveillance': 1,
#  'Porsche': 1,
#  'USPS View': 1,
#  'British Airways': 1,
#  'Spring Rock Green': 1,
#  'Nvidia NVDA': 1,
#  'The Department for Transport': 1,
#  'SUMCO': 1,
#  'INEGI': 1,
#  'CMS': 1,
#  'Attisani/FT Share': 1,
#  'ITV': 1,
#  'COBOL': 1,
#  'Bloomberg / Getty Images': 1,
#  'Arianespace': 1,
#  'UK Insurance': 1,
#  'BOSS Magazine': 1,
#  'The Penny Hoarder Issues “Urgent': 1,
#  'JJE North America': 1,
#  'Ibiden Co.': 1,
#  '14 Cores & Alder Lake-M': 1,
#  'Motorola': 1,
#  "Volkswagen Group's": 1,
#  'Rabobank': 1,
#  'the US EPA': 1,
#  'Hacker leaks Twitch': 1,
#  'Elkem ASA': 1,
#  '台積電': 1,
#  'Oak Furnitureland': 1,
#  'A16': 1,
#  'Medical Center Hospital': 1,
#  "The Democratic Party's": 1,
#  'Sexy': 1,
#  'Point47:26Oct 6, 2021': 1,
#  'Ford Motor F -1.1%': 1,
#  'CMA': 1,
#  'a UK Company': 1,
#  'Smash Bros.’': 1,
#  'Ocotillo Fab': 1,
#  'Ultraviolet Audio Video': 1,
#  'FOUP': 1,
#  'Terran Orbital': 1,
#  'VW Group': 1,
#  'Chair of the Supply Chain Management Analytics Department': 1,
#  'the US Department of Interior': 1,
#  "Democracy New York's": 1,
#  'FOREX': 1,
#  'Warner Media Company': 1,
#  'Ryanair': 1,
#  'Reuss says Looking': 1,
#  'the European Central Bank': 1,
#  'Denso Corp.': 1,
#  'NXPI': 1,
#  'Electropages Media Ltd': 1,
#  'the Wolfspeed Assurance of Supply Program': 1,
#  'Gavekal Research': 1,
#  'Sainsbury': 1,
#  'Essex': 1,
#  'Qualcomm Inc.': 1,
#  'The EU Digital Services': 1,
#  'LETI/CEA': 1,
#  '@WillyShih_atHBS': 1,
#  'JSR': 1,
#  'Lloyds': 1,
#  'Getty Images/Image Source': 1,
#  'Futurum Research': 1,
#  'The New YorkerBuy Covers': 1,
#  'Ford Motor Company': 1,
#  'DJI Opco': 1,
#  'Normative': 1,
#  'BMW AG': 1,
#  'TPM': 1,
#  'the Subscriber Agreement & Terms of Use': 1,
#  'Gavekal Global Macro Research': 1,
#  'BBC Radio 4’s': 1,
#  'Camber Energy Inc.': 1,
#  'Alphabet': 1,
#  'ICE Data Services': 1,
#  'Copyright 2018': 1,
#  'the High Court': 1,
#  'Societe Generale': 1,
#  'Gavekal Gavekal': 1,
#  'Slack': 1,
#  'Avis Budget Group Inc.': 1,
#  'Boris brands': 1,
#  'Barcroft Media/Getty': 1,
#  'N Glebe Road Suite 210': 1,
#  'Powerball': 1,
#  'The US Commerce Department': 1,
#  'AMC Entertainment Holdings Inc.': 1,
#  'Ford Motor Co.’s': 1,
#  'Sami Fathi Apple': 1,
#  'Vaccine Tracker &': 1,
#  'Woodford': 1,
#  'RED VENTURES': 1,
#  'the Federal eRulemaking Portal': 1,
#  'Canberra': 1,
#  'Telegraph': 1,
#  'GMC Sierra': 1,
#  'Michigan Senate': 1,
#  'eBay': 1,
#  'Moody’s': 1,
#  'Sakurai': 1,
#  'Optus': 1,
#  'FTC': 1,
#  'TIMOTHY A. CLARY/AFP': 1,
#  'Apple MacBook': 1,
#  'Siemens': 1,
#  'IHS Markit INFO': 1,
#  'Alejandro de la Garza/New York': 1,
#  'Email GM': 1,
#  'Mercedes-Benz': 1,
#  'BMG': 1,
#  'Intel Foundry Services': 1,
#  'Gavekal Asia': 1,
#  'Nike': 1,
#  'EIA': 1,
#  'NAACP': 1,
#  'the Success of Brands High Quits Rates,': 1,
#  'The US treasury': 1,
#  'DLC': 1,
#  'FAA': 1,
#  'British Apples and Pears': 1,
#  'Get Supply Chain Dive': 1,
#  'Tesla Inc.': 1,
#  'Intel INTC': 1,
#  'NHS': 1,
#  'General Motors GM': 1,
#  'Media Ltd.': 1,
#  "General Motors Co's": 1,
#  'GrabFood': 1,
#  'UWB': 1,
#  'Tsinghua Unigroup': 1,
#  'Cree Inc.': 1,
#  'EPM': 1,
#  'LMS Automotive': 1,
#  'LAM Research': 1,
#  'Apollo': 1,
#  "BBC Radio 4's": 1,
#  'JD Sports': 1,
#  'YOSHIFUMI UESAKA': 1,
#  'LG Chem': 1,
#  'Alberto Alerigi Cars': 1,
#  'Chicago Mercantile Exchange Inc.': 1,
#  'Fiat Chrysler Automobiles NV': 1,
#  '7:15AM IDC': 1,
#  'the US Federal Reserve': 1,
#  'Wearable Sensors': 1,
#  'The Sierra Club': 1,
#  'GlobalData': 1,
#  'Lunchclub': 1,
#  'Howdy': 1,
#  'President Capital Management Corp.': 1,
#  'Mitsubishi Motors North America': 1,
#  'BIG DATA/IOT/': 1}

# %%
with open('csvs/updated_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(sorted_freq_dict))

# %%
import itertools

thirty_sorted_freq_dict = dict(itertools.islice(sorted_freq_dict.items(), 30))

with open('csvs/updated_thirty_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(thirty_sorted_freq_dict))

# %%
thirty_sorted_freq_dict
# Out:
# {'REE': 270,
#  'TSMC': 147,
#  'MIT': 120,
#  'UBS': 111,
#  'NSO': 111,
#  'Intel': 86,
#  'Apple': 82,
#  'Reuters': 80,
#  'RAM': 75,
#  'NIO': 73,
#  'General Motors': 47,
#  'AMD': 43,
#  'FRI': 35,
#  'Ford': 31,
#  'Nvidia': 30,
#  'Commerce': 29,
#  'Fed': 28,
#  'Toyota': 27,
#  'Digital': 27,
#  'PRA': 25,
#  'GlobalFoundries': 24,
#  'Nissan': 23,
#  'Barra': 23,
#  'MSU': 22,
#  'Target': 22,
#  'BIS': 19,
#  'Samsung': 19,
#  'Audi': 18,
#  'GETTY': 18,
#  'RHA': 18}

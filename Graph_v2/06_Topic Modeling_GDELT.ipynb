# %%
import pandas as pd
import json
gdelt_news = pd.read_csv('csvs/gdelt_news_updated.csv', sep='\t')

# %%
gdelt_news[gdelt_news.isnull().any(axis=1)]
# Out:
#    News
# 59  NaN

# %%
gdelt_news.dropna(inplace=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
dtm = tfidf.fit_transform(gdelt_news['News'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=10,random_state=101)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=101)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV

search_params = {
  'n_components': [5, 10, 15, 20, 25],
  'learning_decay': [.5, .7]
}

model = LatentDirichletAllocation()

# Try all of the options
gridsearch = GridSearchCV(model, param_grid=search_params, n_jobs=-1, verbose=1)
gridsearch.fit(dtm)

# What did we find?
print("Best Model's Params: ", gridsearch.best_params_)
print("Best Log Likelihood Score: ", gridsearch.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -2896.018811810439

# %%
topic_lst = []
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
    topic_lst.append([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['se', 'peluang', 'ujian', 'menyebutkan', 'video', 'na', 'network', 'investasi', 'suzuki', 'cnn', 'seks', 'october', 'tekanan', 'agus', 'menperin']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['fsr', '게시글', 'года', 'дефицита', 'liga', '업데이트', 'чипов', 'что', 'за', 'из', '뉴스', '이벤트', '케이벤치', 'amd', 'на']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['footsteps', 'rival', 'bring', 'نيكاي', 'شراء', 'day', 'list', 'insights', 'following', 'upside', 'house', 'daily', 'google', 'advisor', 'stock']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['780g', 'syarikat', 'taiwan', 'bekalan', 'networking', 'malaysia', 'فى', 'peranti', 'kilang', 'wi', 'fi', 'snapdragon', 'cip', 'stocks', 'korsel']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['إلكترونية', 'ونقلت', 'الأزمة', 'رقائق', 'نتيجة', 'عام', 'العالمي', 'التأمين', 'الدراسة', 'الدفع', 'و6', 'يتراوح', 'بما', 'ارتفاع', 'تقرير']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['industry', 'chip', 'companies', 'uy', 'manufacturing', 'demand', 'en', 'said', 'production', 'la', 'new', 'semiconductor', 'shortage', 'supply', 'chips']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['kelangkaan', 'mobil', 'dengan', 'semikonduktor', 'pada', 'indonesia', 'akan', 'industri', '2021', 'ini', 'untuk', 'dan', 'yang', 'chip', 'di']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['عن', 'العالم', 'أكبر', 'الإنتاج', 'صناعة', 'تويوتا', 'أن', 'إلى', 'نقص', 'بسبب', 'على', 'الرقائق', 'السيارات', 'من', 'في']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['berikut', 'banjar', 'berhadiah', 'rizky', 'billar', 'bali', 'lesti', 'kejora', 'site', 'reset', 'checking', 'connection', 'reached', 'firewall', 'proxy']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['să', 'substandard', 'jenesis', 'pe', 'care', 'la', 'se', 'şi', 'din', 'jeep', 'cu', 'die', 'pentru', 'на', 'în']

# %%
with open('csvs/gdelt_topics.json','w+', encoding='utf-8') as f:
    f.writelines(json.dumps(topic_lst))

# %%
topic_results = LDA.transform(dtm)

# %%
gdelt_news['Topic'] = topic_results.argmax(axis=1)

# %%
gdelt_news.to_csv('csvs/gdelt_news_with_topic.csv', sep='\t', index=False)

# %%
gdelt_news
# Out:
#                                                  News  Topic
# 0   Menperin Targetkan RI Produksi Chip untuk Mobi...      6
# 1   Kekurangan Pasokan Chip PS5 Bakal Diprediksi h...      6
# 2   Na těchto webových stránkách se používají soub...      9
# 3   REPUBLIKA.ID REPUBLIKA TV GERAI IHRAM REPJABAR...      6
# 4   ANTARANEWS.COM TERKINI TOP NEWS TERPOPULER Thu...      6
# ..                                                ...    ...
# 68  Krisis Chip, Produksi Suzuki India Anjlok Sept...      6
# 69  ANTARANEWS.COM TERKINI TOP NEWS TERPOPULER Thu...      6
# 70  miércoles, octubre 6, 2021 Canal de televisión...      5
# 71  AKTUÁLNĚ: Koronavirus Situace v Afghánistánu D...      0
# 72  English | 로그인 ㅣ ID/비번 찾기 ㅣ 회원가입/이메일 재인증 PC 부품 ...      1
#
# [72 rows x 2 columns]

# %%
# ================== Company Info GDELT =====================

# %%
all_news = list(gdelt_news['News'])

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(all_news[10])
[(X.text, X.label_) for X in doc.ents]
# Out:
# [('Thursday', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('October 2021', 'DATE'),
#  ('Oto Tek', 'PERSON'),
#  ('2023', 'DATE'),
#  ('12', 'CARDINAL'),
#  ('Penurunan', 'GPE'),
#  ('ilustrasi mobil listrik menggunakan chip', 'ORG'),
#  ('Penurunan', 'GPE'),
#  ('JAKARTA', 'ORG'),
#  ('Kelangkaan dan kurangnya', 'PERSON'),
#  ('produk mobil', 'ORG'),
#  ('secara global', 'PERSON'),
#  ('2023', 'DATE'),
#  ('dari berbagai pihak', 'PERSON'),
#  ('mobil', 'ORG'),
#  ('Jerman Mercedez-Benz yang', 'PERSON'),
#  ('kuartal ketiga', 'ORG'),
#  ('2021 mengalami', 'QUANTITY'),
#  ('dan penjualan secara signifikan karena', 'PERSON'),
#  ('menyebutkan kondisi', 'ORG'),
#  ('akan', 'NORP'),
#  ('terus', 'PRODUCT'),
#  ('2022', 'CARDINAL'),
#  ('dan kemudian', 'PERSON'),
#  ('Artinya kelangkaan bisa', 'PERSON'),
#  ('2023', 'DATE'),
#  ('Mercedes-Benz Kallenius seperti', 'ORG'),
#  ('BBC', 'ORG'),
#  ('12/9', 'CARDINAL'),
#  ('5', 'CARDINAL'),
#  ('Makanan Kaya', 'PERSON'),
#  ('Turunkan Berat', 'PERSON'),
#  ('Isolasi Covid Saat PON XX', 'PERSON'),
#  ('Papua Masjid Sunshine', 'PERSON'),
#  ('Rona Utsmaniyah', 'PERSON'),
#  ('Negeri Kanguru Ia', 'PERSON'),
#  ('secara global', 'PERSON'),
#  ('kelangkaan pasokan chip tidak sampai', 'PERSON'),
#  ('industri lainnya', 'PERSON'),
#  ('penurunan dari berbagai', 'PERSON'),
#  ('seperti yang tengah', 'PERSON'),
#  ('Mercedes-Benz', 'ORG'),
#  ('Kallenius menyebutkan', 'PERSON'),
#  ('merupakan', 'NORP'),
#  ('tekanan dan', 'PERSON'),
#  ('mengibaratkannya', 'GPE'),
#  ('sebagai sebuah kemacetan', 'PERSON'),
#  ('bagi industri otomotif', 'PERSON'),
#  ('yang', 'PERSON'),
#  ('Kita', 'PERSON'),
#  ('ke depan', 'ORG'),
#  ('pihak yang terlibat', 'PERSON'),
#  ('kuat lagi', 'PERSON'),
#  ('Kallenius', 'PERSON'),
#  ('menjadi', 'GPE'),
#  ('tekanan tidak', 'PERSON'),
#  ('hanya', 'GPE'),
#  ('industri yang mengandalkan chip', 'PERSON'),
#  ('untuk memenuhi kebutuhan sehari-hari', 'PERSON'),
#  ('yang kini tak bisa', 'PERSON'),
#  ('lepas dari', 'PERSON'),
#  ('Analis', 'GPE'),
#  ('Koray Kose', 'PERSON'),
#  ('Tekanan lainnya yang kini tengah', 'PERSON'),
#  ('Disusul juga', 'PERSON'),
#  ('denganlarangan Amerika Serikat kepada', 'PERSON'),
#  ('Huawei', 'WORK_OF_ART'),
#  ('Hal', 'PERSON'),
#  ('China', 'GPE'),
#  ('Ketika', 'PERSON'),
#  ('dan pemesanan', 'PERSON'),
#  ('muka oleh beberapa perusahaan', 'ORG'),
#  ('berjuang untuk', 'PERSON'),
#  ('mendapatkan komponen', 'PERSON'),
#  ('Masyarakat secara global yang', 'PERSON'),
#  ('dari rumah', 'PERSON'),
#  ('membutuhkan laptop', 'PERSON'),
#  ('dan webcam', 'ORG'),
#  ('melakukan pekerjaan', 'NORP'),
#  ('dan pabrik-pabrik', 'PERSON'),
#  ('Hal itu menyebabkan tak sedikit', 'PERSON'),
#  ('meski pada', 'PERSON'),
#  ('akhirnya', 'GPE'),
#  ('ini selalu mampu', 'PERSON'),
#  ('memenuhi permintaan pada akhirnya', 'PERSON'),
#  ('Kabar', 'GPE'),
#  ('akan', 'NORP'),
#  ('2023', 'CARDINAL'),
#  ('dibenarkan', 'NORP'),
#  ('komputer.\\Baik Kepala', 'PERSON'),
#  ('Intel', 'ORG'),
#  ('IBM', 'ORG'),
#  ('Serial Sejarah', 'PERSON'),
#  ('Islam', 'ORG'),
#  ('Islam Digest', 'ORG'),
#  ('Klik di Sini', 'PERSON'),
#  ('Baru', 'PERSON'),
#  ('Dikirim ke Pemesan', 'PERSON'),
#  ('2023', 'DATE'),
#  ('Kelangkaan Chip Diperkirakan Berlanjut', 'PERSON'),
#  ('Mercedes Benz', 'ORG'),
#  ('Indonesia', 'GPE'),
#  ('Mulai Terdampak Kelangkaan Chip Kelangkaan Chip Mulai Pengaruhi Industri Sepeda Motor',
#   'ORG'),
#  ('Gebby Amankan', 'LOC'),
#  ('Putri', 'NORP'),
#  ('Timnya Ketika', 'PERSON'),
#  ('Hadapi Papua', 'PERSON'),
#  ('Martil Jawa', 'PERSON'),
#  ('Atlet Positif Covid-19', 'PERSON'),
#  ('Menpora Ingatkan Prokes PON XX', 'ORG'),
#  ('Jokowi', 'NORP'),
#  ('Penetapan Komcad', 'ORG'),
#  ('Siswa Komponen Cadangan', 'PERSON'),
#  ('Utang Pemerintah Meningkat', 'PERSON'),
#  ('Keuangan', 'PERSON'),
#  ('Interaksi Peradaban', 'PERSON'),
#  ('Islam', 'ORG'),
#  ('China', 'GPE'),
#  ('Guratan Seni', 'PERSON'),
#  ('Islam', 'ORG'),
#  ('China', 'GPE'),
#  ('Warga Sabar', 'ORG'),
#  ('Perpanjangan PPKM Dengan', 'ORG'),
#  ('masyarakat berkontribusi', 'PERSON'),
#  ('Digerebek Suami', 'PERSON'),
#  ('Pasangan ASN', 'PERSON'),
#  ('Lampung Jadi', 'PERSON'),
#  ('Pasangan', 'PERSON'),
#  ('ASN', 'PRODUCT'),
#  ('DPRD', 'ORG'),
#  ('indekos Anggi', 'PERSON'),
#  ('Papua Ternyata', 'GPE'),
#  ('Katarak Bisa Anda', 'ORG'),
#  ('Ini Tidak', 'PERSON'),
#  ('memuaskan seorang wanita', 'PERSON'),
#  ('Anda harus', 'PERSON'),
#  ('masuk ke sini', 'PERSON'),
#  ('AeroMobil', 'ORG'),
#  ('Siap Luncurkan Kembali', 'PERSON'),
#  ('akan', 'NORP'),
#  ('Rilis Mobil', 'PERSON'),
#  ('James Bond', 'PERSON'),
#  ('Hanya', 'GPE'),
#  ('300', 'PRODUCT'),
#  ('Mercedes Benz', 'ORG'),
#  ('Indonesia', 'GPE'),
#  ('Kelangkaan Chip Tak Perlu Laser', 'PERSON'),
#  ('Mata Mulai Kabur', 'PERSON'),
#  ('Ternyata Cukup', 'PERSON'),
#  ('Ini Anda', 'PERSON'),
#  ('Agar', 'PERSON'),
#  ('120/80', 'GPE'),
#  ('darah bersih', 'PERSON'),
#  ('Kontes Modifikasi Motor', 'ORG'),
#  ('Medan Trik Berkendara Nyaman', 'PERSON'),
#  ('Mobil Listrik', 'ORG'),
#  ('Rolex yang', 'PERSON'),
#  ('Diskon', 'GPE'),
#  ('90%', 'PERCENT'),
#  ('jam tangan', 'PERSON'),
#  ('Lelaki Jakarta', 'PERSON'),
#  ('Hitungan', 'PERSON'),
#  ('James Bond Apresiasi', 'PERSON'),
#  ('BRI Bagi', 'PERSON'),
#  ('Kembalikan Uang', 'PERSON'),
#  ('Atas ATM Kamis', 'WORK_OF_ART'),
#  ('07 Oct 2021', 'DATE'),
#  ('01:00', 'TIME'),
#  ('Kesetaraan Demond Tutu', 'PERSON'),
#  ('2', 'CARDINAL'),
#  ('Disidang', 'GPE'),
#  ('18', 'CARDINAL'),
#  ('CIA', 'ORG'),
#  ('Negeri Seorang', 'PERSON'),
#  ('Minta', 'GPE'),
#  ('06 Oct 2021', 'DATE'),
#  ('15:41 WIB', 'TIME'),
#  ('Penetapan', 'DATE'),
#  ('Pemilu 2024 Satgas Ingatkan', 'PERSON'),
#  ('Nabi Jl', 'PERSON'),
#  ('Warung Buncit Raya', 'FAC'),
#  ('37', 'CARDINAL'),
#  ('Jakarta', 'GPE'),
#  ('12510', 'DATE'),
#  ('308', 'CARDINAL'),
#  ('021', 'CARDINAL'),
#  ('021', 'CARDINAL'),
#  ('US', 'GPE')]

# %%
organization = []
for news in all_news:
    doc = nlp(news)
    organization.append([i.text for i in doc.ents if (i.label_ == 'ORG' and i.text != "LLC")])

# %%
flat_org = [item for sublist in organization for item in sublist]

# %%
flat_org_unq = list(set(flat_org))

# %%
keywords = [
    "house",
    "university",
    "report",
    "information",
    "communication",
    "time",
    "visa",
    "master",
    "social",
    "sale",
    "invest",
    "street",
    "network",
    "terminal",
    "linked",
    "facebook",
    "yahoo",
    'youtube',
    "daily",
    "week",
    "business",
    "trust",
    "foundation",
    ".com",
    "stud",
    "history",
    "school",
    "stock",
    "world",
    "cnn",
    "science",
    "england &",
    "fund",
    "wordpress",
    "trump",
    "electric",
    "twitter",
    "musk",
    "elon",
    "berkley",
    "usb",
    "l.",
    "modi",
    "postal"
    "app",
    "semiconductor",
    "Li",
    "ST",
    "on",
    "Lattice",
    "micro",
    "state",
    "ip",
    "ev",
    "ml",
    "next",
    "live",
    "led",
    "silicon",
    "covid",
    "news",
    "journal",
    "council",
    "SaaS",
    'Global',
    'car',
    'app',
    'Government',
    'VAT',
    'Air',
    'OPEN',
    'Group',
    'WSJ',
    'Shop',
    'cnbc',
    'bank',
    "air",
    "fact",
    "mobil"
]

# %%
filtered_flat_org_unq = []

for org in flat_org_unq:
    flag = True
    for k in keywords:
        if k.strip().lower() in org.strip().lower():
            flag = False
            break
    if flag:
        filtered_flat_org_unq.append(org)

# %%
filtered_flat_org_unq
# Out:
# ['skirtų plataus vartojimo prekių',
#  "Moody's Analytics",
#  'PWL',
#  'RPP Złoty',
#  'eBay',
#  'Niska',
#  'iOS',
#  'dan webcam',
#  'INTC',
#  'ČTK',
#  'ŞTIRI PE',
#  'serta',
#  'Hollywood Video',
#  'General Motors Co',
#  'CKD',
#  'Gunakan Layanan DriveThru Supaya Cepat',
#  'KOSPI',
#  'WIB Berikut',
#  'De',
#  'Die&quot',
#  'Digital',
#  'ستايل محطة',
#  'ECU',
#  'Video',
#  'FIT 55',
#  'САЩ General Motors',
#  'mengatakan bahwa',
#  'إلى يوم',
#  'HMC',
#  'E-Sport Football Sulut',
#  'OPINIA',
#  'Към',
#  'HP',
#  'Artificial Intelegence (AI',
#  'mengurangi disrupsi pada',
#  'segera memperoleh',
#  'Toyota Motor Corp',
#  'Ordinul',
#  'OLEH NAZRIN',
#  'aveau un impact asupra transmiterii',
#  'tetapi sektor',
#  'из всех американских',
#  'Saksikan Video di Bawah Ini',
#  'Impresi City Hatchback',
#  'nieco w czasie zagładę ludzkości',
#  'Menurut NY Magazine',
#  'Pfizer',
#  'fintech de soluţii complete de plată şi',
#  'Katarak Bisa Anda',
#  'Criza',
#  'حوالي',
#  'BMW M4',
#  'się',
#  'Polaków',
#  'Zymergen',
#  'Ada',
#  'dan perusahaan',
#  'Disney',
#  'FOTO',
#  'memperingatkan bahwa',
#  'Swedia',
#  'Sejak',
#  'Moody’s',
#  'Dikritik Para',
#  'Pasokan',
#  "Moody's",
#  'Par',
#  'FIFA',
#  'ČEZ',
#  'Problemen wie Toshiba',
#  'еще',
#  'JICT',
#  'Reuters',
#  'Satu Dokumen',
#  'مرة',
#  'Tapi',
#  'Merck',
#  'TM',
#  'ZEN',
#  'Pesawat PPKM',
#  'PRO W6600',
#  'Киев',
#  'Transfer Alami Pergeseran',
#  'Tesla',
#  'Tantang Galaxy Watch',
#  'INDY',
#  'Salah',
#  'GDPR',
#  'un',
#  'WSKT',
#  'např',
#  'dampak pada',
#  '© 2021',
#  'PMI Manufaktur RI Lampaui',
#  'Váš',
#  'Samsung Display Co',
#  'CBU',
#  'Benchmark Company',
#  'что',
#  'تدفع',
#  'Counter Quotes',
#  'UE może',
#  'opresc vaccinarea tinerilor cu',
#  "img src='http://advm.ahram.org.eg/www",
#  'ley para',
#  'AMD jego najnowszy flagowiec',
#  'Bayar Utang',
#  'Nouă',
#  'Modelnya',
#  'mii de lei celor cu',
#  'sementara pasokan',
#  'TSMC',
#  'HDMI',
#  'Baca',
#  'XPT',
#  'Гендиректор',
#  'نصف نسبة',
#  'dengan',
#  'Mental Health',
#  'Maruti Suzuki',
#  'w Ameryce Północnej',
#  'Pada',
#  'Coupe',
#  'Guvern cu',
#  'Huawei',
#  'kebijakan khusus',
#  'iki',
#  'ASII, EMTK & BBNI',
#  'Semua Negara Terkait Prokes',
#  'Nikola',
#  'Mercedes-Benz Kallenius seperti',
#  'prověříme',
#  'dengan gigih',
#  'ساعة سائق أول سيارة',
#  'طلب جديدة تراجع',
#  'AMD',
#  'Ford Motor',
#  'وهو ما',
#  'DREPTATE',
#  'IDM',
#  'setkání',
#  'muka oleh beberapa perusahaan',
#  'Vous pouvez',
#  'في مخزونات',
#  'dari perusahaan',
#  'MUNICH',
#  'Kamera Ciamik Hadir',
#  'Solusi Nissan',
#  'Us Editorial Ethics',
#  'NGK',
#  'في الخريف',
#  'serie de electrocasnice',
#  'PR',
#  'General Motors',
#  'kec',
#  'MacBooków',
#  'Home Umum Scania',
#  'Targetare',
#  'Shio Tersenyum Puas Zoya Amirin',
#  'Můžeme Vám',
#  'Dua Motor Raib Dicuri',
#  'BMW',
#  'el diseño',
#  'PSD',
#  'Xiaomi',
#  'Ford Motors',
#  'Начало / Автомобили / Новини Volkswagen',
#  'Baidu KUNLUN',
#  'WIB Windows',
#  'العام',
#  'harga pasar',
#  'Heroin PPKM',
#  'IBD',
#  'ما الأسباب',
#  'UMKM',
#  'عندما',
#  'Penjualan',
#  'Perpanjangan PPKM Dengan',
#  'Persen',
#  'недостиг',
#  'CPU EPYC',
#  'ANTARA/Toshiba',
#  'Pasar Apresiasi',
#  'Tesla Falls Tesla',
#  '베스트',
#  'Kamis',
#  'для',
#  'Dengan Harga Mercedes Benz C-Class',
#  'které mohou',
#  'KPK',
#  'NFT',
#  'Centrul de inovare',
#  'mengambil langkah',
#  'CAPTCHA',
#  'Продавачите',
#  'są w coraz',
#  'Parlamento',
#  'Scoţia',
#  'ANTARA',
#  'Qualcomm Inc',
#  'السيارات يجنون أرباحًا',
#  'S&P Futures',
#  'patrulează pe',
#  'The Commerce Department',
#  'Szef RE',
#  'paklausą',
#  'dependemos de Asia',
#  'kata Karyanto',
#  'Produksi Toyota',
#  'dovezeme',
#  'търсенето',
#  'تنسيق الدبلومات',
#  'Елена Илиева',
#  'Кентукки',
#  'german BMW AG',
#  'Home Umum Krisis',
#  'أفكار جديدة ومتنوعه',
#  'Saham Korsel',
#  'di pusat',
#  'karena pada saat itu ada',
#  'dengan mengatakan',
#  'akan kuasai pasar',
#  'Kia',
#  'EU',
#  'تبقيه مرتفعا',
#  'Producenci',
#  'iti',
#  'Kata Pengamat Pajak Debitur',
#  'berdampak pada',
#  '120/80 dan pembuluh darah',
#  'się po decyzji RPP ws',
#  'Ceny',
#  'BSH',
#  'Un',
#  'Karakter',
#  'kedua perusahaan',
#  'Källenius',
#  'KRL Masa Perpanjangan PPKM',
#  'IBD Digital',
#  'Lehman Brothers',
#  'قالت صحيفة',
#  'M.2',
#  'w nadchodzących',
#  'ajutorul unui',
#  'premieră pe',
#  'للسيارات',
#  'Samsung',
#  'Ford Motor Джим Фарли',
#  'Bain & Co.',
#  'reagovaly na Putinova slova Školáky',
#  'Suzuki Motor',
#  'dengan larangan pemerintah AS',
#  'la Hamburg',
#  'LG Chem',
#  'Technologies Inc.',
#  'fabryki w innych częściach',
#  'dan pusat data',
#  'Sementara',
#  '03:37:10',
#  'nic',
#  'Jeep Jeep',
#  'zdraví',
#  'servici sau serviciu',
#  'وتجلب جوانب',
#  'В компании добавили',
#  'ValueWalk',
#  'legătură cu',
#  'AFP',
#  'Hyundai',
#  'va',
#  'ZDnet',
#  'Juta Unit',
#  '| Redaksi | Pedoman Media',
#  'pasokannya',
#  'Fireworks',
#  'sejumah produk VW',
#  'ANTARA/HO',
#  'Bosch',
#  'Bloomberg Клиентите',
#  'Blackout w Chinach',
#  'Rotasi Antar Matra',
#  'رقائق مصنوعة',
#  'Taufiek',
#  'ke depan',
#  'Kejadian Terburuk Sejak 2008',
#  'MIT',
#  'حول',
#  'DPRD',
#  'Penjualan Volvo',
#  'La escasez de',
#  'آخر أخبارنا المحلية',
#  'Baru',
#  'Yardeni Research',
#  'мышью и нажмите Ctrl+Enter',
#  'Woman',
#  'pe pagina cu',
#  'Klaus',
#  'NYSE',
#  'ke pasar Eropa',
#  'LCD',
#  'Subaru',
#  'توك شو فيديو صور إنفوجراف',
#  'GMI Technology',
#  'memprediksi',
#  'PKB dla',
#  'Pesawat',
#  'Najmniejszy',
#  'Kalsel',
#  'Google',
#  'Samsung Galaxy Buds 2',
#  'AS',
#  'CM',
#  'aut',
#  'Moldavsko',
#  'orang beraktivitas di',
#  'NIK',
#  'Crucii Rosii Romane Primul',
#  'Mercedes',
#  'la cadena de valor',
#  'Patung Soeharto Museum',
#  'عدد',
#  'Wi-Fi',
#  'kata perusahaan itu',
#  'بين',
#  'ułatwienia związane z',
#  'Burger King',
#  'dengan kantor pusat VW',
#  'Android Authority',
#  'City Bakal',
#  'Nvidia',
#  'CELE',
#  'JernihBerkomentar',
#  'Общините',
#  'może mniejsze zyski',
#  'Bezrobocie w Hiszpanii',
#  'НАТО',
#  'والبنزين الأمريكية الأسبوع',
#  'Hewlett-Packard',
#  'Holendrzy',
#  'Dukung Ekspor Ikan',
#  'UE',
#  'CCTV',
#  'sako',
#  'BSI',
#  'США',
#  'Asan',
#  'Qualcomm',
#  'لماذا تعطلت تطبيقات فيسبوك',
#  'NATO',
#  'العالم',
#  'Mercedes-Benz AG',
#  'meningkatkan',
#  'upaya menjaga program vaksinasi',
#  'kolejne iteracje',
#  'Mitsubishi',
#  'Penetapan Komcad',
#  'Marvell',
#  'WIB Proses',
#  'السيارات الألمانية',
#  'Harvard',
#  'Vendor-ii',
#  'paklausos patenkina',
#  'PCR тестове',
#  'Northvolt',
#  'Hartford Hospital Promoted',
#  'JK',
#  'Bisericii',
#  'عام',
#  'AHM',
#  'NU',
#  'Polda',
#  'Renault SA',
#  'dan Volvo',
#  'PDKT',
#  'Volvo',
#  'pak',
#  'JAKARTA',
#  'BBC',
#  'Volkswagen',
#  'niż',
#  'KPR',
#  'terduga dengan',
#  'Klučinová',
#  'FBI',
#  'mengatakan pada',
#  'Warga Sabar',
#  'czy marka produkowana',
#  'Marvell Technology',
#  'které zveřejní informace',
#  'WIB',
#  'vyšetřování bývalé',
#  'عبد',
#  'mengembangkan',
#  'ANTARA/REUTERS/',
#  'Santa Fe',
#  'berdiskusi dengan mereka',
#  'Mei',
#  'Renault',
#  'FREE',
#  'Индексите',
#  'VWAGY',
#  'مليارات دولار',
#  'BYD (BYDDF',
#  'MKTX',
#  'el cerebro',
#  'Potrivit',
#  'Szef',
#  'Edge şi Cloud',
#  'Produksi Suzuki India',
#  'COPYRIGHT ©',
#  'Jeep Gladiator',
#  'Home Umum Hyundai',
#  'Founder of Jetcool',
#  'Syracuse',
#  'Penfield',
#  'التي تعمل',
#  'UMC',
#  'ومتابعات ملفات خاصة',
#  'تفوق',
#  'CFRA',
#  'producţia pe',
#  'producţia de',
#  'AP',
#  'الشهر المقبل',
#  'Parlemen Eropa di Brussels',
#  'Meet Mercedes Chat pada Kamis',
#  'kuartal ketiga',
#  'VLSI Research',
#  'Korsel 4 Oktober 2021',
#  'Ford',
#  'WPG',
#  'ТД',
#  'masalah',
#  'Islam',
#  'عالم',
#  'Начало / Технологии /',
#  'Czekaja',
#  'TSLA',
#  'Baidu',
#  'hilang selamanya & pankreas',
#  'Wechsel',
#  'zdraví Kancelář',
#  'الشهر المقبل وفقا',
#  'sementara itu',
#  'NĚMECKO AUTOMOTO',
#  'tetapi',
#  'AMD GPU',
#  'nadzieje',
#  'كما ستمدد شركة أودي',
#  'NXP',
#  'Usia',
#  'Toyoty',
#  'Murdaningsih Pasokan',
#  'Bývalá',
#  'Mercedes Benz',
#  'Berawal',
#  'perdagangan',
#  "Cathie Wood's",
#  'salah satu',
#  'Smart',
#  'Commerce',
#  'Menit Wapres Minta TNI-Polri',
#  'التي تخلق هيكلًا معدنيًا',
#  'Verge',
#  '10:00PM',
#  'Answer Technology',
#  'Jeep',
#  'Jaringan Pemberitaan',
#  'OTT',
#  'Nintendo Switch',
#  'dan perangkat telekomunikasi',
#  'doar',
#  '베스트 브랜드어워드',
#  'Dia mengingatkan',
#  'dzięki wirusowi planeta złapie drugi',
#  'Cabor Angkat Besi',
#  'PAPUA SIMPEG RRI LPP RRI',
#  'BEI Rayu Perusahaan',
#  'БФБ',
#  'dari',
#  'susţin',
#  '어워드',
#  'serta para',
#  'Avtur Campuran',
#  '미니6',
#  'Artificial Intelegence',
#  'Mit',
#  'مليون دولار لموظف سابق',
#  'JAKARTA - PT',
#  'novináři',
#  'România cu',
#  'използвани в центрове за данни',
#  'Velký',
#  'Magna',
#  'dotyczących prywatności',
#  'kelompok itu karena',
#  'MJF',
#  'Bantah',
#  'Toshiba',
#  'تقلص',
#  'dari depan ke belakang',
#  'Spółek Grupy INFOR PL',
#  'Mercedez-Benz',
#  'Copyright ©',
#  'mutasi baru',
#  'Wiceszef',
#  'Ereksi',
#  'grania w symulatory',
#  'Ltd Akzeptieren Cyber Security Challenge',
#  'partneři zpracováváme údaje',
#  'Kebijakan Pajak',
#  'NAND',
#  'JAKARTA - Perang',
#  'Polymetal',
#  '갤럭시 Z',
#  'Pahlawan',
#  'Nissan',
#  'ta sytuacja',
#  'Jakarta - Hyundai Motors',
#  'Tokopedia & Bukalapak Pesawat',
#  'la un',
#  'TOYOTA VOLKSWAGEN',
#  'ke',
#  'PS5',
#  'Божидарка Чобалигова',
#  'Mercedes-Benz',
#  'световната енергийна криза',
#  'إلى',
#  'Хардуер',
#  'Toyota',
#  'Napięta',
#  'السيارات',
#  'ekranu',
#  'General Motors Bangkrut',
#  'GM',
#  'la Teatrul Nottara Alegerile',
#  'Deficitul',
#  'Otwarto',
#  'Prima TV',
#  'Warga Uganda Bayar',
#  'Berbeda',
#  'EQB',
#  '성능으로는 1080Ti에 필적하는 성능에',
#  '40%من إنتاجها العالمي',
#  'Delta',
#  'EQE',
#  'WHATS NEW 06/10/2021',
#  'الياباني',
#  'terpakasa',
#  'Senin',
#  '&quot;Sun',
#  'Arkana SUV',
#  'كما',
#  'SK Hynix Inc dan LG Display Co Ltd',
#  'NXPI',
#  'seluruh dunia',
#  'Canada Trupurile',
#  'إن مخزونات',
#  'Entrepreneur Media',
#  'po nowym roku',
#  'Nelu Tătaru',
#  'INSERT_RANDOM_NUMBER_HERE',
#  'Outbrain UK Ltd',
#  'Intel',
#  'Tetapi',
#  'CIA',
#  'الجديدة',
#  'Anggap Wajar',
#  'Chyba',
#  'أكبر مصنع تابع لها',
#  'التي تم تسجيلها',
#  'producţia',
#  'meningkatkan kapasitas',
#  'Tetapi Usaha',
#  'Więcej',
#  'والعَلم',
#  'său',
#  'partneři',
#  'IBM',
#  'الخميس',
#  'PrimaTV te cucereşte cu PREMII PE CUVÂNT!']

# %%
temp_all_news = " ".join(all_news)

# %%
freq_dict = dict()
for org in filtered_flat_org_unq:
    if len(org) > 2:
        count = temp_all_news.lower().count(org.lower())
        freq_dict[org] = count

# %%
sorted_freq_dict = {k: v for k, v in sorted(freq_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_freq_dict
# Out:
# {'Ada': 319,
#  'NGK': 267,
#  'Par': 183,
#  'Pada': 160,
#  'aut': 145,
#  'dari': 125,
#  'dengan': 123,
#  'iti': 109,
#  'Pasokan': 102,
#  'NIK': 98,
#  'WIB': 98,
#  'CIA': 95,
#  'nic': 92,
#  'pak': 85,
#  'السيارات': 73,
#  'iki': 61,
#  'Toyota': 60,
#  'się': 54,
#  'Smart': 54,
#  'Baru': 53,
#  'Baca': 51,
#  'MIT': 50,
#  'Mit': 50,
#  'Video': 48,
#  'Samsung': 47,
#  'ANTARA': 46,
#  'Hyundai': 44,
#  'JAKARTA': 44,
#  'Penjualan': 43,
#  'ZEN': 40,
#  'Asan': 39,
#  'Mercedes': 38,
#  'Intel': 38,
#  'Ford': 37,
#  'إلى': 36,
#  'ECU': 35,
#  'Tesla': 35,
#  'عالم': 33,
#  'Salah': 30,
#  'Persen': 30,
#  'العالم': 29,
#  'iOS': 27,
#  'Kia': 26,
#  'Nissan': 26,
#  'Tapi': 25,
#  'BMW': 25,
#  'عام': 25,
#  'Kamis': 24,
#  'Mercedes-Benz': 23,
#  "Moody's": 18,
#  'Ceny': 18,
#  'Sementara': 18,
#  'CELE': 18,
#  'Volkswagen': 18,
#  'General Motors': 17,
#  'بين': 17,
#  'Islam': 17,
#  'Usia': 17,
#  'salah satu': 17,
#  'Sejak': 16,
#  'العام': 16,
#  'PS5': 16,
#  'Digital': 15,
#  'Reuters': 15,
#  'Google': 15,
#  'BSI': 15,
#  'AHM': 15,
#  'Jeep': 15,
#  'Toshiba': 15,
#  'FOTO': 14,
#  'AMD': 14,
#  'للسيارات': 14,
#  'Klaus': 14,
#  'что': 13,
#  'niż': 13,
#  'masalah': 13,
#  'الياباني': 13,
#  'IBD': 12,
#  'Qualcomm': 12,
#  'Mei': 12,
#  'COPYRIGHT ©': 12,
#  'OTT': 12,
#  'Copyright ©': 12,
#  '© 2021': 11,
#  'Wi-Fi': 11,
#  'meningkatkan': 11,
#  'tetapi': 11,
#  'Mercedes Benz': 11,
#  'Tetapi': 11,
#  'Więcej': 11,
#  'serta': 10,
#  'CKD': 10,
#  'TSMC': 10,
#  'Solusi Nissan': 10,
#  'Renault': 10,
#  'WHATS NEW 06/10/2021': 10,
#  'Senin': 10,
#  'dampak pada': 9,
#  'недостиг': 9,
#  'ke depan': 9,
#  "Moody's Analytics": 8,
#  'Niska': 8,
#  'Maruti Suzuki': 8,
#  'Xiaomi': 8,
#  'Producenci': 8,
#  'Källenius': 8,
#  'Volvo': 8,
#  'INSERT_RANDOM_NUMBER_HERE': 8,
#  'Към': 7,
#  'مرة': 7,
#  'Huawei': 7,
#  'Saham Korsel': 7,
#  'berdampak pada': 7,
#  'Pesawat': 7,
#  'عدد': 7,
#  'Nvidia': 7,
#  'Szef': 7,
#  'perdagangan': 7,
#  'الجديدة': 7,
#  'producţia': 7,
#  'Ordinul': 6,
#  'Pfizer': 6,
#  'Criza': 6,
#  'وهو ما': 6,
#  'IDM': 6,
#  'kec': 6,
#  'для': 6,
#  'KPK': 6,
#  'Technologies Inc.': 6,
#  'السيارات الألمانية': 6,
#  'Polda': 6,
#  'BBC': 6,
#  'FREE': 6,
#  'Jeep Gladiator': 6,
#  'kuartal ketiga': 6,
#  'Deficitul': 6,
#  'seluruh dunia': 6,
#  'Chyba': 6,
#  'ČTK': 5,
#  'Katarak Bisa Anda': 5,
#  'Swedia': 5,
#  'MUNICH': 5,
#  'Perpanjangan PPKM Dengan': 5,
#  'Marvell': 5,
#  'Warga Sabar': 5,
#  'Potrivit': 5,
#  'الشهر المقبل': 5,
#  'hilang selamanya & pankreas': 5,
#  'NXP': 5,
#  'تقلص': 5,
#  'الخميس': 5,
#  'dan webcam': 4,
#  'KOSPI': 4,
#  'mengatakan bahwa': 4,
#  'dan perusahaan': 4,
#  "img src='http://advm.ahram.org.eg/www": 4,
#  'Nikola': 4,
#  'muka oleh beberapa perusahaan': 4,
#  'PSD': 4,
#  'ما الأسباب': 4,
#  '120/80 dan pembuluh darah': 4,
#  'Lehman Brothers': 4,
#  'zdraví': 4,
#  'حول': 4,
#  'DPRD': 4,
#  'Общините': 4,
#  'Penetapan Komcad': 4,
#  'UMC': 4,
#  'Baidu': 4,
#  'Commerce': 4,
#  'Nintendo Switch': 4,
#  'Spółek Grupy INFOR PL': 4,
#  'Mercedez-Benz': 4,
#  'Ereksi': 4,
#  'Napięta': 4,
#  'Berbeda': 4,
#  'كما': 4,
#  'IBM': 4,
#  'إلى يوم': 3,
#  'Saksikan Video di Bawah Ini': 3,
#  'Impresi City Hatchback': 3,
#  'حوالي': 3,
#  'Zymergen': 3,
#  'ČEZ': 3,
#  'еще': 3,
#  'CBU': 3,
#  'Nouă': 3,
#  'Ford Motor': 3,
#  'UMKM': 3,
#  '베스트': 3,
#  'IBD Digital': 3,
#  'Juta Unit': 3,
#  '| Redaksi | Pedoman Media': 3,
#  'pasokannya': 3,
#  'Patung Soeharto Museum': 3,
#  'kata perusahaan itu': 3,
#  'sako': 3,
#  'KPR': 3,
#  'mengatakan pada': 3,
#  'mengembangkan': 3,
#  'ANTARA/REUTERS/': 3,
#  'Penfield': 3,
#  'sementara itu': 3,
#  'كما ستمدد شركة أودي': 3,
#  'Verge': 3,
#  'dan perangkat telekomunikasi': 3,
#  'doar': 3,
#  '어워드': 3,
#  'Artificial Intelegence': 3,
#  'ta sytuacja': 3,
#  'Delta': 3,
#  'أكبر مصنع تابع لها': 3,
#  'RPP Złoty': 2,
#  'eBay': 2,
#  'General Motors Co': 2,
#  'ستايل محطة': 2,
#  'FIT 55': 2,
#  'OPINIA': 2,
#  'nieco w czasie zagładę ludzkości': 2,
#  'Polaków': 2,
#  'Disney': 2,
#  'Dikritik Para': 2,
#  'JICT': 2,
#  'Merck': 2,
#  'INDY': 2,
#  'GDPR': 2,
#  'تدفع': 2,
#  'mii de lei celor cu': 2,
#  'w Ameryce Północnej': 2,
#  'Mercedes-Benz Kallenius seperti': 2,
#  'dengan gigih': 2,
#  'Vous pouvez': 2,
#  'Kamera Ciamik Hadir': 2,
#  'el diseño': 2,
#  'WIB Windows': 2,
#  'NFT': 2,
#  'CAPTCHA': 2,
#  'Продавачите': 2,
#  'są w coraz': 2,
#  'Szef RE': 2,
#  'paklausą': 2,
#  'търсенето': 2,
#  'أفكار جديدة ومتنوعه': 2,
#  'akan kuasai pasar': 2,
#  'się po decyzji RPP ws': 2,
#  'kedua perusahaan': 2,
#  'M.2': 2,
#  'dengan larangan pemerintah AS': 2,
#  'la Hamburg': 2,
#  'fabryki w innych częściach': 2,
#  'ValueWalk': 2,
#  'ZDnet': 2,
#  'Bosch': 2,
#  'Blackout w Chinach': 2,
#  'Taufiek': 2,
#  'Woman': 2,
#  'pe pagina cu': 2,
#  'Subaru': 2,
#  'توك شو فيديو صور إنفوجراف': 2,
#  'GMI Technology': 2,
#  'memprediksi': 2,
#  'PKB dla': 2,
#  'ułatwienia związane z': 2,
#  'może mniejsze zyski': 2,
#  'Bezrobocie w Hiszpanii': 2,
#  'Holendrzy': 2,
#  'لماذا تعطلت تطبيقات فيسبوك': 2,
#  'NATO': 2,
#  'Mercedes-Benz AG': 2,
#  'Harvard': 2,
#  'Vendor-ii': 2,
#  'PCR тестове': 2,
#  'Klučinová': 2,
#  'czy marka produkowana': 2,
#  'عبد': 2,
#  'berdiskusi dengan mereka': 2,
#  'Индексите': 2,
#  'Produksi Suzuki India': 2,
#  'Founder of Jetcool': 2,
#  'Syracuse': 2,
#  'التي تعمل': 2,
#  'ومتابعات ملفات خاصة': 2,
#  'CFRA': 2,
#  'Czekaja': 2,
#  'nadzieje': 2,
#  'Toyoty': 2,
#  'Bývalá': 2,
#  'dzięki wirusowi planeta złapie drugi': 2,
#  'БФБ': 2,
#  'susţin': 2,
#  'مليون دولار لموظف سابق': 2,
#  'dotyczących prywatności': 2,
#  'dari depan ke belakang': 2,
#  'Wiceszef': 2,
#  'TOYOTA VOLKSWAGEN': 2,
#  'световната енергийна криза': 2,
#  'Хардуер': 2,
#  'General Motors Bangkrut': 2,
#  'Otwarto': 2,
#  'Prima TV': 2,
#  'EQE': 2,
#  'Entrepreneur Media': 2,
#  'po nowym roku': 2,
#  'Outbrain UK Ltd': 2,
#  'meningkatkan kapasitas': 2,
#  'والعَلم': 2,
#  'său': 2,
#  'partneři': 2,
#  'skirtų plataus vartojimo prekių': 1,
#  'PWL': 1,
#  'INTC': 1,
#  'ŞTIRI PE': 1,
#  'Hollywood Video': 1,
#  'Gunakan Layanan DriveThru Supaya Cepat': 1,
#  'WIB Berikut': 1,
#  'Die&quot': 1,
#  'САЩ General Motors': 1,
#  'HMC': 1,
#  'E-Sport Football Sulut': 1,
#  'Artificial Intelegence (AI': 1,
#  'mengurangi disrupsi pada': 1,
#  'segera memperoleh': 1,
#  'Toyota Motor Corp': 1,
#  'OLEH NAZRIN': 1,
#  'aveau un impact asupra transmiterii': 1,
#  'tetapi sektor': 1,
#  'из всех американских': 1,
#  'Menurut NY Magazine': 1,
#  'fintech de soluţii complete de plată şi': 1,
#  'BMW M4': 1,
#  'memperingatkan bahwa': 1,
#  'Moody’s': 1,
#  'FIFA': 1,
#  'Problemen wie Toshiba': 1,
#  'Satu Dokumen': 1,
#  'Pesawat PPKM': 1,
#  'PRO W6600': 1,
#  'Киев': 1,
#  'Transfer Alami Pergeseran': 1,
#  'Tantang Galaxy Watch': 1,
#  'WSKT': 1,
#  'např': 1,
#  'PMI Manufaktur RI Lampaui': 1,
#  'Váš': 1,
#  'Samsung Display Co': 1,
#  'Benchmark Company': 1,
#  'Counter Quotes': 1,
#  'UE może': 1,
#  'opresc vaccinarea tinerilor cu': 1,
#  'ley para': 1,
#  'AMD jego najnowszy flagowiec': 1,
#  'Bayar Utang': 1,
#  'Modelnya': 1,
#  'sementara pasokan': 1,
#  'HDMI': 1,
#  'XPT': 1,
#  'Гендиректор': 1,
#  'نصف نسبة': 1,
#  'Mental Health': 1,
#  'Coupe': 1,
#  'Guvern cu': 1,
#  'kebijakan khusus': 1,
#  'ASII, EMTK & BBNI': 1,
#  'Semua Negara Terkait Prokes': 1,
#  'prověříme': 1,
#  'ساعة سائق أول سيارة': 1,
#  'طلب جديدة تراجع': 1,
#  'DREPTATE': 1,
#  'setkání': 1,
#  'في مخزونات': 1,
#  'dari perusahaan': 1,
#  'Us Editorial Ethics': 1,
#  'في الخريف': 1,
#  'serie de electrocasnice': 1,
#  'MacBooków': 1,
#  'Home Umum Scania': 1,
#  'Targetare': 1,
#  'Shio Tersenyum Puas Zoya Amirin': 1,
#  'Můžeme Vám': 1,
#  'Dua Motor Raib Dicuri': 1,
#  'Ford Motors': 1,
#  'Начало / Автомобили / Новини Volkswagen': 1,
#  'Baidu KUNLUN': 1,
#  'harga pasar': 1,
#  'Heroin PPKM': 1,
#  'عندما': 1,
#  'CPU EPYC': 1,
#  'ANTARA/Toshiba': 1,
#  'Pasar Apresiasi': 1,
#  'Tesla Falls Tesla': 1,
#  'Dengan Harga Mercedes Benz C-Class': 1,
#  'které mohou': 1,
#  'Centrul de inovare': 1,
#  'mengambil langkah': 1,
#  'Parlamento': 1,
#  'Scoţia': 1,
#  'Qualcomm Inc': 1,
#  'السيارات يجنون أرباحًا': 1,
#  'S&P Futures': 1,
#  'patrulează pe': 1,
#  'The Commerce Department': 1,
#  'dependemos de Asia': 1,
#  'kata Karyanto': 1,
#  'Produksi Toyota': 1,
#  'dovezeme': 1,
#  'تنسيق الدبلومات': 1,
#  'Елена Илиева': 1,
#  'Кентукки': 1,
#  'german BMW AG': 1,
#  'Home Umum Krisis': 1,
#  'di pusat': 1,
#  'karena pada saat itu ada': 1,
#  'dengan mengatakan': 1,
#  'تبقيه مرتفعا': 1,
#  'Kata Pengamat Pajak Debitur': 1,
#  'BSH': 1,
#  'Karakter': 1,
#  'KRL Masa Perpanjangan PPKM': 1,
#  'قالت صحيفة': 1,
#  'w nadchodzących': 1,
#  'ajutorul unui': 1,
#  'premieră pe': 1,
#  'Ford Motor Джим Фарли': 1,
#  'Bain & Co.': 1,
#  'reagovaly na Putinova slova Školáky': 1,
#  'Suzuki Motor': 1,
#  'LG Chem': 1,
#  'dan pusat data': 1,
#  '03:37:10': 1,
#  'Jeep Jeep': 1,
#  'servici sau serviciu': 1,
#  'وتجلب جوانب': 1,
#  'В компании добавили': 1,
#  'legătură cu': 1,
#  'AFP': 1,
#  'Fireworks': 1,
#  'sejumah produk VW': 1,
#  'ANTARA/HO': 1,
#  'Bloomberg Клиентите': 1,
#  'Rotasi Antar Matra': 1,
#  'رقائق مصنوعة': 1,
#  'Kejadian Terburuk Sejak 2008': 1,
#  'Penjualan Volvo': 1,
#  'La escasez de': 1,
#  'آخر أخبارنا المحلية': 1,
#  'Yardeni Research': 1,
#  'мышью и нажмите Ctrl+Enter': 1,
#  'NYSE': 1,
#  'ke pasar Eropa': 1,
#  'LCD': 1,
#  'Najmniejszy': 1,
#  'Kalsel': 1,
#  'Samsung Galaxy Buds 2': 1,
#  'Moldavsko': 1,
#  'orang beraktivitas di': 1,
#  'Crucii Rosii Romane Primul': 1,
#  'la cadena de valor': 1,
#  'Burger King': 1,
#  'dengan kantor pusat VW': 1,
#  'Android Authority': 1,
#  'City Bakal': 1,
#  'JernihBerkomentar': 1,
#  'НАТО': 1,
#  'والبنزين الأمريكية الأسبوع': 1,
#  'Hewlett-Packard': 1,
#  'Dukung Ekspor Ikan': 1,
#  'CCTV': 1,
#  'США': 1,
#  'upaya menjaga program vaksinasi': 1,
#  'kolejne iteracje': 1,
#  'Mitsubishi': 1,
#  'WIB Proses': 1,
#  'paklausos patenkina': 1,
#  'Northvolt': 1,
#  'Hartford Hospital Promoted': 1,
#  'Bisericii': 1,
#  'Renault SA': 1,
#  'dan Volvo': 1,
#  'PDKT': 1,
#  'terduga dengan': 1,
#  'FBI': 1,
#  'Marvell Technology': 1,
#  'které zveřejní informace': 1,
#  'vyšetřování bývalé': 1,
#  'Santa Fe': 1,
#  'VWAGY': 1,
#  'مليارات دولار': 1,
#  'BYD (BYDDF': 1,
#  'MKTX': 1,
#  'el cerebro': 1,
#  'Edge şi Cloud': 1,
#  'Home Umum Hyundai': 1,
#  'تفوق': 1,
#  'producţia pe': 1,
#  'producţia de': 1,
#  'Parlemen Eropa di Brussels': 1,
#  'Meet Mercedes Chat pada Kamis': 1,
#  'VLSI Research': 1,
#  'Korsel 4 Oktober 2021': 1,
#  'WPG': 1,
#  'Начало / Технологии /': 1,
#  'TSLA': 1,
#  'Wechsel': 1,
#  'zdraví Kancelář': 1,
#  'الشهر المقبل وفقا': 1,
#  'NĚMECKO AUTOMOTO': 1,
#  'AMD GPU': 1,
#  'Murdaningsih Pasokan': 1,
#  'Berawal': 1,
#  "Cathie Wood's": 1,
#  'Menit Wapres Minta TNI-Polri': 1,
#  'التي تخلق هيكلًا معدنيًا': 1,
#  '10:00PM': 1,
#  'Answer Technology': 1,
#  'Jaringan Pemberitaan': 1,
#  '베스트 브랜드어워드': 1,
#  'Dia mengingatkan': 1,
#  'Cabor Angkat Besi': 1,
#  'PAPUA SIMPEG RRI LPP RRI': 1,
#  'BEI Rayu Perusahaan': 1,
#  'serta para': 1,
#  'Avtur Campuran': 1,
#  '미니6': 1,
#  'JAKARTA - PT': 1,
#  'novináři': 1,
#  'România cu': 1,
#  'използвани в центрове за данни': 1,
#  'Velký': 1,
#  'Magna': 1,
#  'kelompok itu karena': 1,
#  'MJF': 1,
#  'Bantah': 1,
#  'mutasi baru': 1,
#  'grania w symulatory': 1,
#  'Ltd Akzeptieren Cyber Security Challenge': 1,
#  'partneři zpracováváme údaje': 1,
#  'Kebijakan Pajak': 1,
#  'NAND': 1,
#  'JAKARTA - Perang': 1,
#  'Polymetal': 1,
#  '갤럭시 Z': 1,
#  'Pahlawan': 1,
#  'Jakarta - Hyundai Motors': 1,
#  'Tokopedia & Bukalapak Pesawat': 1,
#  'la un': 1,
#  'Божидарка Чобалигова': 1,
#  'ekranu': 1,
#  'la Teatrul Nottara Alegerile': 1,
#  'Warga Uganda Bayar': 1,
#  'EQB': 1,
#  '성능으로는 1080Ti에 필적하는 성능에': 1,
#  '40%من إنتاجها العالمي': 1,
#  'terpakasa': 1,
#  '&quot;Sun': 1,
#  'Arkana SUV': 1,
#  'SK Hynix Inc dan LG Display Co Ltd': 1,
#  'NXPI': 1,
#  'Canada Trupurile': 1,
#  'إن مخزونات': 1,
#  'Nelu Tătaru': 1,
#  'Anggap Wajar': 1,
#  'التي تم تسجيلها': 1,
#  'Tetapi Usaha': 1,
#  'PrimaTV te cucereşte cu PREMII PE CUVÂNT!': 1}

# %%
with open('csvs/updated_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(sorted_freq_dict))

# %%
import itertools

thirty_sorted_freq_dict = dict(itertools.islice(sorted_freq_dict.items(), 30))

with open('csvs/updated_thirty_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(thirty_sorted_freq_dict))

# %%
thirty_sorted_freq_dict
# Out:
# {'Ada': 319,
#  'NGK': 267,
#  'Pada': 160,
#  'aut': 145,
#  'dari': 125,
#  'dengan': 123,
#  'iti': 109,
#  'Pasokan': 102,
#  'NIK': 98,
#  'WIB': 98,
#  'CIA': 95,
#  'nic': 92,
#  'pak': 85,
#  'السيارات': 73,
#  'iki': 61,
#  'Toyota': 60,
#  'się': 54,
#  'Smart': 54,
#  'Baru': 53,
#  'Baca': 51,
#  'MIT': 50,
#  'Video': 48,
#  'Samsung': 47,
#  'ANTARA': 46,
#  'Hyundai': 44,
#  'JAKARTA': 44,
#  'Penjualan': 43,
#  'ZEN': 40,
#  'Asan': 39,
#  'Mercedes': 38}

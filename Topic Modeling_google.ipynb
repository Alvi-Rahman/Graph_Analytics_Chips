# %%
import pandas as pd

# %%
google_news = pd.read_csv('csvs/google_news_updated.csv', sep='\t')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
dtm = tfidf.fit_transform(google_news['News'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=10,random_state=101)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=101)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV

search_params = {
  'n_components': [5, 10, 15, 20, 25],
  'learning_decay': [.5, .7]
}

model = LatentDirichletAllocation()

# Try all of the options
gridsearch = GridSearchCV(model, param_grid=search_params, n_jobs=-1, verbose=1)
gridsearch.fit(dtm)

# What did we find?
print("Best Model's Params: ", gridsearch.best_params_)
print("Best Log Likelihood Score: ", gridsearch.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -3039.524846940912

# %%
lda_model = gridsearch.best_estimator_

# %%
single_topic = lda_model.components_[0]
top_word_indices = single_topic.argsort()[-10:]
for index in top_word_indices:
    print(tfidf.get_feature_names()[index])
# Out:
# companies
# 2021
# new
# said
# chips
# supply
# stocks
# industry
# chip
# semiconductor
# E:\Graph_Analytics\graphEnv\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
topic_lst = []
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
    
    topic_lst.append([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['market', 'manufacturing', 'semiconductors', 'year', 'stock', 'companies', '2021', 'new', 'said', 'chips', 'supply', 'stocks', 'industry', 'chip', 'semiconductor']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['indices', 'ads', 'opinion', 'span', 'hydrogen', 'usa', 'water', 'standard', 'splitting', 'carbon', 'purdue', 'dow', 'li', 'jones', 'milwaukee']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['inhibits', 'sens', 'crapo', 'mosi2n4', 'siltron', 'ang', 'contacts', 'boi', 'chest', 'window', 'makris', 'dallas', 'ut', '2d', 'michigan']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['lamps', 'victoria', 'cascade', 'commercialization', 'tillmann', 'deductions', 'code', 'lighting', 'casfet', 'steven', 'woo', 'santo', 'kubis', 'osram', 'purdue']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['footprint', 'ideas', 'senesky', 'son', 'carbon', 'clean', 'climate', 'fab', 'lewis', 'performer', 'wong', 'softbank', 'liu', 'theme', 'stanford']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['expandable', 'computers', '1941', 'bcg', 'google', 'menu', 'indicates', 'chromebook', 'nikkei', 'news', 'pixel', 'icon', 'network', 'listen', 'statesman']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['german', 'cookie', 'id', 'browser', 'javascript', 'loading', 'pine', 'bassett', 'clay', 'euractiv', 'midland', 'ghosh', 'hsc', 'gm', 'plant']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['parties', 'metrics', 'qualcomm', 'packaged', 'cookies', 'chipmakers', 'volkswagen', 'telecoms', 'magnachip', 'toyota', 'ic', 'transaction', 'insights', 'carmakers', 'cfius']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['ja', 'lev', 'burkacky', 'keefe', 'cruise', 'ars', 'unsolved', 'reacts', 'mysteries', 'fpga', 'fpgas', 'tuttle', 'lam', 'asu', 'lattice']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['cards', 'mbl', 'connection', 'fool', 'exascale', 'attackers', 'steal', 'messages', 'passwords', 'lowyinstitute', 'ramp', 'motley', 'mit', 'quad', 'quantum']

# %%
import json

# %%
with open('csvs/google_topics.json','w+', encoding='utf-8') as f:
    f.writelines(json.dumps(topic_lst))

# %%
topic_results = LDA.transform(dtm)

# %%
topic_results.shape
# Out:
# (70, 10)

# %%
google_news['Topic'] = topic_results.argmax(axis=1)

# %%
google_news
# Out:
#                                                  News  \
# 0   TOP BUSINESS NEWS (15 VIDEOS) GlobalFoundries ...
# 1   Tom's Hardware is supported by its audience. W...
# 2   Sign up as a reader Academic rigour, journalis...
# 3    Analyst Remains Bullish On Micron And These 2...
# 4   New semiconductor device possibilities using b...
# ..                                                ...
# 65  Skip to main content The computer chip industr...
# 66    Ford CEO on F-150 Lightning: ‘we want to lea...
# 67  Guidance for the Brookings community and the p...
# 68  OCTOBER 2, 2021 | MORE EVIDENCE THAT VITAMIN D...
# 69                   Listen to Statesman News Network
#
#                                                Titles  Topic
# 0   GlobalFoundries CEO on demand for semiconducto...      1
# 1   China's Mandated Power Cuts Hit Local Semicond...      0
# 2   Europe is running out of semiconductors – here...      0
# 3   Analyst Remains Bullish On Micron And These 2 ...      0
# 4   New semiconductor device possibilities using b...      0
# ..                                                ...    ...
# 65  The computer chip industry has a dirty climate...      0
# 66  Ford CEO: Semiconductor shortage is improving ...      0
# 67  Podcast: The view from industry on U.S. semico...      9
# 68  Newly Discovered Family of 2D Semiconductors E...      0
# 69  Austin's Cirrus Logic acquires Lion Semiconduc...      5
#
# [70 rows x 3 columns]

# %%
google_news.to_csv('csvs/google_news_with_topic.csv', index=False)

# %%
# ===================== COMPANY INFO ============================

# %%
all_news = list(google_news['News'])

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
import en_core_web_sm

# %%
nlp = en_core_web_sm.load()

# %%
doc = nlp(all_news[10])
[(X.text, X.label_) for X in doc.ents]
# Out:
# [('FDA', 'ORG'),
#  ('Facebook', 'ORG'),
#  ('CTO', 'PRODUCT'),
#  ('White House', 'ORG'),
#  ("Yahoo Finance's", 'ORG'),
#  ('Julie Hyman', 'PERSON'),
#  ('Thursday', 'DATE'),
#  ('White House', 'ORG'),
#  ('September 23', 'DATE'),
#  ('2021·2', 'DATE'),
#  ('WASHINGTON', 'GPE'),
#  ('Sept 23', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('The White House', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('Commerce', 'ORG'),
#  ('Gina Raimondo', 'PERSON'),
#  ('White House National Economic Council', 'ORG'),
#  ('Detroit', 'GPE'),
#  ('General Motors', 'ORG'),
#  ('Ford Motor', 'ORG'),
#  ('Stellantis', 'ORG'),
#  ('Apple', 'ORG'),
#  ('Daimler AG', 'ORG'),
#  ('GlobalFoundries', 'ORG'),
#  ('Micron', 'ORG'),
#  ('Microsoft', 'ORG'),
#  ('Samsung', 'ORG'),
#  ('TSMC', 'ORG'),
#  ('Intel Corp', 'ORG'),
#  ('Pat Gelsinger', 'PERSON'),
#  ('The White House', 'ORG'),
#  ('this week', 'DATE'),
#  ('45 days', 'DATE'),
#  ('Biden', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('Biden', 'PERSON'),
#  ('U.S.', 'GPE'),
#  ('Vietnam', 'GPE'),
#  ('Malaysia', 'GPE'),
#  ('Last month', 'DATE'),
#  ('Taiwan', 'GPE'),
#  ('U.S.', 'GPE'),
#  ('nearly 394.7', 'CARDINAL'),
#  ('$9.5 Billion', 'MONEY'),
#  ('Paris', 'GPE'),
#  ('3-Qatar', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('44%', 'PERCENT'),
#  ('Arvind Krishna', 'PERSON'),
#  ('IBM', 'ORG'),
#  ('April 2020', 'DATE'),
#  ('Merck', 'ORG'),
#  ('Anthony Harris', 'PERSON'),
#  ('WorkCare', 'ORG'),
#  ('A Bag', 'WORK_OF_ART'),
#  ('China', 'GPE'),
#  ('China', 'GPE'),
#  ('the United States', 'GPE'),
#  ('Chinese', 'NORP'),
#  ('a mile', 'QUANTITY'),
#  ('The Wall Street Journal Countdown Starts', 'ORG'),
#  ('Chinese', 'NORP'),
#  ('U.S.', 'GPE'),
#  ('three-year', 'DATE'),
#  ('Chinese', 'NORP'),
#  ('American', 'NORP'),
#  ('Washington', 'GPE'),
#  ('Beijing', 'GPE'),
#  ('Americans', 'NORP'),
#  ('Social Security', 'ORG'),
#  ('at least 35 years', 'DATE'),
#  ('age 70', 'DATE'),
#  ('Rich', 'PERSON'),
#  ('Melania Trump', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Melania Trump', 'PERSON'),
#  ('Donald Trump', 'PERSON'),
#  ('the White House', 'ORG'),
#  ('January', 'DATE'),
#  ('Ford', 'ORG'),
#  ('Sept. 23', 'DATE'),
#  ('Ford Motors Company', 'ORG'),
#  ('NYSE', 'ORG'),
#  ('June 4', 'DATE'),
#  ('16.45', 'MONEY'),
#  ('Ford', 'ORG'),
#  ('11%', 'PERCENT'),
#  ('the four trading days', 'DATE'),
#  ('14.73', 'MONEY'),
#  ('Ford', 'ORG'),
#  ('GM', 'ORG'),
#  ('Ford', 'ORG'),
#  ('Ford', 'ORG'),
#  ('Donald Trump', 'PERSON'),
#  ('Pfizer', 'ORG'),
#  ('Donald Trump', 'PERSON'),
#  ("Yahoo Finance's", 'ORG'),
#  ('Adam Shapiro', 'PERSON'),
#  ('first', 'ORDINAL'),
#  ('Pfizer-Biontech', 'ORG'),
#  ('ARK', 'ORG'),
#  ('Cathie Wood', 'PERSON'),
#  ('the mid 1800s', 'DATE'),
#  ('Citing U.S. Energy Information Administration', 'ORG'),
#  ('101 million barrels', 'QUANTITY'),
#  ('2019', 'DATE'),
#  ('92', 'CARDINAL'),
#  ('2020', 'DATE'),
#  ('97', 'CARDINAL'),
#  ('2021', 'DATE'),
#  ('EV', 'ORG'),
#  ('Pfizer', 'ORG'),
#  ('the U.S. Department of Health and Human Services', 'ORG'),
#  ('last year', 'DATE'),
#  ('Medicare', 'ORG'),
#  ('Pfizer', 'ORG'),
#  ('225,000', 'MONEY'),
#  ('Thursday', 'DATE'),
#  ('Mary Kay Vyskocil', 'PERSON'),
#  ('U.S. District Court', 'ORG'),
#  ('the Southern District', 'LOC'),
#  ('New York', 'GPE'),
#  ('Pfizer', 'GPE'),
#  ('Saudis Triumph', 'ORG'),
#  ('Bloomberg', 'PERSON'),
#  ('next week', 'DATE'),
#  ('Saudi Arabia', 'GPE'),
#  ('Anti-Biennial', 'NORP'),
#  ('Cimarex Energy, Marathon Oil', 'ORG'),
#  ('Royal Dutch Shell', 'ORG'),
#  ('JPMorgan', 'ORG'),
#  ('Texas Muni Work Becomes Latest', 'ORG'),
#  ('Bloomberg', 'PERSON'),
#  ('U.S.', 'GPE'),
#  ('Texas', 'GPE'),
#  ('BloombergWall Street Titans Warn', 'ORG'),
#  ('Be Natural Gas Price Forecast –', 'ORG'),
#  ('6.00', 'MONEY'),
#  ('Friday', 'DATE'),
#  ('6.00', 'MONEY'),
#  ('The Wall Street Journal', 'ORG'),
#  ('Social Security', 'ORG'),
#  ('China', 'GPE'),
#  ('Coal Miners Told to Produce Even If They’re Over Quotas', 'ORG'),
#  ('Bloomberg', 'PERSON'),
#  ('China', 'GPE'),
#  ('the year', 'DATE'),
#  ('annual', 'DATE'),
#  ('BloombergWall Street Titans Warn', 'ORG'),
#  ('WCPO', 'ORG'),
#  ('Merck', 'ORG'),
#  ('50%', 'PERCENT'),
#  ('Merck Covid Drug Rocks Moderna', 'ORG')]

# %%
organization = []
for news in all_news:
    doc = nlp(news)
    organization.append([i.text for i in doc.ents if (i.label_ == 'ORG' and i.text != "LLC")])

# %%
flat_org = [item for sublist in organization for item in sublist]

# %%
flat_org_unq = list(set(flat_org))

# %%
keywords = [
    "house",
    "university",
    "report",
    "information",
    "communication",
    "time",
    "visa",
    "master",
    "social",
    "sale",
    "invest",
    "street",
    "network",
    "terminal",
    "linked",
    "facebook",
    "yahoo",
    'youtube',
    "daily",
    "week",
    "business",
    "trust",
    "foundation",
    ".com",
    "stud",
    "history",
    "school",
    "stock",
    "world",
    "cnn",
    "science",
    "england &",
    "fund",
    "wordpress",
    "trump",
    "electric",
    "twitter",
    "musk",
    "elon",
    "berkley",
    "usb",
    "l.",
    "modi",
    "postal"
    "app",
    "semiconductor",
    "Li",
    "ST",
    "on",
    "Lattice",
    "micro",
    "state",
    "ip",
    "ev",
    "ml",
    "next",
    "live",
    "led",
    "silicon",
    "covid",
    "news",
    "journal",
    "automobile",
    "car",
    "council"
]

# %%
filtered_flat_org_unq = []

for org in flat_org_unq:
    flag = True
    for k in keywords:
        if k.strip().lower() in org.strip().lower():
            flag = False
            break
    if flag:
        filtered_flat_org_unq.append(org)

# %%
temp_all_news = " ".join(all_news)

# %%
freq_dict = dict()
for org in filtered_flat_org_unq:
    if len(org) > 2:
        count = temp_all_news.lower().count(org.lower())
        freq_dict[org] = count

# %%
freq_dict
# Out:
# {'FPGA': 79,
#  'KS ASEPTIC PROCESS ENGINEER - PFIZER - ROCKY MOUNT': 1,
#  'North Pole Express': 1,
#  'Qualcomm Europe': 1,
#  'Synopsys': 5,
#  'Ford': 66,
#  'WeWork, Uber, Grab, Compass, DoorDash': 1,
#  'MPW': 4,
#  'Nio, BYD Co.': 1,
#  'Plug Power': 2,
#  'MTW': 2,
#  'USICA': 1,
#  'Lülsdorf': 2,
#  'HPCwire': 4,
#  'Price Bank of America': 1,
#  'Agenda & PR ©': 1,
#  'Nikkei Asia': 3,
#  'Bain & Co.': 1,
#  'the Intel Parallel Computing Center': 1,
#  'Unique': 11,
#  'Barney and Associates': 1,
#  'Si-N': 1,
#  'BMW': 3,
#  'Dimitra': 1,
#  'JPMorgan': 1,
#  'OECD': 1,
#  'How Modern Health': 1,
#  'Cerner': 2,
#  'the U.S. Patent and Trademark Office': 1,
#  'QLC': 1,
#  'Kubis': 11,
#  'ET Intel Corp.': 1,
#  'MOSFET': 4,
#  'Tridge': 2,
#  'IndieBio': 2,
#  'Removing Tax Barriers—': 1,
#  'RPI': 5,
#  'TAM': 17,
#  'IUCRC': 1,
#  'Digital Interfaces': 1,
#  'Inez Kerr Bell Professors': 1,
#  'DFT': 3,
#  'ETF Winners and Losers': 1,
#  'Ford Motor': 4,
#  'Pfizer Inc': 2,
#  'NAISE': 1,
#  'VLSI Technology': 1,
#  'Surge': 14,
#  'Movers': 2,
#  'Umicore AG & Co.': 1,
#  'SoftBank': 17,
#  'Dell, Nokia': 1,
#  'Unleashing the Potential of the Mind': 1,
#  'Realtor of the Year': 1,
#  'Digicel': 1,
#  'QMCPACK': 11,
#  'DesignWare': 2,
#  'SBG': 1,
#  'Detroit Smart Parking Lab': 2,
#  'the Associated Press': 1,
#  'Deal Flow': 1,
#  'NNSA TriLab': 1,
#  'General Motors': 7,
#  'eMemory Technology Incorporated': 1,
#  'OEM': 9,
#  'MEDC': 8,
#  'Waco': 1,
#  'Makris': 12,
#  'IndiaSamayam TamilSamayam TeluguMiss KyraBombay': 1,
#  'D-N.Y.': 2,
#  'ALB': 7,
#  'Ford Motor Co (F.N': 1,
#  'Center for Cybersecurity and Digital Forensics Building': 1,
#  'PSI': 7,
#  'Toyota': 11,
#  'BOI': 4,
#  'IDC': 5,
#  'EU Services': 1,
#  'American Express': 1,
#  'ASE Technology': 2,
#  "Wells Fargo's": 2,
#  'the Texas Analog Center of Excellence': 1,
#  'AB Ghosh': 1,
#  'SK Broadband': 4,
#  'Chargeway': 2,
#  'EMS': 92,
#  'Chromebooks': 2,
#  'AmbaniNirmala': 1,
#  'Reuters': 33,
#  'Telecoms': 7,
#  'Certus/Certus Pro': 1,
#  'globe': 4,
#  'Nvidia': 33,
#  'MIT D-Lab': 1,
#  'Mac': 74,
#  'Azeredo': 3,
#  'Samsung Bioepis': 1,
#  'RBC': 2,
#  'NSF Awards U': 1,
#  'LÜLSDORF': 2,
#  'Susquehanna Financial Group': 1,
#  'FLP': 5,
#  'LLC Associates Program': 1,
#  'CCP': 1,
#  'Arabinda ‘AB': 1,
#  'Coca-Cola': 1,
#  'Nio': 69,
#  'Quantum': 54,
#  'PrimeTalk': 1,
#  'MKL': 1,
#  'Quantum Computing’s Uptake': 1,
#  'FULL': 49,
#  'telco': 7,
#  'BCG/SIA': 5,
#  'Fujitsu': 2,
#  'Pittsburgh Supercomputer Powers Machine Learning Analysis': 1,
#  'Nike': 1,
#  'NSW': 19,
#  'big hyperscale data': 2,
#  'the European Initiative ‘Important': 1,
#  'the U.S. Department': 6,
#  'Merck': 23,
#  'ACES': 16,
#  'Motorola': 3,
#  'Pulse Veterinary Technologies': 2,
#  'The Group': 4,
#  'the Pros Workers': 1,
#  'Apple': 50,
#  'Insider': 9,
#  'Copyright 2018': 1,
#  'NFC': 1,
#  'Three Universities Team for NSF': 1,
#  'Cloud Security': 1,
#  'GETTY IMAGES Lam Research Corp.': 1,
#  'Robinhood': 5,
#  '2021,12:03pm EDT Building Technology': 2,
#  'BMY': 3,
#  'Clay': 7,
#  'Ways and Means Plan': 1,
#  'GPU': 11,
#  'Acteurs Européens': 1,
#  'GENERATORS': 1,
#  'INTC': 6,
#  "Phoenix Bashas'": 1,
#  'the U.S. Department of Energy': 4,
#  'Goldman Sachs': 3,
#  'LAM Research': 5,
#  'Royal Dutch Shell': 3,
#  'SMH': 8,
#  'the DOE Exascale Comupting Project': 1,
#  'DSP': 5,
#  'UMC': 3,
#  'McKinsey & Company': 1,
#  'the Katherine Ngai Pesic & Silvaco Research': 1,
#  'hyperscale data': 2,
#  'WWWG-AM': 1,
#  'AMD': 40,
#  'Toyota Motors': 2,
#  'Nissan': 1,
#  'GDDR': 4,
#  'HHS': 2,
#  'MSF': 4,
#  'Nikkei': 6,
#  'app': 334,
#  'C60': 1,
#  'D-Lab': 2,
#  'Wise Road Capital': 2,
#  'Hewlett-Packard': 1,
#  'Fiat Chrysler': 2,
#  'COO': 41,
#  'Powerball': 2,
#  'Kozicki': 5,
#  'Apple TV': 1,
#  'TLC': 1,
#  'HBM': 6,
#  'Cambridge Quantum': 1,
#  'CNBC': 2,
#  'AC-DC': 1,
#  'Lexus': 1,
#  'XDL': 1,
#  'GlobalFoundries': 5,
#  'IBM': 7,
#  'TLDR A15': 1,
#  'Bank of America': 4,
#  'The Motley Fool': 6,
#  'Derecho': 2,
#  'Delphi': 1,
#  'EurekAlert': 3,
#  'Undergrad Programs Earn Higher Marks': 1,
#  'Future brands': 1,
#  'Cathie Wood': 4,
#  'the Solar Power Laboratory': 1,
#  'Apollo': 1,
#  'Arm Technology China': 1,
#  'IMG': 1,
#  'Faraday Technology': 1,
#  'Schottky': 6,
#  'ASCAC': 1,
#  'Global Security Initiative': 2,
#  'DRAMS': 2,
#  'Intel Foundry Services': 3,
#  'Ars Technica': 3,
#  'GlobalWafers': 4,
#  'TE-MSC-SMT-2021-93-LD': 1,
#  'The TechCrunch Exchange': 1,
#  'NIO': 69,
#  'MagSafe': 2,
#  'CMA': 3,
#  'France Energy': 1,
#  'quantum dots': 3,
#  'MTA': 1,
#  'HPC User Forum': 1,
#  'ETF Channel': 1,
#  'NASA': 6,
#  'Deloitte': 2,
#  "U.S. Supreme Court's": 1,
#  'the U.S. Senate': 4,
#  'Mercedes': 1,
#  'ISM': 13,
#  'Kiyosaki': 4,
#  'the Tri-Lab CTS-2': 1,
#  'Aurora': 9,
#  'DIY': 2,
#  'Central Processing Unit': 2,
#  'ASU’s MacroTechnology Works': 1,
#  'Samsung Biologics': 2,
#  'AnandTech Interview': 1,
#  'NVIDIA': 33,
#  "the Center of America's": 1,
#  'Bay Future, Inc.': 2,
#  'Commerce': 17,
#  'Center for Nanotechnology': 1,
#  'MassMutual': 2,
#  'IEEE': 4,
#  'AMD SVP of Computing and Graphics': 1,
#  'Intel-HPE': 1,
#  'WTO': 1,
#  'SCOTUS': 2,
#  'Big Finance': 1,
#  'Arm': 85,
#  'High Performance': 2,
#  'Huawei': 5,
#  'the Ned Davis Research': 4,
#  'Ned Davis Research': 8,
#  'quantum mechanics': 1,
#  'AUM': 2,
#  'CSI': 2,
#  'BMS': 2,
#  'Xiaomi': 1,
#  'NASDAQ': 61,
#  'Javey': 7,
#  'NNSA': 3,
#  'FOUP': 1,
#  'MBA': 20,
#  'WiFi': 1,
#  'Digital & Media Digital Compass': 1,
#  'DividendChannel': 1,
#  'KETV - Omaha': 1,
#  'RED VENTURES': 1,
#  'The U.S. Senate': 4,
#  "SK Broadband's": 1,
#  'IEEE Spectrum': 1,
#  'Fed': 28,
#  'Samsung Group': 1,
#  'Avnet': 1,
#  'CXL': 8,
#  'EURACTIV European': 1,
#  'Bain & Company': 1,
#  'the American Society of Mechanical Engineers': 2,
#  'Goldman Sachs Group Inc.': 1,
#  'the People’s Bank of China': 1,
#  'Power Up': 4,
#  'AspenCore,': 1,
#  'the 6G Futures': 1,
#  'NDA': 121,
#  'Trade': 63,
#  'The Segment Producer': 1,
#  'Royal Dutch': 4,
#  'Nadia Schadlow': 2,
#  'MIT Welcome Center': 1,
#  'HEALTH, SAFETY & SECURITY': 1,
#  'Jabil': 1,
#  'FDA': 2,
#  'White Pine Commerce Park': 2,
#  'Rambus': 11,
#  'K. P Esler': 1,
#  'Forbes': 1,
#  'Pavneet Singh': 2,
#  'NXPI': 2,
#  'Rivian Automotive Inc.': 3,
#  'County Broadband': 1,
#  'Nokia': 2,
#  "Midland Co. Sheriff's Office": 1,
#  'Score Board': 1,
#  'Dell Technologies': 1,
#  'Frey': 7,
#  'TRW': 1,
#  'LRCX': 1,
#  'TSMC': 71,
#  'the Lafayette Park Neighborhood': 2,
#  'Intel': 150,
#  'Outperform to Market Perform': 1,
#  'Mental': 31,
#  '6G Technology': 1,
#  'Zacks ETF Rank #1': 1,
#  'UK Operators': 1,
#  'Telecom': 22,
#  'Digital Compass': 2,
#  'S&P': 18,
#  'DOI': 33,
#  'Anti-Drugs Agency': 2,
#  'Seagate Technology': 4,
#  'PLTR': 1,
#  'Federal Reserve': 4,
#  'Chicago Mercantile Exchange Inc.': 1,
#  'Bay Future,': 2,
#  'HPC': 16,
#  'Mentor Graphics': 1,
#  'Coins': 1,
#  'Google': 20,
#  'Department of Defense (DoD': 1,
#  'Centralab': 1,
#  'GENCI': 6,
#  'Nano Letters': 1,
#  'TANCO': 1,
#  'Future US Inc': 1,
#  'Shakers': 1,
#  'the VanEck': 1,
#  'Ning': 241,
#  'ColdQuanta': 1,
#  'CED': 175,
#  'Arm Holdings': 1,
#  'Ryzen': 6,
#  'Bengaluru': 1,
#  'Warner Media Company': 1,
#  'SMIC': 2,
#  'NXP': 12,
#  'Moderna Inc': 2,
#  'Arm Ltd': 1,
#  "M&A. The U.K.-based company's": 1,
#  'SoftBank Group Corp': 2,
#  'ALCF': 7,
#  'Exchange': 9,
#  'Ferrari': 1,
#  'the Google TPU': 1,
#  'Buenos Aires': 1,
#  'Lava': 1,
#  'Bertan Bakkaloglu': 1,
#  '6G Futures': 3,
#  'Siemens': 2,
#  'the Federal Reserve': 1,
#  'CTM': 1,
#  'SEC': 190,
#  'Daphne Leprince-Ringuet': 3,
#  'Tableau': 1,
#  'Axxia/Intel': 1,
#  'Pixel': 6,
#  'FTXL': 3,
#  'FREE': 28,
#  'ADI': 88,
#  'the Twinkie PD': 1,
#  'Shepherd': 1,
#  'XLNX': 2,
#  'Centennial Resource': 2,
#  'the US Government': 5,
#  'Internal Market': 2,
#  'SKPRES-WB': 1,
#  'WSJ': 8,
#  'Asia Pacific': 2,
#  'CMD': 1,
#  'Wells Fargo': 8,
#  'White Pine': 3,
#  'Shore Chan': 2,
#  'NVIDIA Corp (NASDAQ:': 1,
#  'XSD': 2,
#  'BAAP': 1,
#  'OCBC': 2,
#  'IC Insights': 8,
#  'Nasdaq,': 4,
#  'RAMP': 15,
#  'WCPO': 2,
#  'Qualcomm': 11,
#  'PSA': 3,
#  'Five9 Inc.': 1,
#  'Acorn Computers': 1,
#  'Uighurs': 1,
#  'Harvard': 5,
#  'Easier Than You Think Property': 1,
#  'MarketWatch': 10,
#  'PCB': 1,
#  'H&M': 1,
#  'AT&T': 6,
#  'The Commerce Department': 1,
#  'TechCrunch': 5,
#  'Hanbury': 5,
#  'FWIW': 1,
#  'NAM': 49,
#  'Bangladesh Work': 1,
#  '@JamesDSneed': 1,
#  'ComputerBase': 1,
#  'Design': 124,
#  'Ford Motors Company': 2,
#  'J. P Towsend': 1,
#  'Bacteria, Fungi': 1,
#  'Semtech': 2,
#  'Bosch': 3,
#  'ASU Thrive': 2,
#  "Moody's Analytics": 3,
#  'Phys': 41,
#  'Goal': 17,
#  'Bangladesh Jobs': 1,
#  'Treasury': 2,
#  'Pune': 2,
#  'Tesla Inc': 2,
#  'Warframe': 1,
#  'Pure Michigan': 1,
#  'Freddie Mac': 1,
#  'Mac-Imprint': 1,
#  'HPE': 2,
#  'ASE': 290,
#  'LDP': 1,
#  'Berkeley': 10,
#  'USPS': 1,
#  'CFIUS': 30,
#  'Saudis Triumph': 2,
#  'AT&T Inc.': 4,
#  'J.P. Morgan Asset Management': 5,
#  'Vitamin C': 2,
#  'Lam Research': 5,
#  'Ohmic': 4,
#  'automotive assembly': 1,
#  "Bezos' Rocket Company Blue Origin Allege Sexism, Safety Risks Senators Push": 1,
#  'the U.S. Department of Health and Human Services': 1,
#  'SPX': 1,
#  'ByteDance': 1,
#  'Umno': 1,
#  'Biden CFPB Pick Rohit': 2,
#  'Rewards': 1,
#  'Designer': 8,
#  'Pfizer': 16,
#  "The U.S. ISM 's": 1,
#  'General Motor': 8,
#  'D-Ore': 1,
#  'SABAH &': 1,
#  'Texas Advanced Computing Center Marks': 1,
#  'Samsung': 49,
#  'MovieRedbus': 1,
#  'MediaTek': 1,
#  'Dynamic Random-Access Memory': 1,
#  'U.S. Supreme Court': 2,
#  'CMOS': 2,
#  'ARK': 319,
#  'SK Group': 1,
#  'Fortune': 9,
#  'SIA': 65,
#  'NIO Inc.': 1,
#  'TTD': 3,
#  'ETF': 51,
#  'sci-tech': 2,
#  'SoundDesign': 1,
#  'Kintex': 1,
#  'DPA': 3,
#  'Apple MacBook': 1,
#  'AMD platforms': 1,
#  'the Zacks Equity Research': 1,
#  'NGL': 63,
#  'ESM': 3,
#  'DoD': 6,
#  'SPAC': 48,
#  'Anant Agarwal': 1,
#  'Intel Corp': 2,
#  'Committee': 13,
#  'Saks Fifth Avenue': 1,
#  'Rivian Details': 3,
#  'KLA': 8,
#  'quantum dynamics': 1,
#  'NYSE': 29,
#  'NAND': 6,
#  'EU Internal Market': 1,
#  'Fermi': 6,
#  'Wahab Alasfour': 1,
#  'Factories': 18,
#  'Arabinda “AB': 1,
#  'Macy': 3,
#  'F-35': 2,
#  'MediaLab': 1,
#  'Brookings': 2,
#  'WIDAD': 1,
#  'TOPGLOV': 1,
#  'Courtaulds': 1,
#  'The Detroit Smart Parking Lab': 1,
#  'Alejandro de la Garza/New York': 1,
#  'JCR': 1,
#  'Raley': 1,
#  'LGR': 1,
#  'Punit Goenka': 1,
#  "Moody'S Analytics": 3,
#  'Volkswagen': 6,
#  'CFPB': 3,
#  'Annie Saunders': 1,
#  'TAFI': 1,
#  'Meritage Group': 1,
#  'OCIDA': 1,
#  'Michigan Realtor': 2,
#  'CDC': 11,
#  'Fisker Inc.': 1,
#  'MRNA': 3,
#  'TKL': 1,
#  'DOE': 51,
#  'Delta': 7,
#  'Senate': 16,
#  'Citadel': 1,
#  'NYC': 3,
#  'the Exascale Computing Project': 1,
#  'the US Senate': 1,
#  'SCOPE': 5,
#  'Salak South': 1,
#  'Norman C Rasmussen': 1,
#  'Walmart': 1,
#  'HSC': 8,
#  'Canaccord Genuity': 1,
#  'Nitin Dahad': 8,
#  'Govt': 2,
#  'EUV': 1,
#  'Chargers': 1,
#  'Salvatori': 2,
#  'a UK Company': 2,
#  'PBS': 1,
#  'MIA': 13,
#  'NBA': 2,
#  'Lyell Immunopharma': 1,
#  'Invesco': 5,
#  'Tracy': 1,
#  'Indo-Pacific': 1,
#  'GOP': 3,
#  'Greenpeace': 1,
#  'EURACTIV': 9,
#  'Volkswagen Group': 1,
#  'QMC': 18,
#  'X86': 1,
#  'AT&T Bell Laboratories': 1,
#  'ULTRACOLD': 1,
#  'Brent': 1,
#  'GrowthIndia': 1,
#  'DJI Opco': 1,
#  'LF Energy': 2,
#  'LSI': 17,
#  'Apple Watch': 3,
#  'This Intel Core i7-11700K CPU': 1,
#  'General Motors Co': 1,
#  'MIT': 162,
#  'Solvay Special Chemicals': 1,
#  '@Laughing_Man @hnpn914': 1,
#  'ATP': 3}

# %%
sorted_freq_dict = {k: v for k, v in sorted(freq_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_freq_dict
# Out:
# {'ARK': 319,
#  'ASE': 290,
#  'Ning': 241,
#  'SEC': 190,
#  'CED': 175,
#  'MIT': 162,
#  'Intel': 150,
#  'NDA': 121,
#  'EMS': 92,
#  'ADI': 88,
#  'Arm': 85,
#  'FPGA': 79,
#  'Mac': 74,
#  'TSMC': 71,
#  'Nio': 69,
#  'Ford': 66,
#  'SIA': 65,
#  'NGL': 63,
#  'NASDAQ': 61,
#  'Quantum': 54,
#  'ETF': 51,
#  'DOE': 51,
#  'Apple': 50,
#  'FULL': 49,
#  'NAM': 49,
#  'Samsung': 49,
#  'SPAC': 48,
#  'COO': 41,
#  'Phys': 41,
#  'AMD': 40,
#  'Reuters': 33,
#  'Nvidia': 33,
#  'DOI': 33,
#  'Mental': 31,
#  'CFIUS': 30,
#  'NYSE': 29,
#  'Fed': 28,
#  'FREE': 28,
#  'Merck': 23,
#  'Telecom': 22,
#  'Google': 20,
#  'NSW': 19,
#  'S&P': 18,
#  'Factories': 18,
#  'QMC': 18,
#  'TAM': 17,
#  'SoftBank': 17,
#  'Commerce': 17,
#  'Goal': 17,
#  'LSI': 17,
#  'ACES': 16,
#  'HPC': 16,
#  'Pfizer': 16,
#  'Senate': 16,
#  'RAMP': 15,
#  'Surge': 14,
#  'ISM': 13,
#  'Committee': 13,
#  'MIA': 13,
#  'Makris': 12,
#  'NXP': 12,
#  'Unique': 11,
#  'Kubis': 11,
#  'QMCPACK': 11,
#  'Toyota': 11,
#  'GPU': 11,
#  'Rambus': 11,
#  'Qualcomm': 11,
#  'CDC': 11,
#  'MarketWatch': 10,
#  'Berkeley': 10,
#  'OEM': 9,
#  'Insider': 9,
#  'Aurora': 9,
#  'Exchange': 9,
#  'Fortune': 9,
#  'EURACTIV': 9,
#  'MEDC': 8,
#  'SMH': 8,
#  'Ned Davis Research': 8,
#  'CXL': 8,
#  'WSJ': 8,
#  'Wells Fargo': 8,
#  'IC Insights': 8,
#  'Designer': 8,
#  'General Motor': 8,
#  'KLA': 8,
#  'HSC': 8,
#  'Nitin Dahad': 8,
#  'General Motors': 7,
#  'ALB': 7,
#  'PSI': 7,
#  'Telecoms': 7,
#  'telco': 7,
#  'Clay': 7,
#  'IBM': 7,
#  'Javey': 7,
#  'Frey': 7,
#  'ALCF': 7,
#  'Delta': 7,
#  'the U.S. Department': 6,
#  'INTC': 6,
#  'Nikkei': 6,
#  'HBM': 6,
#  'The Motley Fool': 6,
#  'Schottky': 6,
#  'NASA': 6,
#  'GENCI': 6,
#  'Ryzen': 6,
#  'Pixel': 6,
#  'AT&T': 6,
#  'DoD': 6,
#  'NAND': 6,
#  'Fermi': 6,
#  'Volkswagen': 6,
#  'Synopsys': 5,
#  'RPI': 5,
#  'IDC': 5,
#  'FLP': 5,
#  'BCG/SIA': 5,
#  'Robinhood': 5,
#  'LAM Research': 5,
#  'DSP': 5,
#  'Kozicki': 5,
#  'GlobalFoundries': 5,
#  'Huawei': 5,
#  'the US Government': 5,
#  'Harvard': 5,
#  'TechCrunch': 5,
#  'Hanbury': 5,
#  'J.P. Morgan Asset Management': 5,
#  'Lam Research': 5,
#  'SCOPE': 5,
#  'Invesco': 5,
#  'MPW': 4,
#  'HPCwire': 4,
#  'MOSFET': 4,
#  'Ford Motor': 4,
#  'BOI': 4,
#  'SK Broadband': 4,
#  'globe': 4,
#  'The Group': 4,
#  'the U.S. Department of Energy': 4,
#  'GDDR': 4,
#  'MSF': 4,
#  'Bank of America': 4,
#  'Cathie Wood': 4,
#  'GlobalWafers': 4,
#  'the U.S. Senate': 4,
#  'Kiyosaki': 4,
#  'IEEE': 4,
#  'the Ned Davis Research': 4,
#  'The U.S. Senate': 4,
#  'Power Up': 4,
#  'Royal Dutch': 4,
#  'Seagate Technology': 4,
#  'Federal Reserve': 4,
#  'Nasdaq,': 4,
#  'AT&T Inc.': 4,
#  'Ohmic': 4,
#  'Nikkei Asia': 3,
#  'BMW': 3,
#  'DFT': 3,
#  'Azeredo': 3,
#  'Motorola': 3,
#  'BMY': 3,
#  'Goldman Sachs': 3,
#  'Royal Dutch Shell': 3,
#  'UMC': 3,
#  'EurekAlert': 3,
#  'Intel Foundry Services': 3,
#  'Ars Technica': 3,
#  'CMA': 3,
#  'quantum dots': 3,
#  'NNSA': 3,
#  'Rivian Automotive Inc.': 3,
#  '6G Futures': 3,
#  'Daphne Leprince-Ringuet': 3,
#  'FTXL': 3,
#  'White Pine': 3,
#  'PSA': 3,
#  'Bosch': 3,
#  "Moody's Analytics": 3,
#  'TTD': 3,
#  'DPA': 3,
#  'ESM': 3,
#  'Rivian Details': 3,
#  'Macy': 3,
#  "Moody'S Analytics": 3,
#  'CFPB': 3,
#  'MRNA': 3,
#  'NYC': 3,
#  'GOP': 3,
#  'Apple Watch': 3,
#  'ATP': 3,
#  'Plug Power': 2,
#  'MTW': 2,
#  'Lülsdorf': 2,
#  'Cerner': 2,
#  'Tridge': 2,
#  'IndieBio': 2,
#  'Pfizer Inc': 2,
#  'Movers': 2,
#  'DesignWare': 2,
#  'Detroit Smart Parking Lab': 2,
#  'D-N.Y.': 2,
#  'ASE Technology': 2,
#  "Wells Fargo's": 2,
#  'Chargeway': 2,
#  'Chromebooks': 2,
#  'RBC': 2,
#  'LÜLSDORF': 2,
#  'Fujitsu': 2,
#  'big hyperscale data': 2,
#  'Pulse Veterinary Technologies': 2,
#  '2021,12:03pm EDT Building Technology': 2,
#  'hyperscale data': 2,
#  'Toyota Motors': 2,
#  'HHS': 2,
#  'D-Lab': 2,
#  'Wise Road Capital': 2,
#  'Fiat Chrysler': 2,
#  'Powerball': 2,
#  'CNBC': 2,
#  'Derecho': 2,
#  'Global Security Initiative': 2,
#  'DRAMS': 2,
#  'MagSafe': 2,
#  'Deloitte': 2,
#  'DIY': 2,
#  'Central Processing Unit': 2,
#  'Samsung Biologics': 2,
#  'Bay Future, Inc.': 2,
#  'MassMutual': 2,
#  'SCOTUS': 2,
#  'High Performance': 2,
#  'AUM': 2,
#  'CSI': 2,
#  'BMS': 2,
#  'the American Society of Mechanical Engineers': 2,
#  'Nadia Schadlow': 2,
#  'FDA': 2,
#  'White Pine Commerce Park': 2,
#  'Pavneet Singh': 2,
#  'NXPI': 2,
#  'Nokia': 2,
#  'the Lafayette Park Neighborhood': 2,
#  'Digital Compass': 2,
#  'Anti-Drugs Agency': 2,
#  'Bay Future,': 2,
#  'SMIC': 2,
#  'Moderna Inc': 2,
#  'SoftBank Group Corp': 2,
#  'Siemens': 2,
#  'XLNX': 2,
#  'Centennial Resource': 2,
#  'Internal Market': 2,
#  'Asia Pacific': 2,
#  'Shore Chan': 2,
#  'XSD': 2,
#  'OCBC': 2,
#  'WCPO': 2,
#  'Ford Motors Company': 2,
#  'Semtech': 2,
#  'ASU Thrive': 2,
#  'Treasury': 2,
#  'Pune': 2,
#  'Tesla Inc': 2,
#  'HPE': 2,
#  'Saudis Triumph': 2,
#  'Vitamin C': 2,
#  'Biden CFPB Pick Rohit': 2,
#  'U.S. Supreme Court': 2,
#  'CMOS': 2,
#  'sci-tech': 2,
#  'Intel Corp': 2,
#  'F-35': 2,
#  'Brookings': 2,
#  'Michigan Realtor': 2,
#  'Govt': 2,
#  'Salvatori': 2,
#  'a UK Company': 2,
#  'NBA': 2,
#  'LF Energy': 2,
#  'KS ASEPTIC PROCESS ENGINEER - PFIZER - ROCKY MOUNT': 1,
#  'North Pole Express': 1,
#  'Qualcomm Europe': 1,
#  'WeWork, Uber, Grab, Compass, DoorDash': 1,
#  'Nio, BYD Co.': 1,
#  'USICA': 1,
#  'Price Bank of America': 1,
#  'Agenda & PR ©': 1,
#  'Bain & Co.': 1,
#  'the Intel Parallel Computing Center': 1,
#  'Barney and Associates': 1,
#  'Si-N': 1,
#  'Dimitra': 1,
#  'JPMorgan': 1,
#  'OECD': 1,
#  'How Modern Health': 1,
#  'the U.S. Patent and Trademark Office': 1,
#  'QLC': 1,
#  'ET Intel Corp.': 1,
#  'Removing Tax Barriers—': 1,
#  'IUCRC': 1,
#  'Digital Interfaces': 1,
#  'Inez Kerr Bell Professors': 1,
#  'ETF Winners and Losers': 1,
#  'NAISE': 1,
#  'VLSI Technology': 1,
#  'Umicore AG & Co.': 1,
#  'Dell, Nokia': 1,
#  'Unleashing the Potential of the Mind': 1,
#  'Realtor of the Year': 1,
#  'Digicel': 1,
#  'SBG': 1,
#  'the Associated Press': 1,
#  'Deal Flow': 1,
#  'NNSA TriLab': 1,
#  'eMemory Technology Incorporated': 1,
#  'Waco': 1,
#  'IndiaSamayam TamilSamayam TeluguMiss KyraBombay': 1,
#  'Ford Motor Co (F.N': 1,
#  'Center for Cybersecurity and Digital Forensics Building': 1,
#  'EU Services': 1,
#  'American Express': 1,
#  'the Texas Analog Center of Excellence': 1,
#  'AB Ghosh': 1,
#  'AmbaniNirmala': 1,
#  'Certus/Certus Pro': 1,
#  'MIT D-Lab': 1,
#  'Samsung Bioepis': 1,
#  'NSF Awards U': 1,
#  'Susquehanna Financial Group': 1,
#  'LLC Associates Program': 1,
#  'CCP': 1,
#  'Arabinda ‘AB': 1,
#  'Coca-Cola': 1,
#  'PrimeTalk': 1,
#  'MKL': 1,
#  'Quantum Computing’s Uptake': 1,
#  'Pittsburgh Supercomputer Powers Machine Learning Analysis': 1,
#  'Nike': 1,
#  'the European Initiative ‘Important': 1,
#  'the Pros Workers': 1,
#  'Copyright 2018': 1,
#  'NFC': 1,
#  'Three Universities Team for NSF': 1,
#  'Cloud Security': 1,
#  'GETTY IMAGES Lam Research Corp.': 1,
#  'Ways and Means Plan': 1,
#  'Acteurs Européens': 1,
#  'GENERATORS': 1,
#  "Phoenix Bashas'": 1,
#  'the DOE Exascale Comupting Project': 1,
#  'McKinsey & Company': 1,
#  'the Katherine Ngai Pesic & Silvaco Research': 1,
#  'WWWG-AM': 1,
#  'Nissan': 1,
#  'C60': 1,
#  'Hewlett-Packard': 1,
#  'Apple TV': 1,
#  'TLC': 1,
#  'Cambridge Quantum': 1,
#  'AC-DC': 1,
#  'Lexus': 1,
#  'XDL': 1,
#  'TLDR A15': 1,
#  'Delphi': 1,
#  'Undergrad Programs Earn Higher Marks': 1,
#  'Future brands': 1,
#  'the Solar Power Laboratory': 1,
#  'Apollo': 1,
#  'Arm Technology China': 1,
#  'IMG': 1,
#  'Faraday Technology': 1,
#  'ASCAC': 1,
#  'TE-MSC-SMT-2021-93-LD': 1,
#  'The TechCrunch Exchange': 1,
#  'France Energy': 1,
#  'MTA': 1,
#  'HPC User Forum': 1,
#  'ETF Channel': 1,
#  "U.S. Supreme Court's": 1,
#  'Mercedes': 1,
#  'the Tri-Lab CTS-2': 1,
#  'ASU’s MacroTechnology Works': 1,
#  'AnandTech Interview': 1,
#  "the Center of America's": 1,
#  'Center for Nanotechnology': 1,
#  'AMD SVP of Computing and Graphics': 1,
#  'Intel-HPE': 1,
#  'WTO': 1,
#  'Big Finance': 1,
#  'quantum mechanics': 1,
#  'Xiaomi': 1,
#  'FOUP': 1,
#  'WiFi': 1,
#  'Digital & Media Digital Compass': 1,
#  'DividendChannel': 1,
#  'KETV - Omaha': 1,
#  'RED VENTURES': 1,
#  "SK Broadband's": 1,
#  'IEEE Spectrum': 1,
#  'Samsung Group': 1,
#  'Avnet': 1,
#  'EURACTIV European': 1,
#  'Bain & Company': 1,
#  'Goldman Sachs Group Inc.': 1,
#  'the People’s Bank of China': 1,
#  'AspenCore,': 1,
#  'the 6G Futures': 1,
#  'The Segment Producer': 1,
#  'MIT Welcome Center': 1,
#  'HEALTH, SAFETY & SECURITY': 1,
#  'Jabil': 1,
#  'K. P Esler': 1,
#  'Forbes': 1,
#  'County Broadband': 1,
#  "Midland Co. Sheriff's Office": 1,
#  'Score Board': 1,
#  'Dell Technologies': 1,
#  'TRW': 1,
#  'LRCX': 1,
#  'Outperform to Market Perform': 1,
#  '6G Technology': 1,
#  'Zacks ETF Rank #1': 1,
#  'UK Operators': 1,
#  'PLTR': 1,
#  'Chicago Mercantile Exchange Inc.': 1,
#  'Mentor Graphics': 1,
#  'Coins': 1,
#  'Department of Defense (DoD': 1,
#  'Centralab': 1,
#  'Nano Letters': 1,
#  'TANCO': 1,
#  'Future US Inc': 1,
#  'Shakers': 1,
#  'the VanEck': 1,
#  'ColdQuanta': 1,
#  'Arm Holdings': 1,
#  'Bengaluru': 1,
#  'Warner Media Company': 1,
#  'Arm Ltd': 1,
#  "M&A. The U.K.-based company's": 1,
#  'Ferrari': 1,
#  'the Google TPU': 1,
#  'Buenos Aires': 1,
#  'Lava': 1,
#  'Bertan Bakkaloglu': 1,
#  'the Federal Reserve': 1,
#  'CTM': 1,
#  'Tableau': 1,
#  'Axxia/Intel': 1,
#  'the Twinkie PD': 1,
#  'Shepherd': 1,
#  'SKPRES-WB': 1,
#  'CMD': 1,
#  'NVIDIA Corp (NASDAQ:': 1,
#  'BAAP': 1,
#  'Five9 Inc.': 1,
#  'Acorn Computers': 1,
#  'Uighurs': 1,
#  'Easier Than You Think Property': 1,
#  'PCB': 1,
#  'H&M': 1,
#  'The Commerce Department': 1,
#  'FWIW': 1,
#  'Bangladesh Work': 1,
#  '@JamesDSneed': 1,
#  'ComputerBase': 1,
#  'J. P Towsend': 1,
#  'Bacteria, Fungi': 1,
#  'Bangladesh Jobs': 1,
#  'Warframe': 1,
#  'Pure Michigan': 1,
#  'Freddie Mac': 1,
#  'Mac-Imprint': 1,
#  'LDP': 1,
#  'USPS': 1,
#  'automotive assembly': 1,
#  "Bezos' Rocket Company Blue Origin Allege Sexism, Safety Risks Senators Push": 1,
#  'the U.S. Department of Health and Human Services': 1,
#  'SPX': 1,
#  'ByteDance': 1,
#  'Umno': 1,
#  'Rewards': 1,
#  "The U.S. ISM 's": 1,
#  'D-Ore': 1,
#  'SABAH &': 1,
#  'Texas Advanced Computing Center Marks': 1,
#  'MovieRedbus': 1,
#  'MediaTek': 1,
#  'Dynamic Random-Access Memory': 1,
#  'SK Group': 1,
#  'NIO Inc.': 1,
#  'SoundDesign': 1,
#  'Kintex': 1,
#  'Apple MacBook': 1,
#  'AMD platforms': 1,
#  'the Zacks Equity Research': 1,
#  'Anant Agarwal': 1,
#  'Saks Fifth Avenue': 1,
#  'quantum dynamics': 1,
#  'EU Internal Market': 1,
#  'Wahab Alasfour': 1,
#  'Arabinda “AB': 1,
#  'MediaLab': 1,
#  'WIDAD': 1,
#  'TOPGLOV': 1,
#  'Courtaulds': 1,
#  'The Detroit Smart Parking Lab': 1,
#  'Alejandro de la Garza/New York': 1,
#  'JCR': 1,
#  'Raley': 1,
#  'LGR': 1,
#  'Punit Goenka': 1,
#  'Annie Saunders': 1,
#  'TAFI': 1,
#  'Meritage Group': 1,
#  'OCIDA': 1,
#  'Fisker Inc.': 1,
#  'TKL': 1,
#  'Citadel': 1,
#  'the Exascale Computing Project': 1,
#  'the US Senate': 1,
#  'Salak South': 1,
#  'Norman C Rasmussen': 1,
#  'Walmart': 1,
#  'Canaccord Genuity': 1,
#  'EUV': 1,
#  'Chargers': 1,
#  'PBS': 1,
#  'Lyell Immunopharma': 1,
#  'Tracy': 1,
#  'Indo-Pacific': 1,
#  'Greenpeace': 1,
#  'Volkswagen Group': 1,
#  'X86': 1,
#  'AT&T Bell Laboratories': 1,
#  'ULTRACOLD': 1,
#  'Brent': 1,
#  'GrowthIndia': 1,
#  'DJI Opco': 1,
#  'This Intel Core i7-11700K CPU': 1,
#  'General Motors Co': 1,
#  'Solvay Special Chemicals': 1,
#  '@Laughing_Man @hnpn914': 1}

# %%
import json

# %%
with open('csvs/updated_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(sorted_freq_dict))

# %%
import itertools

thirty_sorted_freq_dict = dict(itertools.islice(sorted_freq_dict.items(), 30))

# %%
with open('csvs/updated_thirty_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(thirty_sorted_freq_dict))

# %%
keys = list(sorted_freq_dict.keys())

# %%
lower_sorted_freq_dict = {k.lower():sorted_freq_dict[k] for k in keys}

# %%
lower_sorted_freq_dict.pop('ark')
# Out:
# {'ark': 319,
#  'ase': 290,
#  'ning': 241,
#  'sec': 190,
#  'ced': 175,
#  'mit': 162,
#  'intel': 150,
#  'nda': 121,
#  'ems': 92,
#  'adi': 88,
#  'arm': 85,
#  'fpga': 79,
#  'mac': 74,
#  'tsmc': 71,
#  'nio': 69,
#  'ford': 66,
#  'sia': 65,
#  'trade': 63,
#  'ngl': 63,
#  'nasdaq': 61,
#  'quantum': 54,
#  'etf': 51,
#  'doe': 51,
#  'apple': 50,
#  'full': 49,
#  'nam': 49,
#  'samsung': 49,
#  'spac': 48,
#  'coo': 41,
#  'phys': 41,
#  'amd': 40,
#  'reuters': 33,
#  'nvidia': 33,
#  'doi': 33,
#  'mental': 31,
#  'cfius': 30,
#  'nyse': 29,
#  'fed': 28,
#  'free': 28,
#  'merck': 23,
#  'telecom': 22,
#  'google': 20,
#  'nsw': 19,
#  's&p': 18,
#  'factories': 18,
#  'qmc': 18,
#  'tam': 17,
#  'softbank': 17,
#  'commerce': 17,
#  'goal': 17,
#  'lsi': 17,
#  'aces': 16,
#  'hpc': 16,
#  'pfizer': 16,
#  'senate': 16,
#  'ramp': 15,
#  'surge': 14,
#  'ism': 13,
#  'committee': 13,
#  'mia': 13,
#  'makris': 12,
#  'nxp': 12,
#  'unique': 11,
#  'kubis': 11,
#  'qmcpack': 11,
#  'toyota': 11,
#  'gpu': 11,
#  'rambus': 11,
#  'qualcomm': 11,
#  'cdc': 11,
#  'marketwatch': 10,
#  'berkeley': 10,
#  'oem': 9,
#  'insider': 9,
#  'aurora': 9,
#  'exchange': 9,
#  'fortune': 9,
#  'euractiv': 9,
#  'medc': 8,
#  'smh': 8,
#  'ned davis research': 8,
#  'cxl': 8,
#  'wsj': 8,
#  'wells fargo': 8,
#  'ic insights': 8,
#  'designer': 8,
#  'general motor': 8,
#  'kla': 8,
#  'hsc': 8,
#  'nitin dahad': 8,
#  'general motors': 7,
#  'alb': 7,
#  'psi': 7,
#  'telecoms': 7,
#  'telco': 7,
#  'clay': 7,
#  'ibm': 7,
#  'javey': 7,
#  'frey': 7,
#  'alcf': 7,
#  'delta': 7,
#  'the u.s. department': 6,
#  'intc': 6,
#  'nikkei': 6,
#  'hbm': 6,
#  'the motley fool': 6,
#  'schottky': 6,
#  'nasa': 6,
#  'genci': 6,
#  'ryzen': 6,
#  'pixel': 6,
#  'at&t': 6,
#  'dod': 6,
#  'nand': 6,
#  'fermi': 6,
#  'volkswagen': 6,
#  'synopsys': 5,
#  'rpi': 5,
#  'idc': 5,
#  'flp': 5,
#  'bcg/sia': 5,
#  'robinhood': 5,
#  'lam research': 5,
#  'dsp': 5,
#  'kozicki': 5,
#  'globalfoundries': 5,
#  'huawei': 5,
#  'the us government': 5,
#  'harvard': 5,
#  'techcrunch': 5,
#  'hanbury': 5,
#  'j.p. morgan asset management': 5,
#  'scope': 5,
#  'invesco': 5,
#  'mpw': 4,
#  'hpcwire': 4,
#  'mosfet': 4,
#  'ford motor': 4,
#  'boi': 4,
#  'sk broadband': 4,
#  'globe': 4,
#  'the group': 4,
#  'the u.s. department of energy': 4,
#  'gddr': 4,
#  'msf': 4,
#  'bank of america': 4,
#  'cathie wood': 4,
#  'globalwafers': 4,
#  'the u.s. senate': 4,
#  'kiyosaki': 4,
#  'ieee': 4,
#  'the ned davis research': 4,
#  'power up': 4,
#  'royal dutch': 4,
#  'seagate technology': 4,
#  'federal reserve': 4,
#  'nasdaq,': 4,
#  'at&t inc.': 4,
#  'ohmic': 4,
#  'nikkei asia': 3,
#  'bmw': 3,
#  'dft': 3,
#  'azeredo': 3,
#  'motorola': 3,
#  'bmy': 3,
#  'goldman sachs': 3,
#  'royal dutch shell': 3,
#  'umc': 3,
#  'eurekalert': 3,
#  'intel foundry services': 3,
#  'ars technica': 3,
#  'cma': 3,
#  'quantum dots': 3,
#  'nnsa': 3,
#  'rivian automotive inc.': 3,
#  '6g futures': 3,
#  'daphne leprince-ringuet': 3,
#  'ftxl': 3,
#  'white pine': 3,
#  'psa': 3,
#  'bosch': 3,
#  "moody's analytics": 3,
#  'ttd': 3,
#  'dpa': 3,
#  'esm': 3,
#  'rivian details': 3,
#  'macy': 3,
#  'cfpb': 3,
#  'mrna': 3,
#  'nyc': 3,
#  'gop': 3,
#  'apple watch': 3,
#  'atp': 3,
#  'plug power': 2,
#  'mtw': 2,
#  'lülsdorf': 2,
#  'cerner': 2,
#  'tridge': 2,
#  'indiebio': 2,
#  'pfizer inc': 2,
#  'movers': 2,
#  'designware': 2,
#  'detroit smart parking lab': 2,
#  'd-n.y.': 2,
#  'ase technology': 2,
#  "wells fargo's": 2,
#  'chargeway': 2,
#  'chromebooks': 2,
#  'rbc': 2,
#  'fujitsu': 2,
#  'big hyperscale data': 2,
#  'pulse veterinary technologies': 2,
#  '2021,12:03pm edt building technology': 2,
#  'hyperscale data': 2,
#  'toyota motors': 2,
#  'hhs': 2,
#  'd-lab': 2,
#  'wise road capital': 2,
#  'fiat chrysler': 2,
#  'powerball': 2,
#  'cnbc': 2,
#  'derecho': 2,
#  'global security initiative': 2,
#  'drams': 2,
#  'magsafe': 2,
#  'deloitte': 2,
#  'diy': 2,
#  'central processing unit': 2,
#  'samsung biologics': 2,
#  'bay future, inc.': 2,
#  'massmutual': 2,
#  'scotus': 2,
#  'high performance': 2,
#  'aum': 2,
#  'csi': 2,
#  'bms': 2,
#  'the american society of mechanical engineers': 2,
#  'nadia schadlow': 2,
#  'fda': 2,
#  'white pine commerce park': 2,
#  'pavneet singh': 2,
#  'nxpi': 2,
#  'nokia': 2,
#  'the lafayette park neighborhood': 2,
#  'digital compass': 2,
#  'anti-drugs agency': 2,
#  'bay future,': 2,
#  'smic': 2,
#  'moderna inc': 2,
#  'softbank group corp': 2,
#  'siemens': 2,
#  'xlnx': 2,
#  'centennial resource': 2,
#  'internal market': 2,
#  'asia pacific': 2,
#  'shore chan': 2,
#  'xsd': 2,
#  'ocbc': 2,
#  'wcpo': 2,
#  'ford motors company': 2,
#  'semtech': 2,
#  'asu thrive': 2,
#  'treasury': 2,
#  'pune': 2,
#  'tesla inc': 2,
#  'hpe': 2,
#  'saudis triumph': 2,
#  'vitamin c': 2,
#  'biden cfpb pick rohit': 2,
#  'u.s. supreme court': 2,
#  'cmos': 2,
#  'sci-tech': 2,
#  'intel corp': 2,
#  'f-35': 2,
#  'brookings': 2,
#  'michigan realtor': 2,
#  'govt': 2,
#  'salvatori': 2,
#  'a uk company': 2,
#  'nba': 2,
#  'lf energy': 2,
#  'ks aseptic process engineer - pfizer - rocky mount': 1,
#  'north pole express': 1,
#  'qualcomm europe': 1,
#  'wework, uber, grab, compass, doordash': 1,
#  'nio, byd co.': 1,
#  'usica': 1,
#  'price bank of america': 1,
#  'agenda & pr ©': 1,
#  'bain & co.': 1,
#  'the intel parallel computing center': 1,
#  'barney and associates': 1,
#  'si-n': 1,
#  'dimitra': 1,
#  'jpmorgan': 1,
#  'oecd': 1,
#  'how modern health': 1,
#  'the u.s. patent and trademark office': 1,
#  'qlc': 1,
#  'et intel corp.': 1,
#  'removing tax barriers—': 1,
#  'iucrc': 1,
#  'digital interfaces': 1,
#  'inez kerr bell professors': 1,
#  'etf winners and losers': 1,
#  'naise': 1,
#  'vlsi technology': 1,
#  'umicore ag & co.': 1,
#  'dell, nokia': 1,
#  'unleashing the potential of the mind': 1,
#  'realtor of the year': 1,
#  'digicel': 1,
#  'sbg': 1,
#  'the associated press': 1,
#  'deal flow': 1,
#  'nnsa trilab': 1,
#  'ememory technology incorporated': 1,
#  'waco': 1,
#  'indiasamayam tamilsamayam telugumiss kyrabombay': 1,
#  'ford motor co (f.n': 1,
#  'center for cybersecurity and digital forensics building': 1,
#  'eu services': 1,
#  'american express': 1,
#  'the texas analog center of excellence': 1,
#  'ab ghosh': 1,
#  'ambaninirmala': 1,
#  'certus/certus pro': 1,
#  'mit d-lab': 1,
#  'samsung bioepis': 1,
#  'nsf awards u': 1,
#  'susquehanna financial group': 1,
#  'llc associates program': 1,
#  'ccp': 1,
#  'arabinda ‘ab': 1,
#  'coca-cola': 1,
#  'primetalk': 1,
#  'mkl': 1,
#  'quantum computing’s uptake': 1,
#  'pittsburgh supercomputer powers machine learning analysis': 1,
#  'nike': 1,
#  'the european initiative ‘important': 1,
#  'the pros workers': 1,
#  'copyright 2018': 1,
#  'nfc': 1,
#  'three universities team for nsf': 1,
#  'cloud security': 1,
#  'getty images lam research corp.': 1,
#  'ways and means plan': 1,
#  'acteurs européens': 1,
#  'generators': 1,
#  "phoenix bashas'": 1,
#  'the doe exascale comupting project': 1,
#  'mckinsey & company': 1,
#  'the katherine ngai pesic & silvaco research': 1,
#  'wwwg-am': 1,
#  'nissan': 1,
#  'c60': 1,
#  'hewlett-packard': 1,
#  'apple tv': 1,
#  'tlc': 1,
#  'cambridge quantum': 1,
#  'ac-dc': 1,
#  'lexus': 1,
#  'xdl': 1,
#  'tldr a15': 1,
#  'delphi': 1,
#  'undergrad programs earn higher marks': 1,
#  'future brands': 1,
#  'the solar power laboratory': 1,
#  'apollo': 1,
#  'arm technology china': 1,
#  'img': 1,
#  'faraday technology': 1,
#  'ascac': 1,
#  'te-msc-smt-2021-93-ld': 1,
#  'the techcrunch exchange': 1,
#  'france energy': 1,
#  'mta': 1,
#  'hpc user forum': 1,
#  'etf channel': 1,
#  "u.s. supreme court's": 1,
#  'mercedes': 1,
#  'the tri-lab cts-2': 1,
#  'asu’s macrotechnology works': 1,
#  'anandtech interview': 1,
#  "the center of america's": 1,
#  'center for nanotechnology': 1,
#  'amd svp of computing and graphics': 1,
#  'intel-hpe': 1,
#  'wto': 1,
#  'big finance': 1,
#  'quantum mechanics': 1,
#  'xiaomi': 1,
#  'foup': 1,
#  'wifi': 1,
#  'digital & media digital compass': 1,
#  'dividendchannel': 1,
#  'ketv - omaha': 1,
#  'red ventures': 1,
#  "sk broadband's": 1,
#  'ieee spectrum': 1,
#  'samsung group': 1,
#  'avnet': 1,
#  'euractiv european': 1,
#  'bain & company': 1,
#  'goldman sachs group inc.': 1,
#  'the people’s bank of china': 1,
#  'aspencore,': 1,
#  'the 6g futures': 1,
#  'the segment producer': 1,
#  'mit welcome center': 1,
#  'health, safety & security': 1,
#  'jabil': 1,
#  'k. p esler': 1,
#  'forbes': 1,
#  'county broadband': 1,
#  "midland co. sheriff's office": 1,
#  'score board': 1,
#  'dell technologies': 1,
#  'trw': 1,
#  'lrcx': 1,
#  'outperform to market perform': 1,
#  '6g technology': 1,
#  'zacks etf rank #1': 1,
#  'uk operators': 1,
#  'pltr': 1,
#  'chicago mercantile exchange inc.': 1,
#  'mentor graphics': 1,
#  'coins': 1,
#  'department of defense (dod': 1,
#  'centralab': 1,
#  'nano letters': 1,
#  'tanco': 1,
#  'future us inc': 1,
#  'shakers': 1,
#  'the vaneck': 1,
#  'coldquanta': 1,
#  'arm holdings': 1,
#  'bengaluru': 1,
#  'warner media company': 1,
#  'arm ltd': 1,
#  "m&a. the u.k.-based company's": 1,
#  'ferrari': 1,
#  'the google tpu': 1,
#  'buenos aires': 1,
#  'lava': 1,
#  'bertan bakkaloglu': 1,
#  'the federal reserve': 1,
#  'ctm': 1,
#  'tableau': 1,
#  'axxia/intel': 1,
#  'the twinkie pd': 1,
#  'shepherd': 1,
#  'skpres-wb': 1,
#  'cmd': 1,
#  'nvidia corp (nasdaq:': 1,
#  'baap': 1,
#  'five9 inc.': 1,
#  'acorn computers': 1,
#  'uighurs': 1,
#  'easier than you think property': 1,
#  'pcb': 1,
#  'h&m': 1,
#  'the commerce department': 1,
#  'fwiw': 1,
#  'bangladesh work': 1,
#  '@jamesdsneed': 1,
#  'computerbase': 1,
#  'j. p towsend': 1,
#  'bacteria, fungi': 1,
#  'bangladesh jobs': 1,
#  'warframe': 1,
#  'pure michigan': 1,
#  'freddie mac': 1,
#  'mac-imprint': 1,
#  'ldp': 1,
#  'usps': 1,
#  'automotive assembly': 1,
#  "bezos' rocket company blue origin allege sexism, safety risks senators push": 1,
#  'the u.s. department of health and human services': 1,
#  'spx': 1,
#  'bytedance': 1,
#  'umno': 1,
#  'rewards': 1,
#  "the u.s. ism 's": 1,
#  'd-ore': 1,
#  'sabah &': 1,
#  'texas advanced computing center marks': 1,
#  'movieredbus': 1,
#  'mediatek': 1,
#  'dynamic random-access memory': 1,
#  'sk group': 1,
#  'nio inc.': 1,
#  'sounddesign': 1,
#  'kintex': 1,
#  'apple macbook': 1,
#  'amd platforms': 1,
#  'the zacks equity research': 1,
#  'anant agarwal': 1,
#  'saks fifth avenue': 1,
#  'quantum dynamics': 1,
#  'eu internal market': 1,
#  'wahab alasfour': 1,
#  'arabinda “ab': 1,
#  'medialab': 1,
#  'widad': 1,
#  'topglov': 1,
#  'courtaulds': 1,
#  'the detroit smart parking lab': 1,
#  'alejandro de la garza/new york': 1,
#  'jcr': 1,
#  'raley': 1,
#  'lgr': 1,
#  'punit goenka': 1,
#  'annie saunders': 1,
#  'tafi': 1,
#  'meritage group': 1,
#  'ocida': 1,
#  'fisker inc.': 1,
#  'tkl': 1,
#  'citadel': 1,
#  'the exascale computing project': 1,
#  'the us senate': 1,
#  'salak south': 1,
#  'norman c rasmussen': 1,
#  'walmart': 1,
#  'canaccord genuity': 1,
#  'euv': 1,
#  'chargers': 1,
#  'pbs': 1,
#  'lyell immunopharma': 1,
#  'tracy': 1,
#  'indo-pacific': 1,
#  'greenpeace': 1,
#  'volkswagen group': 1,
#  'x86': 1,
#  'at&t bell laboratories': 1,
#  'ultracold': 1,
#  'brent': 1,
#  'growthindia': 1,
#  'dji opco': 1,
#  'this intel core i7-11700k cpu': 1,
#  'general motors co': 1,
#  'solvay special chemicals': 1,
#  '@laughing_man @hnpn914': 1}

# %%
with open('csvs/updated_sorted_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(lower_sorted_freq_dict))

# %%
import itertools

lower_thirty_sorted_freq_dict = dict(itertools.islice(lower_sorted_freq_dict.items(), 30))

# %%
with open('csvs/lower_updated_thirty_freq_company_names.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(lower_thirty_sorted_freq_dict))

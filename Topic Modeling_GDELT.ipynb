# %%
import pandas as pd
import json
gdelt_news = pd.read_csv('csvs/gdelt_news_updated.csv', sep='\t')

# %%
gdelt_news.fillna('', inplace=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
dtm = tfidf.fit_transform(gdelt_news['News'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA = LatentDirichletAllocation(n_components=10,random_state=101)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=101)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV

search_params = {
  'n_components': [5, 10, 15, 20, 25],
  'learning_decay': [.5, .7]
}

model = LatentDirichletAllocation()

# Try all of the options
gridsearch = GridSearchCV(model, param_grid=search_params, n_jobs=-1, verbose=1)
gridsearch.fit(dtm)

# What did we find?
print("Best Model's Params: ", gridsearch.best_params_)
print("Best Log Likelihood Score: ", gridsearch.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -2896.018811810439

# %%
topic_lst = []
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
    topic_lst.append([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['semiconductor', 'kompas', 'banking', 'trend', 'perindustri', 'tiongkok', 'cibatu', 'kunjungi', 'garut', 'rights', 'jl', 'auto', '38', 'banjar', 'desa']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['car', 'toshiba', '780g', 'dihasilkan', 'und', 'der', 'se', 'ps5', 'peranti', 'power', 'console', 'na', 'snapdragon', 'stocks', 'die']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['pemprosesan', '1200', 'mengesahkan', 'dimensity', 'مبيعات', 'cu', 'producătorii', 'pentru', 'cipuri', 'mediatek', 'nord', 'din', 'în', 'şi', 'oneplus']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['moody', 'companies', 'cnbc', 'like', 'demand', 'manufacturing', 'uy', 'chip', 'said', 'production', 'new', 'semiconductor', 'shortage', 'supply', 'chips']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['kelangkaan', 'dari', 'pada', 'semikonduktor', 'wib', 'indonesia', '2021', 'industri', 'akan', 'untuk', 'ini', 'dan', 'chip', 'yang', 'di']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['www', 'جديدة', 'insert_random_number_here', 'advm', 'org', 'php', 'ahram', 'http', 'cb', 'delivery', 'فيديو', 'por', 'en', 'amp', 'la']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['ou', 'series', 'ford', 'données', 'trucks', 'run', 'devices', 'semiconductor', 'solution', 'supply', 'chips', 'et', 'fewer', 'cooling', 'jetcool']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['lack', 'volkswagen', 'business', 'second', 'samsung', 'q2', 'flip', 'oled', 'производството', 'sector', 'pang', 'fold', 'money', 'smartphone', 'galaxy']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['sepakbola', 'terdampak', 'la', 'picture', 'się', 'chipów', 'że', 'samochodów', 'produkcji', 'bmw', 'în', 'republika', 'oct', 'ahad', 'na']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['чипов', 'что', 'от', 'по', 'да', 'بسبب', 'إلى', 'نقص', 'على', 'за', 'الرقائق', 'السيارات', 'من', 'في', 'на']

# %%
with open('csvs/gdelt_topics.json','w+', encoding='utf-8') as f:
    f.writelines(json.dumps(topic_lst))

# %%
topic_results = LDA.transform(dtm)

# %%
gdelt_news['Topic'] = topic_results.argmax(axis=1)

# %%
gdelt_news.to_csv('csvs/gdelt_news_with_topic.csv', index=False)

# %%
all_news = list(gdelt_news['News'])

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(all_news[10])
[(X.text, X.label_) for X in doc.ents]
# Out:
# [('webových stránkách', 'PERSON'),
#  ('které mohou', 'ORG'),
#  ('údaje', 'GPE'),
#  ('např', 'ORG'),
#  ('jak procházíte', 'PERSON'),
#  ('partneři', 'ORG'),
#  ('Vašem', 'PERSON'),
#  ('Tyto', 'GPE'),
#  ('Můžeme Vám', 'ORG'),
#  ('Váš', 'ORG'),
#  ('Svůj souhlas můžete', 'PERSON'),
#  ('či jej odvoláte', 'PERSON'),
#  ('Vám', 'GPE'),
#  ('oprávněného zájmu', 'PERSON'),
#  ('Vznést', 'ORG'),
#  ('oprávněného zájmu', 'PERSON'),
#  ('další nastavení soukromí můžete v sekci', 'ORG'),
#  ('Podrobné nastavení', 'WORK_OF_ART'),
#  ('či v odkazech tam uvedených', 'WORK_OF_ART'),
#  ('Vámi', 'PERSON'),
#  ('partneři zpracováváme údaje', 'ORG'),
#  ('následujícím způsobem', 'PERSON'),
#  ('Personalizovaná', 'PERSON'),
#  ('Ukládání', 'GPE'),
#  ('Zpracování', 'PERSON'),
#  ('Zpracování', 'PERSON'),
#  ('Daimleru Nedostatek', 'PERSON'),
#  ('pocítí', 'GPE'),
#  ('ještě v roce', 'PERSON'),
#  ('2023', 'DATE'),
#  ('Daimleru', 'GPE')]

# %%
organization = []
for news in all_news:
    doc = nlp(news)
    organization.append([i.text for i in doc.ents if (i.label_ == 'ORG' and i.text != "LLC")])

# %%
flat_org = [item for sublist in organization for item in sublist]

# %%
flat_org_unq = list(set(flat_org))

# %%
keywords = [
    "house",
    "university",
    "report",
    "information",
    "communication",
    "time",
    "visa",
    "master",
    "social",
    "sale",
    "invest",
    "street",
    "network",
    "terminal",
    "linked",
    "facebook",
    "yahoo",
    'youtube',
    "daily",
    "week",
    "business",
    "trust",
    "foundation",
    ".com",
    "stud",
    "history",
    "school",
    "stock",
    "world",
    "cnn",
    "science",
    "england &",
    "fund",
    "wordpress",
    "trump",
    "electric",
    "twitter",
    "musk",
    "elon",
    "berkley",
    "usb",
    "l.",
    "modi",
    "postal"
    "app",
    "semiconductor",
    "Li",
    "ST",
    "on",
    "Lattice",
    "micro",
    "state",
    "ip",
    "ev",
    "ml",
    "next",
    "live",
    "led",
    "silicon",
    "covid",
    "news",
    "journal",
    "automobile",
    "car",
    "council"
]

# %%
filtered_flat_org_unq = []

for org in flat_org_unq:
    flag = True
    for k in keywords:
        if k.strip().lower() in org.strip().lower():
            flag = False
            break
    if flag:
        filtered_flat_org_unq.append(org)

# %%
filtered_flat_org_unq
# Out:
# ['Toyoty',
#  'mengambil langkah',
#  'jaguar',
#  'mobil',
#  'Serang Diabetes hilang selamanya & pankreas',
#  'что',
#  'Иван Чернов',
#  'Benchmark Company',
#  'AS',
#  'Copyright ©',
#  'използвани в центрове за данни',
#  'kata Karyanto',
#  'MIT',
#  'The Supply Chain is Broken Again for Chicken',
#  'США',
#  'Ford',
#  'Murdaningsih Pasokan',
#  'kedua perusahaan',
#  'Sampai Banyak Orang Rela',
#  'أكبر مصنع تابع لها',
#  'India Motor',
#  'Toyota',
#  'kolejne iteracje',
#  'търсенето',
#  'muka oleh beberapa perusahaan',
#  'приемането',
#  'Yardeni Research',
#  'JLR',
#  'بين',
#  'Android Authority',
#  'AlterNet',
#  'dengan',
#  'său',
#  'meningkatkan',
#  'Artificial Intelegence (AI',
#  'the Detroit Free Press',
#  'M.2',
#  'berdampak pada',
#  'CCTV',
#  'Baidu',
#  'w Ameryce Północnej',
#  'Pasokan',
#  'GIIAS Batal',
#  'Pembangunan Jalan',
#  'WIB',
#  'Batik Kediri Berpromosi',
#  'Armata',
#  'Kuartal III',
#  'harga pasar',
#  'Polymetal',
#  'كما ستمدد شركة أودي',
#  'The Energy & Oil Sector Trade',
#  'КХЛ 1 октября',
#  'لإقامة مشروعات',
#  '2221 Коментари',
#  'САЩ General Motors',
#  'dengan kantor pusat VW',
#  'Karty',
#  'колко',
#  'Криза',
#  'из всех американских',
#  'PAPUA SIMPEG RRI LPP RRI',
#  'např',
#  'продажбите',
#  'tetapi',
#  'Mobil FWD Perlukah Memanaskan Mobil-Mobil Keluaran Terbaru',
#  'Amanz',
#  'световната автомобилна индустрия"',
#  '© 2021',
#  'CIMB Dengan Mudah',
#  'Pfizer',
#  'PLN Mobile',
#  'aut',
#  'Bosch',
#  'GMI Technology',
#  'Inggris Bikin Pusat',
#  'kuartal ketiga',
#  'tim sepak',
#  'ke',
#  'sementara itu',
#  'serta para',
#  'Kokpit Pesawat Rimbun Air',
#  'Mengajar Membatik',
#  'Netizen Auto Bahagia',
#  'Váš',
#  'Baidu KUNLUN',
#  'FORMULARELE',
#  'mobil dengan segera',
#  'Защо България',
#  'Smart',
#  'Founder of Jetcool',
#  'Glukoma',
#  'mobil impianya selama beberapa bulan',
#  '10:00PM',
#  'meningkatkan kapasitas',
#  'Kunjung Motor',
#  'Tetapi Usaha',
#  'PMI Manufaktur RI Lampaui',
#  'AFP',
#  'التي تم تسجيلها',
#  'كلثوم',
#  'serie de electrocasnice',
#  'добави Tata Motors',
#  'Huawei',
#  'MUNICH',
#  'automobilového',
#  'pak',
#  'DPK Tumbuh 2 Oktober 2021',
#  'Coupe',
#  'Ford F-series',
#  'Fiata Chryslera i PSA Group',
#  'юли Жълт',
#  'Jangan Anggap Remeh',
#  "Moody's Analytics",
#  'nich toto',
#  'لديها',
#  'Senate',
#  'PE',
#  'nic',
#  'Warga Uganda Bayar',
#  'تعهد',
#  'العام',
#  'Technologies Inc.',
#  'WIB Ketua',
#  'NXP',
#  'التي تخلق هيكلًا معدنيًا',
#  'VIDEO După ce Drulă',
#  'Toyota Motor Corp',
#  'Delta Variant Rages',
#  'PS5',
#  'eBay',
#  'Magna',
#  'UMC',
#  'General Motors Co',
#  'Renault SA',
#  'Kala Inggris',
#  '베스트',
#  'Produksi Toyota',
#  'ANTARA/Toshiba',
#  'Bain & Co.',
#  'kelompok itu karena',
#  'kec',
#  'ESDM',
#  'Arsenal',
#  'Pelapor',
#  'Pasar Ekspor Ahad',
#  'AP/Matthias Schrader Mnichov - Automobilový',
#  'salah satu',
#  'samsung',
#  'Källenius',
#  'Katarak Bisa Anda',
#  'لمشكلة الزحام..',
#  'Mercedes-Benz AG',
#  'COPYRIGHT ©',
#  'dan webcam',
#  'Secţia',
#  'land rover',
#  'TSMC',
#  'Nikkei Asia',
#  'NYSE',
#  'VWAGY',
#  'Marii Britanii',
#  'Intel',
#  'Moody’s',
#  'Baca',
#  'Par',
#  'Home Umum Krisis',
#  'السيارات بنسبة',
#  'nowości',
#  'електронния гигант',
#  'Orbánova',
#  'produksi mobil banyak tertunda',
#  'توك شو فيديو صور إنفوجراف',
#  'Nintendo Switch',
#  'Marquez',
#  'September Motor',
#  'mengatakan pada',
#  'produk mobil',
#  'serta',
#  'dan perusahaan',
#  'Dia mengingatkan',
#  'الثمن',
#  'mengurangi disrupsi pada',
#  'nimiž',
#  'В САЩ ХАРДУЕР ПАЗАР НА ЧИПОВЕ MARVELL TECHNOLOGIES НЕДОСТИГ',
#  'BYD (BYDDF',
#  'Berikut Ini Program',
#  'WHATS NEW 02/10/2021',
#  'ASEAN',
#  'BMW M4',
#  'ZDnet',
#  'Problemen wie Toshiba',
#  'va',
#  'Serang Ahad',
#  'ke depan',
#  'dengan mengatakan',
#  'WIB Sebanyak',
#  'CELE',
#  'perdagangan',
#  'Nvidia',
#  'Kalsel',
#  'kebijakan khusus',
#  'OTT',
#  'BMW',
#  'PAȘNIC Noi',
#  'FC Rapid',
#  'Въпреки това',
#  'IBD Digital',
#  'Islam',
#  "img src='http://advm.ahram.org.eg/www",
#  'Meterai Tempel BLT',
#  'Porsche',
#  'MacBooków',
#  'La escasez de',
#  'Tetapi',
#  'mobil Toyota',
#  '성능으로는 1080Ti에 필적하는 성능에',
#  'PTM',
#  'Ford Motor Джим Фарли',
#  'the Delta Variant',
#  'Google',
#  'mengembangkan',
#  'أفكار جديدة ومتنوعه',
#  "Moody's",
#  'Nouă',
#  'The Nintendo Switch',
#  'TASS',
#  'غدًا',
#  'Santa Fe',
#  'Nový',
#  'Apple',
#  'Niska',
#  'seluruh dunia',
#  'TM',
#  'Vous pouvez',
#  '제닉스',
#  'Swedia',
#  'حوالي',
#  'Mobil Baru',
#  'Parlemen Eropa di Brussels',
#  'SUSCRITO AL DIARIO IMPRESO',
#  'masyarakat dengan menyerap',
#  'SK Hynix Inc dan LG Display Co Ltd',
#  'В А1',
#  'kuota ketersediaan',
#  'компонентите си',
#  'LG Chem',
#  'грешка',
#  'Mobil Bawa Sepeda',
#  'pasokannya',
#  'Eklerek',
#  'berdiskusi dengan mereka',
#  'إلى يوم',
#  'عندما',
#  'إفلاسها',
#  'IBD',
#  'AMD',
#  'terduga dengan',
#  'NAND',
#  'الاحتلال الإسرائيلي يعلن اعتقال',
#  '갤럭시 Z',
#  'BBC',
#  'Toshiba',
#  'السيارات يجنون أرباحًا',
#  'Кентукки',
#  'Wechsel',
#  'Bloomberg Клиентите',
#  'JPMorgan Siap-siap',
#  'AMD 6나노',
#  'Taufiek',
#  'VOLKSWAGEN VOLKSWAGEN AG',
#  'VLSI Research',
#  'Mercedes-Benz',
#  'Northvolt',
#  'Kia',
#  'Marvell Technology',
#  'Lehman Brothers',
#  'وتجلب جوانب',
#  'الخطوط',
#  'IBM',
#  'JernihBerkomentar',
#  'mobil GM',
#  'Indo-Pacific',
#  'mobil mewah naik harga',
#  'Bahmuțeanca',
#  'Qualcomm',
#  'السيارات',
#  'ستايل محطة',
#  'Asan',
#  'Reuters',
#  'Samsung Display Co',
#  'OLEH NAZRIN',
#  'Как Tesla',
#  'для',
#  'mobil tertunda penjualan',
#  'Smartwatch Bisa',
#  'partneři',
#  'Компании Прегледи',
#  'CKD',
#  'mobil dengan',
#  'Jeep',
#  'Hotărârea de Guvern',
#  'FBI',
#  'Answer Technology',
#  'Mit',
#  'WIB Penyintas',
#  'WSKT',
#  'General Motors',
#  'Pukul',
#  'Pesawat Tempur',
#  'ta sytuacja',
#  'WSJ',
#  'dan perangkat telekomunikasi',
#  'Inter Tempel',
#  'Maycuzai',
#  'НОВИНИ БИЗНЕС НОВИНИ КЛЮКИ СПОРТНИ НОВИНИ ДОСТАВКА НА',
#  'Wi-Fi',
#  'Pasar',
#  'Meet Mercedes Chat pada Kamis',
#  'Zymergen',
#  'Berapa Gaji PNS Sampai Banyak',
#  'Sparty',
#  'Hyundai',
#  'WIB Proses',
#  'NĚMECKO AUTOMOTO',
#  'عالم',
#  'رقائق مصنوعة',
#  'JAKARTA',
#  'kata perusahaan itu',
#  'Sejak',
#  'Samsung',
#  'Mitsubishi',
#  'Mercedez-Benz',
#  'WIB Holding',
#  'Outbrain UK Ltd',
#  '| Redaksi | Pedoman Media',
#  'Apple - Google',
#  'mobil impianya',
#  'Semoga Cepat',
#  'Алберт',
#  'نصف نسبة',
#  'Ford Motor',
#  'В компании добавили',
#  'WPG',
#  'الإجمالي العالمي "',
#  'JAKARTA - Perang',
#  'الشهر المقبل وفقا',
#  'Pak Ganjar Bikin Para Atlet Banten Terharu Sabtu',
#  'fabryki w innych częściach',
#  'еще',
#  "mă enervează'",
#  'EED',
#  'Anda',
#  'Mercedes-Benz Kallenius seperti',
#  'Dodge Journey ke pasar Meksiko',
#  'HMC',
#  'novináři',
#  'TYLKO W DGP Gazprom prześle',
#  'dan pusat data',
#  'GDPR',
#  'Polda',
#  'partneři zpracováváme údaje',
#  'Nissan',
#  'Nikola',
#  'ekranu',
#  'mobil harus',
#  'Silf-Swedbank',
#  'Senin',
#  'UMKM Harus',
#  'وبحث',
#  'Ini 5 Serial Bertema',
#  'Saksikan Video di Bawah Ini',
#  'Mobil',
#  'dan Volvo',
#  'dengan larangan pemerintah AS',
#  'KPK',
#  'Seluruh',
#  'Qualcomm Inc',
#  'w nadchodzących',
#  'dari depan ke belakang',
#  'TSLA',
#  'Tesla',
#  'Pelajar',
#  'tetapi sektor',
#  'GlobalFoundries',
#  'VW',
#  'BepiColombo',
#  'Hadirkan Teknologi Smart Board Mini Court Room',
#  'Nigeria Melunak',
#  'Pada',
#  'CFRA',
#  'وهو ما',
#  'hilang selamanya & pankreas',
#  'german BMW AG',
#  'Hitungan Hari Mercedes Benz',
#  '베스트 브랜드어워드',
#  'недостиг',
#  'The Charlotte Observer',
#  'Тайван',
#  'KOSPI',
#  'Transaksi',
#  'Marvell',
#  '40%من إنتاجها العالمي',
#  'DSA',
#  'mobil lainnya',
#  'sejumah produk VW',
#  'Хари',
#  'Volkswagen',
#  'Kartu Kredit BCA Via ATM',
#  'Korsel Saham Korsel',
#  'الياباني',
#  'ومتابعات ملفات خاصة',
#  'إلى',
#  'السيارات الألمانية',
#  'ZEN',
#  'Mei',
#  'M.2 SSD',
#  'XPT',
#  'dengan gigih',
#  'Salah',
#  'Kill Security Guard',
#  'Jaguar',
#  'Renault',
#  'الجديدة',
#  'ANTARA',
#  'CNBC',
#  'ADIZ',
#  'softApple iOS iOS',
#  'ValueWalk',
#  'Atmosphere Press',
#  'Mercedes Benz',
#  'producţia',
#  'INTC',
#  'Goya',
#  'terpakasa',
#  'německého automobilového',
#  'Mobil  ',
#  'karena kaca depan',
#  'عقاقير',
#  'seluruh',
#  'Impresi City Hatchback',
#  'عام',
#  'CBU',
#  'للسيارات',
#  'acuză de',
#  'NU',
#  'dari',
#  'EU',
#  'MediaTek',
#  'Макрон Неприятният',
#  'Verge',
#  'NXPI',
#  'العالم',
#  'وفاة رأفت الخواجة كبير مشجعى الزمالك رئيس',
#  'Xiaomi',
#  'IDM',
#  'producţia de',
#  'Artificial Intelegence',
#  'susţin',
#  'masalah',
#  'KRL Masa Perpanjangan PPKM',
#  'Chung',
#  'БСП',
#  'Můžeme Vám',
#  'akan kuasai pasar',
#  'Bank Sentral Kuba',
#  'Berikut Ini Dampak',
#  'Eropa Motor',
#  'un',
#  'Гендиректор',
#  'které mohou',
#  'Jeep Gladiator',
#  'Ltd Akzeptieren Cyber Security Challenge',
#  'Tapi',
#  'orang beraktivitas di',
#  'segera memperoleh',
#  'Trackhawk Bersiap Masuk Museum',
#  'Nomura',
#  'UE',
#  'Tanah Air',
#  'karena pada saat itu ada',
#  'CPU EPYC',
#  'الشهر المقبل',
#  'ČTK',
#  'pe pagina cu',
#  'GM',
#  'още',
#  'setkání',
#  'Skotsko',
#  '어워드',
#  'Un',
#  'глобалния недостиг',
#  'upaya menjaga program vaksinasi',
#  'Шарлийн Търсите',
#  'مديروها بهدف',
#  'MJF',
#  'Русия',
#  'CAPTCHA',
#  'Jakarta - Hyundai Motors',
#  'Партнерские',
#  'FIFA',
#  'producţia pe',
#  'UNVR',
#  "General Motors'",
#  'mengatakan bahwa',
#  'Penjualan',
#  'GeForce',
#  'ANTARA/REUTERS/',
#  'JAKARTA - PT',
#  'عبد',
#  'В същото време задръстванията',
#  'Deficitul',
#  'كما',
#  'Pesawat',
#  'Rudý',
#  'dampak pada',
#  'Home Umum Scania',
#  'Ukrajina v NATO',
#  'Vendor-ii',
#  'Olahraga',
#  'Delta']

# %%
temp_all_news = " ".join(all_news)

# %%
freq_dict = dict()
for org in filtered_flat_org_unq:
    if len(org) > 2:
        count = temp_all_news.lower().count(org.lower())
        freq_dict[org] = count

# %%
sorted_freq_dict = {k: v for k, v in sorted(freq_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_freq_dict
# Out:
# {'Pada': 150,
#  'WIB': 115,
#  'dengan': 108,
#  'Pasokan': 101,
#  'Ford': 58,
#  'nic': 58,
#  'Samsung': 54,
#  'Baca': 50,
#  'Toyota': 48,
#  'MIT': 47,
#  'ANTARA': 42,
#  'إلى': 37,
#  'EED': 36,
#  'Asan': 35,
#  'Salah': 33,
#  'عالم': 30,
#  'Pasar': 29,
#  'ZEN': 28,
#  'Tesla': 27,
#  'Hyundai': 26,
#  'недостиг': 26,
#  'Intel': 25,
#  'CNBC': 25,
#  'Penjualan': 25,
#  'BMW': 23,
#  'العالم': 23,
#  'Tapi': 23,
#  'Apple': 22,
#  'عام': 20,
#  'salah satu': 19,
#  "Moody's": 19,
#  'PS5': 18,
#  'что': 17,
#  'Google': 17,
#  'Jeep': 17,
#  'Volkswagen': 17,
#  'Mercedes-Benz': 16,
#  'بين': 14,
#  'Toshiba': 14,
#  'Sejak': 14,
#  'Seluruh': 14,
#  'seluruh': 14,
#  'IBD': 13,
#  'Reuters': 13,
#  'الياباني': 13,
#  'Olahraga': 13,
#  'AMD': 12,
#  'للسيارات': 12,
#  'Copyright ©': 11,
#  'العام': 11,
#  'COPYRIGHT ©': 11,
#  'CELE': 11,
#  'General Motors': 11,
#  'Wi-Fi': 11,
#  'Mei': 11,
#  'Mercedes Benz': 11,
#  'masalah': 11,
#  'meningkatkan': 10,
#  'tetapi': 10,
#  'TSMC': 10,
#  'OTT': 10,
#  'Tetapi': 10,
#  'Qualcomm': 10,
#  'Xiaomi': 10,
#  'търсенето': 9,
#  'WHATS NEW 02/10/2021': 9,
#  'Dodge Journey ke pasar Meksiko': 9,
#  'Senin': 9,
#  'الجديدة': 9,
#  'dampak pada': 9,
#  'Криза': 8,
#  "Moody's Analytics": 8,
#  'land rover': 8,
#  'berdampak pada': 7,
#  'serta': 7,
#  'Nvidia': 7,
#  'для': 7,
#  'CKD': 7,
#  'producţia': 7,
#  'jaguar': 6,
#  '© 2021': 6,
#  'Huawei': 6,
#  'Technologies Inc.': 6,
#  'ke depan': 6,
#  'perdagangan': 6,
#  'Niska': 6,
#  'seluruh dunia': 6,
#  'Kia': 6,
#  'وهو ما': 6,
#  'Marvell': 6,
#  'Jaguar': 6,
#  'عبد': 6,
#  'Deficitul': 6,
#  'Pesawat': 6,
#  'JLR': 5,
#  'колко': 5,
#  'продажбите': 5,
#  'kuartal ketiga': 5,
#  'tim sepak': 5,
#  'Pasar Ekspor Ahad': 5,
#  'produk mobil': 5,
#  'Swedia': 5,
#  'BBC': 5,
#  'еще': 5,
#  'GlobalFoundries': 5,
#  'السيارات الألمانية': 5,
#  'Renault': 5,
#  'Jeep Gladiator': 5,
#  'الشهر المقبل': 5,
#  'Delta': 5,
#  'muka oleh beberapa perusahaan': 4,
#  'M.2': 4,
#  'Baidu': 4,
#  'NXP': 4,
#  'UMC': 4,
#  'kec': 4,
#  'Källenius': 4,
#  'dan webcam': 4,
#  'September Motor': 4,
#  'dan perusahaan': 4,
#  'Islam': 4,
#  "img src='http://advm.ahram.org.eg/www": 4,
#  'Mobil Baru': 4,
#  'IBM': 4,
#  'Mercedez-Benz': 4,
#  'Ford Motor': 4,
#  'Nissan': 4,
#  'hilang selamanya & pankreas': 4,
#  'M.2 SSD': 4,
#  'IDM': 4,
#  'още': 4,
#  'كما': 4,
#  'أكبر مصنع تابع لها': 3,
#  'său': 3,
#  'GIIAS Batal': 3,
#  'Armata': 3,
#  'كما ستمدد شركة أودي': 3,
#  'Pfizer': 3,
#  'FORMULARELE': 3,
#  '베스트': 3,
#  'لمشكلة الزحام..': 3,
#  'Nintendo Switch': 3,
#  'mengatakan pada': 3,
#  'الثمن': 3,
#  'ASEAN': 3,
#  'IBD Digital': 3,
#  'PTM': 3,
#  'mengembangkan': 3,
#  'حوالي': 3,
#  'pasokannya': 3,
#  'إلى يوم': 3,
#  'dan perangkat telekomunikasi': 3,
#  'Inter Tempel': 3,
#  'Zymergen': 3,
#  'kata perusahaan itu': 3,
#  'CBU': 3,
#  'MediaTek': 3,
#  'Artificial Intelegence': 3,
#  'susţin': 3,
#  'akan kuasai pasar': 3,
#  'Nomura': 3,
#  'ČTK': 3,
#  '어워드': 3,
#  'Русия': 3,
#  'mengatakan bahwa': 3,
#  'Toyoty': 2,
#  'Serang Diabetes hilang selamanya & pankreas': 2,
#  'Benchmark Company': 2,
#  'США': 2,
#  'kedua perusahaan': 2,
#  'w Ameryce Północnej': 2,
#  'Batik Kediri Berpromosi': 2,
#  'Kuartal III': 2,
#  'из всех американских': 2,
#  'např': 2,
#  'Amanz': 2,
#  'GMI Technology': 2,
#  'sementara itu': 2,
#  'Mengajar Membatik': 2,
#  'Founder of Jetcool': 2,
#  'Glukoma': 2,
#  'meningkatkan kapasitas': 2,
#  'كلثوم': 2,
#  'automobilového': 2,
#  'Ford F-series': 2,
#  'Fiata Chryslera i PSA Group': 2,
#  'юли Жълт': 2,
#  'Jangan Anggap Remeh': 2,
#  'تعهد': 2,
#  'VIDEO După ce Drulă': 2,
#  'General Motors Co': 2,
#  'ESDM': 2,
#  'Pelapor': 2,
#  'Katarak Bisa Anda': 2,
#  'Mercedes-Benz AG': 2,
#  'Nikkei Asia': 2,
#  'توك شو فيديو صور إنفوجراف': 2,
#  'Marquez': 2,
#  'ZDnet': 2,
#  'Serang Ahad': 2,
#  'Въпреки това': 2,
#  'mobil Toyota': 2,
#  'Ford Motor Джим Фарли': 2,
#  'أفكار جديدة ومتنوعه': 2,
#  'Nouă': 2,
#  'غدًا': 2,
#  'Nový': 2,
#  'Vous pouvez': 2,
#  'грешка': 2,
#  'berdiskusi dengan mereka': 2,
#  'الاحتلال الإسرائيلي يعلن اعتقال': 2,
#  'Кентукки': 2,
#  'Taufiek': 2,
#  'Lehman Brothers': 2,
#  'ستايل محطة': 2,
#  'partneři': 2,
#  'mobil dengan': 2,
#  'FBI': 2,
#  'WIB Penyintas': 2,
#  'Pesawat Tempur': 2,
#  'НОВИНИ БИЗНЕС НОВИНИ КЛЮКИ СПОРТНИ НОВИНИ ДОСТАВКА НА': 2,
#  'Berapa Gaji PNS Sampai Banyak': 2,
#  'Sparty': 2,
#  'Outbrain UK Ltd': 2,
#  '| Redaksi | Pedoman Media': 2,
#  'mobil impianya': 2,
#  'fabryki w innych częściach': 2,
#  "mă enervează'": 2,
#  'Mercedes-Benz Kallenius seperti': 2,
#  'TYLKO W DGP Gazprom prześle': 2,
#  'Polda': 2,
#  'Nikola': 2,
#  'UMKM Harus': 2,
#  'وبحث': 2,
#  'Saksikan Video di Bawah Ini': 2,
#  'dengan larangan pemerintah AS': 2,
#  'KPK': 2,
#  'dari depan ke belakang': 2,
#  'Pelajar': 2,
#  'CFRA': 2,
#  'Тайван': 2,
#  'KOSPI': 2,
#  'ومتابعات ملفات خاصة': 2,
#  'dengan gigih': 2,
#  'ValueWalk': 2,
#  'Impresi City Hatchback': 2,
#  'Макрон Неприятният': 2,
#  'Verge': 2,
#  'وفاة رأفت الخواجة كبير مشجعى الزمالك رئيس': 2,
#  'Chung': 2,
#  'Гендиректор': 2,
#  'Tanah Air': 2,
#  'глобалния недостиг': 2,
#  'CAPTCHA': 2,
#  'ANTARA/REUTERS/': 2,
#  'mengambil langkah': 1,
#  'Иван Чернов': 1,
#  'използвани в центрове за данни': 1,
#  'kata Karyanto': 1,
#  'The Supply Chain is Broken Again for Chicken': 1,
#  'Murdaningsih Pasokan': 1,
#  'Sampai Banyak Orang Rela': 1,
#  'India Motor': 1,
#  'kolejne iteracje': 1,
#  'приемането': 1,
#  'Yardeni Research': 1,
#  'Android Authority': 1,
#  'AlterNet': 1,
#  'Artificial Intelegence (AI': 1,
#  'the Detroit Free Press': 1,
#  'CCTV': 1,
#  'Pembangunan Jalan': 1,
#  'harga pasar': 1,
#  'Polymetal': 1,
#  'The Energy & Oil Sector Trade': 1,
#  'КХЛ 1 октября': 1,
#  'لإقامة مشروعات': 1,
#  '2221 Коментари': 1,
#  'САЩ General Motors': 1,
#  'dengan kantor pusat VW': 1,
#  'Karty': 1,
#  'PAPUA SIMPEG RRI LPP RRI': 1,
#  'Mobil FWD Perlukah Memanaskan Mobil-Mobil Keluaran Terbaru': 1,
#  'световната автомобилна индустрия"': 1,
#  'CIMB Dengan Mudah': 1,
#  'PLN Mobile': 1,
#  'Bosch': 1,
#  'Inggris Bikin Pusat': 1,
#  'serta para': 1,
#  'Kokpit Pesawat Rimbun Air': 1,
#  'Netizen Auto Bahagia': 1,
#  'Váš': 1,
#  'Baidu KUNLUN': 1,
#  'mobil dengan segera': 1,
#  'Защо България': 1,
#  'mobil impianya selama beberapa bulan': 1,
#  '10:00PM': 1,
#  'Kunjung Motor': 1,
#  'Tetapi Usaha': 1,
#  'PMI Manufaktur RI Lampaui': 1,
#  'AFP': 1,
#  'التي تم تسجيلها': 1,
#  'serie de electrocasnice': 1,
#  'добави Tata Motors': 1,
#  'MUNICH': 1,
#  'DPK Tumbuh 2 Oktober 2021': 1,
#  'Coupe': 1,
#  'nich toto': 1,
#  'لديها': 1,
#  'Senate': 1,
#  'Warga Uganda Bayar': 1,
#  'WIB Ketua': 1,
#  'التي تخلق هيكلًا معدنيًا': 1,
#  'Toyota Motor Corp': 1,
#  'Delta Variant Rages': 1,
#  'eBay': 1,
#  'Magna': 1,
#  'Renault SA': 1,
#  'Kala Inggris': 1,
#  'Produksi Toyota': 1,
#  'ANTARA/Toshiba': 1,
#  'Bain & Co.': 1,
#  'kelompok itu karena': 1,
#  'Arsenal': 1,
#  'AP/Matthias Schrader Mnichov - Automobilový': 1,
#  'Secţia': 1,
#  'NYSE': 1,
#  'VWAGY': 1,
#  'Marii Britanii': 1,
#  'Moody’s': 1,
#  'Home Umum Krisis': 1,
#  'السيارات بنسبة': 1,
#  'nowości': 1,
#  'електронния гигант': 1,
#  'Orbánova': 1,
#  'produksi mobil banyak tertunda': 1,
#  'Dia mengingatkan': 1,
#  'mengurangi disrupsi pada': 1,
#  'nimiž': 1,
#  'В САЩ ХАРДУЕР ПАЗАР НА ЧИПОВЕ MARVELL TECHNOLOGIES НЕДОСТИГ': 1,
#  'BYD (BYDDF': 1,
#  'Berikut Ini Program': 1,
#  'BMW M4': 1,
#  'Problemen wie Toshiba': 1,
#  'dengan mengatakan': 1,
#  'WIB Sebanyak': 1,
#  'Kalsel': 1,
#  'kebijakan khusus': 1,
#  'PAȘNIC Noi': 1,
#  'FC Rapid': 1,
#  'Meterai Tempel BLT': 1,
#  'Porsche': 1,
#  'MacBooków': 1,
#  'La escasez de': 1,
#  '성능으로는 1080Ti에 필적하는 성능에': 1,
#  'the Delta Variant': 1,
#  'The Nintendo Switch': 1,
#  'TASS': 1,
#  'Santa Fe': 1,
#  '제닉스': 1,
#  'Parlemen Eropa di Brussels': 1,
#  'SUSCRITO AL DIARIO IMPRESO': 1,
#  'masyarakat dengan menyerap': 1,
#  'SK Hynix Inc dan LG Display Co Ltd': 1,
#  'В А1': 1,
#  'kuota ketersediaan': 1,
#  'компонентите си': 1,
#  'LG Chem': 1,
#  'Mobil Bawa Sepeda': 1,
#  'Eklerek': 1,
#  'عندما': 1,
#  'إفلاسها': 1,
#  'terduga dengan': 1,
#  'NAND': 1,
#  '갤럭시 Z': 1,
#  'السيارات يجنون أرباحًا': 1,
#  'Wechsel': 1,
#  'Bloomberg Клиентите': 1,
#  'JPMorgan Siap-siap': 1,
#  'AMD 6나노': 1,
#  'VOLKSWAGEN VOLKSWAGEN AG': 1,
#  'VLSI Research': 1,
#  'Northvolt': 1,
#  'Marvell Technology': 1,
#  'وتجلب جوانب': 1,
#  'الخطوط': 1,
#  'JernihBerkomentar': 1,
#  'mobil GM': 1,
#  'Indo-Pacific': 1,
#  'mobil mewah naik harga': 1,
#  'Bahmuțeanca': 1,
#  'Samsung Display Co': 1,
#  'OLEH NAZRIN': 1,
#  'Как Tesla': 1,
#  'mobil tertunda penjualan': 1,
#  'Smartwatch Bisa': 1,
#  'Компании Прегледи': 1,
#  'Hotărârea de Guvern': 1,
#  'Answer Technology': 1,
#  'WSKT': 1,
#  'Pukul': 1,
#  'ta sytuacja': 1,
#  'WSJ': 1,
#  'Maycuzai': 1,
#  'Meet Mercedes Chat pada Kamis': 1,
#  'WIB Proses': 1,
#  'NĚMECKO AUTOMOTO': 1,
#  'رقائق مصنوعة': 1,
#  'Mitsubishi': 1,
#  'WIB Holding': 1,
#  'Apple - Google': 1,
#  'Semoga Cepat': 1,
#  'Алберт': 1,
#  'نصف نسبة': 1,
#  'В компании добавили': 1,
#  'WPG': 1,
#  'الإجمالي العالمي "': 1,
#  'JAKARTA - Perang': 1,
#  'الشهر المقبل وفقا': 1,
#  'Pak Ganjar Bikin Para Atlet Banten Terharu Sabtu': 1,
#  'HMC': 1,
#  'novináři': 1,
#  'dan pusat data': 1,
#  'GDPR': 1,
#  'partneři zpracováváme údaje': 1,
#  'ekranu': 1,
#  'mobil harus': 1,
#  'Silf-Swedbank': 1,
#  'Ini 5 Serial Bertema': 1,
#  'dan Volvo': 1,
#  'Qualcomm Inc': 1,
#  'w nadchodzących': 1,
#  'TSLA': 1,
#  'tetapi sektor': 1,
#  'BepiColombo': 1,
#  'Hadirkan Teknologi Smart Board Mini Court Room': 1,
#  'Nigeria Melunak': 1,
#  'german BMW AG': 1,
#  'Hitungan Hari Mercedes Benz': 1,
#  '베스트 브랜드어워드': 1,
#  'The Charlotte Observer': 1,
#  'Transaksi': 1,
#  '40%من إنتاجها العالمي': 1,
#  'DSA': 1,
#  'mobil lainnya': 1,
#  'sejumah produk VW': 1,
#  'Хари': 1,
#  'Kartu Kredit BCA Via ATM': 1,
#  'Korsel Saham Korsel': 1,
#  'XPT': 1,
#  'Kill Security Guard': 1,
#  'ADIZ': 1,
#  'softApple iOS iOS': 1,
#  'Atmosphere Press': 1,
#  'INTC': 1,
#  'Goya': 1,
#  'terpakasa': 1,
#  'německého automobilového': 1,
#  'Mobil  ': 1,
#  'karena kaca depan': 1,
#  'عقاقير': 1,
#  'acuză de': 1,
#  'NXPI': 1,
#  'producţia de': 1,
#  'KRL Masa Perpanjangan PPKM': 1,
#  'БСП': 1,
#  'Můžeme Vám': 1,
#  'Bank Sentral Kuba': 1,
#  'Berikut Ini Dampak': 1,
#  'Eropa Motor': 1,
#  'které mohou': 1,
#  'Ltd Akzeptieren Cyber Security Challenge': 1,
#  'orang beraktivitas di': 1,
#  'segera memperoleh': 1,
#  'Trackhawk Bersiap Masuk Museum': 1,
#  'karena pada saat itu ada': 1,
#  'CPU EPYC': 1,
#  'pe pagina cu': 1,
#  'setkání': 1,
#  'Skotsko': 1,
#  'upaya menjaga program vaksinasi': 1,
#  'Шарлийн Търсите': 1,
#  'مديروها بهدف': 1,
#  'MJF': 1,
#  'Jakarta - Hyundai Motors': 1,
#  'Партнерские': 1,
#  'FIFA': 1,
#  'producţia pe': 1,
#  'UNVR': 1,
#  "General Motors'": 1,
#  'GeForce': 1,
#  'JAKARTA - PT': 1,
#  'В същото време задръстванията': 1,
#  'Rudý': 1,
#  'Home Umum Scania': 1,
#  'Ukrajina v NATO': 1,
#  'Vendor-ii': 1}

# %%
with open('csvs/updated_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(sorted_freq_dict))

# %%
import itertools

thirty_sorted_freq_dict = dict(itertools.islice(sorted_freq_dict.items(), 30))

with open('csvs/updated_thirty_freq_company_names_gdlet.json', 'w+', encoding='utf-8') as f:
    f.writelines(json.dumps(thirty_sorted_freq_dict))

# %%
thirty_sorted_freq_dict
# Out:
# {'Pada': 150,
#  'WIB': 115,
#  'dengan': 108,
#  'Pasokan': 101,
#  'Ford': 58,
#  'nic': 58,
#  'Samsung': 54,
#  'Baca': 50,
#  'Toyota': 48,
#  'MIT': 47,
#  'ANTARA': 42,
#  'إلى': 37,
#  'EED': 36,
#  'Asan': 35,
#  'Salah': 33,
#  'عالم': 30,
#  'Pasar': 29,
#  'ZEN': 28,
#  'Tesla': 27,
#  'Hyundai': 26,
#  'недостиг': 26,
#  'Intel': 25,
#  'CNBC': 25,
#  'Penjualan': 25,
#  'BMW': 23,
#  'العالم': 23,
#  'Tapi': 23,
#  'Apple': 22,
#  'عام': 20,
#  'salah satu': 19}
